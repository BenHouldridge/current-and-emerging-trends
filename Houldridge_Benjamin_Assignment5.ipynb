# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 15
# Scores: (min: 15, avg: 15, max: 15)
#
# Run: 2, exploration: 0.9558895783575597, score: 14
# Scores: (min: 14, avg: 14.5, max: 15)
#
# Run: 3, exploration: 0.8911090557802088, score: 15
# Scores: (min: 14, avg: 14.666666666666666, max: 15)
#
# Run: 4, exploration: 0.7744209942832988, score: 29
# Scores: (min: 14, avg: 18.25, max: 29)
#
# Run: 5, exploration: 0.7183288830986236, score: 16
# Scores: (min: 14, avg: 17.8, max: 29)
#
# Run: 6, exploration: 0.6730128848950395, score: 14
# Scores: (min: 14, avg: 17.166666666666668, max: 29)
#
# Run: 7, exploration: 0.6305556603555866, score: 14
# Scores: (min: 14, avg: 16.714285714285715, max: 29)
#
# Run: 8, exploration: 0.5937455908197752, score: 13
# Scores: (min: 13, avg: 16.25, max: 29)
#
# Run: 9, exploration: 0.531750826943791, score: 23
# Scores: (min: 13, avg: 17, max: 29)
#
# Run: 10, exploration: 0.4907693883854626, score: 17
# Scores: (min: 13, avg: 17, max: 29)
#
# Run: 11, exploration: 0.457510005540005, score: 15
# Scores: (min: 13, avg: 16.818181818181817, max: 29)
#
# Run: 12, exploration: 0.3386767948568688, score: 61
# Scores: (min: 13, avg: 20.5, max: 61)
#
# Run: 13, exploration: 0.2943280830920294, score: 29
# Scores: (min: 13, avg: 21.153846153846153, max: 61)
#
# Run: 14, exploration: 0.27164454854530906, score: 17
# Scores: (min: 13, avg: 20.857142857142858, max: 61)
#
# Run: 15, exploration: 0.25966219297210513, score: 10
# Scores: (min: 10, avg: 20.133333333333333, max: 61)
#
# Run: 16, exploration: 0.23607350863684065, score: 20
# Scores: (min: 10, avg: 20.125, max: 61)
#
# Run: 17, exploration: 0.2211807388415433, score: 14
# Scores: (min: 10, avg: 19.764705882352942, max: 61)
#
# Run: 18, exploration: 0.20516038984972615, score: 16
# Scores: (min: 10, avg: 19.555555555555557, max: 61)
#
# Run: 19, exploration: 0.16957841978827493, score: 39
# Scores: (min: 10, avg: 20.57894736842105, max: 61)
#
# Run: 20, exploration: 0.138769433003975, score: 41
# Scores: (min: 10, avg: 21.6, max: 61)
#
# Run: 21, exploration: 0.1242800989098765, score: 23
# Scores: (min: 10, avg: 21.666666666666668, max: 61)
#
# Run: 22, exploration: 0.09770335251664321, score: 49
# Scores: (min: 10, avg: 22.90909090909091, max: 61)
#
# Run: 23, exploration: 0.09017346495423652, score: 17
# Scores: (min: 10, avg: 22.652173913043477, max: 61)
#
# Run: 24, exploration: 0.07995261925574046, score: 25
# Scores: (min: 10, avg: 22.75, max: 61)
#
# Run: 25, exploration: 0.0494138221100385, score: 97
# Scores: (min: 10, avg: 25.72, max: 97)
#
# Run: 26, exploration: 0.03163025067641567, score: 90
# Scores: (min: 10, avg: 28.192307692307693, max: 97)
#
# Run: 27, exploration: 0.022835098131175, score: 66
# Scores: (min: 10, avg: 29.59259259259259, max: 97)
#
# Run: 28, exploration: 0.015601164601953134, score: 77
# Scores: (min: 10, avg: 31.285714285714285, max: 97)
#
# Run: 29, exploration: 0.01, score: 107
# Scores: (min: 10, avg: 33.89655172413793, max: 107)
#
# Run: 30, exploration: 0.01, score: 26
# Scores: (min: 10, avg: 33.63333333333333, max: 107)
#
# Run: 31, exploration: 0.01, score: 105
# Scores: (min: 10, avg: 35.935483870967744, max: 107)
#
# Run: 32, exploration: 0.01, score: 136
# Scores: (min: 10, avg: 39.0625, max: 136)
#
# Run: 33, exploration: 0.01, score: 110
# Scores: (min: 10, avg: 41.21212121212121, max: 136)
#
# Run: 34, exploration: 0.01, score: 151
# Scores: (min: 10, avg: 44.44117647058823, max: 151)
#
# Run: 35, exploration: 0.01, score: 123
# Scores: (min: 10, avg: 46.68571428571428, max: 151)
#
# Run: 36, exploration: 0.01, score: 158
# Scores: (min: 10, avg: 49.77777777777778, max: 158)
#
# Run: 37, exploration: 0.01, score: 205
# Scores: (min: 10, avg: 53.972972972972975, max: 205)
#
# Run: 38, exploration: 0.01, score: 284
# Scores: (min: 10, avg: 60.026315789473685, max: 284)
#
# Run: 39, exploration: 0.01, score: 154
# Scores: (min: 10, avg: 62.43589743589744, max: 284)
#
# Run: 40, exploration: 0.01, score: 183
# Scores: (min: 10, avg: 65.45, max: 284)
#
# Run: 41, exploration: 0.01, score: 176
# Scores: (min: 10, avg: 68.14634146341463, max: 284)
#
# Run: 42, exploration: 0.01, score: 171
# Scores: (min: 10, avg: 70.5952380952381, max: 284)
#
# Run: 43, exploration: 0.01, score: 148
# Scores: (min: 10, avg: 72.3953488372093, max: 284)
#
# Run: 44, exploration: 0.01, score: 188
# Scores: (min: 10, avg: 75.02272727272727, max: 284)
#
# Run: 45, exploration: 0.01, score: 179
# Scores: (min: 10, avg: 77.33333333333333, max: 284)
#
# Run: 46, exploration: 0.01, score: 202
# Scores: (min: 10, avg: 80.04347826086956, max: 284)
#
# Run: 47, exploration: 0.01, score: 187
# Scores: (min: 10, avg: 82.31914893617021, max: 284)
#
# Run: 48, exploration: 0.01, score: 172
# Scores: (min: 10, avg: 84.1875, max: 284)
#
# Run: 49, exploration: 0.01, score: 274
# Scores: (min: 10, avg: 88.06122448979592, max: 284)
#
# Run: 50, exploration: 0.01, score: 186
# Scores: (min: 10, avg: 90.02, max: 284)
#
# Run: 51, exploration: 0.01, score: 149
# Scores: (min: 10, avg: 91.17647058823529, max: 284)
#
# Run: 52, exploration: 0.01, score: 167
# Scores: (min: 10, avg: 92.63461538461539, max: 284)
#
# Run: 53, exploration: 0.01, score: 171
# Scores: (min: 10, avg: 94.11320754716981, max: 284)
#
# Run: 54, exploration: 0.01, score: 150
# Scores: (min: 10, avg: 95.14814814814815, max: 284)
#
# Run: 55, exploration: 0.01, score: 249
# Scores: (min: 10, avg: 97.94545454545455, max: 284)
#
# Run: 56, exploration: 0.01, score: 169
# Scores: (min: 10, avg: 99.21428571428571, max: 284)
#
# Run: 57, exploration: 0.01, score: 268
# Scores: (min: 10, avg: 102.17543859649123, max: 284)
#
# Run: 58, exploration: 0.01, score: 175
# Scores: (min: 10, avg: 103.43103448275862, max: 284)
#
# Run: 59, exploration: 0.01, score: 185
# Scores: (min: 10, avg: 104.8135593220339, max: 284)
#
# Run: 60, exploration: 0.01, score: 206
# Scores: (min: 10, avg: 106.5, max: 284)
#
# Run: 61, exploration: 0.01, score: 181
# Scores: (min: 10, avg: 107.72131147540983, max: 284)
#
# Run: 62, exploration: 0.01, score: 169
# Scores: (min: 10, avg: 108.70967741935483, max: 284)
#
# Run: 63, exploration: 0.01, score: 206
# Scores: (min: 10, avg: 110.25396825396825, max: 284)
#
# Run: 64, exploration: 0.01, score: 225
# Scores: (min: 10, avg: 112.046875, max: 284)
#
# Run: 65, exploration: 0.01, score: 178
# Scores: (min: 10, avg: 113.06153846153846, max: 284)
#
# Run: 66, exploration: 0.01, score: 215
# Scores: (min: 10, avg: 114.60606060606061, max: 284)
#
# Run: 67, exploration: 0.01, score: 177
# Scores: (min: 10, avg: 115.53731343283582, max: 284)
#
# Run: 68, exploration: 0.01, score: 192
# Scores: (min: 10, avg: 116.66176470588235, max: 284)
#
# Run: 69, exploration: 0.01, score: 190
# Scores: (min: 10, avg: 117.72463768115942, max: 284)
#
# Run: 70, exploration: 0.01, score: 162
# Scores: (min: 10, avg: 118.35714285714286, max: 284)
#
# Run: 71, exploration: 0.01, score: 352
# Scores: (min: 10, avg: 121.64788732394366, max: 352)
#
# Run: 72, exploration: 0.01, score: 165
# Scores: (min: 10, avg: 122.25, max: 352)
#
# Run: 73, exploration: 0.01, score: 184
# Scores: (min: 10, avg: 123.0958904109589, max: 352)
#
# Run: 74, exploration: 0.01, score: 166
# Scores: (min: 10, avg: 123.67567567567568, max: 352)
#
# Run: 75, exploration: 0.01, score: 153
# Scores: (min: 10, avg: 124.06666666666666, max: 352)
#
# Run: 76, exploration: 0.01, score: 147
# Scores: (min: 10, avg: 124.36842105263158, max: 352)
#
# Run: 77, exploration: 0.01, score: 224
# Scores: (min: 10, avg: 125.66233766233766, max: 352)
#
# Run: 78, exploration: 0.01, score: 186
# Scores: (min: 10, avg: 126.43589743589743, max: 352)
#
# Run: 79, exploration: 0.01, score: 206
# Scores: (min: 10, avg: 127.44303797468355, max: 352)
#
# Run: 80, exploration: 0.01, score: 222
# Scores: (min: 10, avg: 128.625, max: 352)
#
# Run: 81, exploration: 0.01, score: 226
# Scores: (min: 10, avg: 129.82716049382717, max: 352)
#
# Run: 82, exploration: 0.01, score: 168
# Scores: (min: 10, avg: 130.29268292682926, max: 352)
#
# Run: 83, exploration: 0.01, score: 117
# Scores: (min: 10, avg: 130.13253012048193, max: 352)
#
# Run: 84, exploration: 0.01, score: 196
# Scores: (min: 10, avg: 130.91666666666666, max: 352)
#
# Run: 85, exploration: 0.01, score: 190
# Scores: (min: 10, avg: 131.61176470588236, max: 352)
#
# Run: 86, exploration: 0.01, score: 198
# Scores: (min: 10, avg: 132.38372093023256, max: 352)
#
# Run: 87, exploration: 0.01, score: 166
# Scores: (min: 10, avg: 132.77011494252875, max: 352)
#
# Run: 88, exploration: 0.01, score: 181
# Scores: (min: 10, avg: 133.3181818181818, max: 352)
# Run: 89, exploration: 0.01, score: 153
# Scores: (min: 10, avg: 133.53932584269663, max: 352)
#
# Run: 90, exploration: 0.01, score: 149
# Scores: (min: 10, avg: 133.7111111111111, max: 352)
#
# Run: 91, exploration: 0.01, score: 133
# Scores: (min: 10, avg: 133.7032967032967, max: 352)
#
# Run: 92, exploration: 0.01, score: 215
# Scores: (min: 10, avg: 134.58695652173913, max: 352)
#
# Run: 93, exploration: 0.01, score: 193
# Scores: (min: 10, avg: 135.21505376344086, max: 352)
#
# Run: 94, exploration: 0.01, score: 182
# Scores: (min: 10, avg: 135.7127659574468, max: 352)
#
# Run: 95, exploration: 0.01, score: 161
# Scores: (min: 10, avg: 135.97894736842105, max: 352)
#
# Run: 96, exploration: 0.01, score: 185
# Scores: (min: 10, avg: 136.48958333333334, max: 352)
#
# Run: 97, exploration: 0.01, score: 199
# Scores: (min: 10, avg: 137.1340206185567, max: 352)
#
# Run: 98, exploration: 0.01, score: 127
# Scores: (min: 10, avg: 137.03061224489795, max: 352)
#
# Run: 99, exploration: 0.01, score: 264
# Scores: (min: 10, avg: 138.31313131313132, max: 352)
#
# Run: 100, exploration: 0.01, score: 123
# Scores: (min: 10, avg: 138.16, max: 352)
#
# Run: 101, exploration: 0.01, score: 214
# Scores: (min: 10, avg: 140.15, max: 352)
#
# Run: 102, exploration: 0.01, score: 270
# Scores: (min: 10, avg: 142.71, max: 352)
#
# Run: 103, exploration: 0.01, score: 220
# Scores: (min: 10, avg: 144.76, max: 352)
#
# Run: 104, exploration: 0.01, score: 176
# Scores: (min: 10, avg: 146.23, max: 352)
#
# Run: 105, exploration: 0.01, score: 197
# Scores: (min: 10, avg: 148.04, max: 352)
#
# Run: 106, exploration: 0.01, score: 183
# Scores: (min: 10, avg: 149.73, max: 352)
#
# Run: 107, exploration: 0.01, score: 226
# Scores: (min: 10, avg: 151.85, max: 352)
#
# Run: 108, exploration: 0.01, score: 181
# Scores: (min: 10, avg: 153.53, max: 352)
#
# Run: 109, exploration: 0.01, score: 179
# Scores: (min: 10, avg: 155.09, max: 352)
#
# Run: 110, exploration: 0.01, score: 161
# Scores: (min: 10, avg: 156.53, max: 352)
#
# Run: 111, exploration: 0.01, score: 270
# Scores: (min: 10, avg: 159.08, max: 352)
#
# Run: 112, exploration: 0.01, score: 211
# Scores: (min: 10, avg: 160.58, max: 352)
#
# Run: 113, exploration: 0.01, score: 329
# Scores: (min: 10, avg: 163.58, max: 352)
#
# Run: 114, exploration: 0.01, score: 274
# Scores: (min: 10, avg: 166.15, max: 352)
#
# Run: 115, exploration: 0.01, score: 262
# Scores: (min: 14, avg: 168.67, max: 352)
#
# Run: 116, exploration: 0.01, score: 178
# Scores: (min: 14, avg: 170.25, max: 352)
#
# Run: 117, exploration: 0.01, score: 296
# Scores: (min: 16, avg: 173.07, max: 352)
#
# Run: 118, exploration: 0.01, score: 225
# Scores: (min: 17, avg: 175.16, max: 352)
#
# Run: 119, exploration: 0.01, score: 177
# Scores: (min: 17, avg: 176.54, max: 352)
#
# Run: 120, exploration: 0.01, score: 244
# Scores: (min: 17, avg: 178.57, max: 352)
#
# Run: 121, exploration: 0.01, score: 180
# Scores: (min: 17, avg: 180.14, max: 352)
#
# Run: 122, exploration: 0.01, score: 125
# Scores: (min: 17, avg: 180.9, max: 352)
#
# Run: 123, exploration: 0.01, score: 242
# Scores: (min: 25, avg: 183.15, max: 352)
#
# Run: 124, exploration: 0.01, score: 165
# Scores: (min: 26, avg: 184.55, max: 352)
#
# Run: 125, exploration: 0.01, score: 130
# Scores: (min: 26, avg: 184.88, max: 352)
#
# Run: 126, exploration: 0.01, score: 171
# Scores: (min: 26, avg: 185.69, max: 352)
#
# Run: 127, exploration: 0.01, score: 161
# Scores: (min: 26, avg: 186.64, max: 352)
#
# Run: 128, exploration: 0.01, score: 192
# Scores: (min: 26, avg: 187.79, max: 352)
#
# Run: 129, exploration: 0.01, score: 174
# Scores: (min: 26, avg: 188.46, max: 352)
#
# Run: 130, exploration: 0.01, score: 366
# Scores: (min: 105, avg: 191.86, max: 366)
#
# Run: 131, exploration: 0.01, score: 161
# Scores: (min: 110, avg: 192.42, max: 366)
#
# Run: 132, exploration: 0.01, score: 243
# Scores: (min: 110, avg: 193.49, max: 366)
#
# Run: 133, exploration: 0.01, score: 146
# Scores: (min: 117, avg: 193.85, max: 366)
#
# Run: 134, exploration: 0.01, score: 229
# Scores: (min: 117, avg: 194.63, max: 366)
#
# Run: 135, exploration: 0.01, score: 362
# Scores: (min: 117, avg: 197.02, max: 366)
#
# Solved in 35 runs, 135 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %% [markdown]
# Adjusting Exploration factor

# %%
EXPLORATION_DECAY = 0.9

cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 17
# Scores: (min: 17, avg: 17, max: 17)
#
# Run: 2, exploration: 0.1500946352969992, score: 21
# Scores: (min: 17, avg: 19, max: 21)
#
# Run: 3, exploration: 0.0523347633027361, score: 11
# Scores: (min: 11, avg: 16.333333333333332, max: 21)
#
# Run: 4, exploration: 0.020275559590445278, score: 10
# Scores: (min: 10, avg: 14.75, max: 21)
#
# Run: 5, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 13.8, max: 21)
#
# Run: 6, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 13, max: 21)
#
# Run: 7, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.285714285714286, max: 21)
#
# Run: 8, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12, max: 21)
#
# Run: 9, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.88888888888889, max: 21)
#
# Run: 10, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.8, max: 21)
#
# Run: 11, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.545454545454545, max: 21)
#
# Run: 12, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.666666666666666, max: 21)
#
# Run: 13, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.923076923076923, max: 21)
#
# Run: 14, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 13, max: 27)
#
# Run: 15, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 14.8, max: 40)
#
# Run: 16, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 14.875, max: 40)
#
# Run: 17, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.588235294117647, max: 40)
#
# Run: 18, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 17.5, max: 67)
#
# Run: 19, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 19.57894736842105, max: 67)
#
# Run: 20, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 19.45, max: 67)
#
# Run: 21, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19, max: 67)
#
# Run: 22, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 18.772727272727273, max: 67)
#
# Run: 23, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.347826086956523, max: 67)
#
# Run: 24, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18, max: 67)
#
# Run: 25, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.68, max: 67)
#
# Run: 26, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.46153846153846, max: 67)
#
# Run: 27, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 17.62962962962963, max: 67)
#
# Run: 28, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 18.821428571428573, max: 67)
#
# Run: 29, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 19.482758620689655, max: 67)
#
# Run: 30, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 19.7, max: 67)
#
# Run: 31, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 20.129032258064516, max: 67)
#
# Run: 32, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 22.15625, max: 85)
#
# Run: 33, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 23.303030303030305, max: 85)
#
# Run: 34, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 25.264705882352942, max: 90)
#
# Run: 35, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 28.057142857142857, max: 123)
#
# Run: 36, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 28.805555555555557, max: 123)
#
# Run: 37, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 30, max: 123)
#
# Run: 38, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 31.05263157894737, max: 123)
#
# Run: 39, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 31.871794871794872, max: 123)
#
# Run: 40, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 33.425, max: 123)
#
# Run: 41, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 35.390243902439025, max: 123)
#
# Run: 42, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 37.95238095238095, max: 143)
#
# Run: 43, exploration: 0.01, score: 140
# Scores: (min: 8, avg: 40.325581395348834, max: 143)
#
# Run: 44, exploration: 0.01, score: 227
# Scores: (min: 8, avg: 44.56818181818182, max: 227)
#
# Run: 45, exploration: 0.01, score: 271
# Scores: (min: 8, avg: 49.6, max: 271)
#
# Run: 46, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 52.391304347826086, max: 271)
#
# Run: 47, exploration: 0.01, score: 217
# Scores: (min: 8, avg: 55.8936170212766, max: 271)
#
# Run: 48, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 58.604166666666664, max: 271)
#
# Run: 49, exploration: 0.01, score: 230
# Scores: (min: 8, avg: 62.10204081632653, max: 271)
#
# Run: 50, exploration: 0.01, score: 180
# Scores: (min: 8, avg: 64.46, max: 271)
#
# Run: 51, exploration: 0.01, score: 252
# Scores: (min: 8, avg: 68.13725490196079, max: 271)
#
# Run: 52, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 70.0576923076923, max: 271)
#
# Run: 53, exploration: 0.01, score: 188
# Scores: (min: 8, avg: 72.28301886792453, max: 271)
#
# Run: 54, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 73.5, max: 271)
#
# Run: 55, exploration: 0.01, score: 148
# Scores: (min: 8, avg: 74.85454545454546, max: 271)
#
# Run: 56, exploration: 0.01, score: 233
# Scores: (min: 8, avg: 77.67857142857143, max: 271)
#
# Run: 57, exploration: 0.01, score: 146
# Scores: (min: 8, avg: 78.87719298245614, max: 271)
#
# Run: 58, exploration: 0.01, score: 210
# Scores: (min: 8, avg: 81.13793103448276, max: 271)
#
# Run: 59, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 82.01694915254237, max: 271)
#
# Run: 60, exploration: 0.01, score: 154
# Scores: (min: 8, avg: 83.21666666666667, max: 271)
#
# Run: 61, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 84.49180327868852, max: 271)
#
# Run: 62, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 85.88709677419355, max: 271)
#
# Run: 63, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 87.0952380952381, max: 271)
#
# Run: 64, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 88.171875, max: 271)
#
# Run: 65, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 89.29230769230769, max: 271)
#
# Run: 66, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 90.3030303030303, max: 271)
#
# Run: 67, exploration: 0.01, score: 187
# Scores: (min: 8, avg: 91.74626865671642, max: 271)
#
# Run: 68, exploration: 0.01, score: 191
# Scores: (min: 8, avg: 93.20588235294117, max: 271)
#
# Run: 69, exploration: 0.01, score: 273
# Scores: (min: 8, avg: 95.81159420289855, max: 273)
#
# Run: 70, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 96.5, max: 273)
#
# Run: 71, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 97.98591549295774, max: 273)
#
# Run: 72, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 98.90277777777777, max: 273)
#
# Run: 73, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 98.32876712328768, max: 273)
#
# Run: 74, exploration: 0.01, score: 197
# Scores: (min: 8, avg: 99.66216216216216, max: 273)
#
# Run: 75, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 100.24, max: 273)
#
# Run: 76, exploration: 0.01, score: 237
# Scores: (min: 8, avg: 102.03947368421052, max: 273)
#
# Run: 77, exploration: 0.01, score: 247
# Scores: (min: 8, avg: 103.92207792207792, max: 273)
#
# Run: 78, exploration: 0.01, score: 188
# Scores: (min: 8, avg: 105, max: 273)
#
# Run: 79, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 106.35443037974683, max: 273)
#
# Run: 80, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 107.25, max: 273)
#
# Run: 81, exploration: 0.01, score: 201
# Scores: (min: 8, avg: 108.4074074074074, max: 273)
#
# Run: 82, exploration: 0.01, score: 207
# Scores: (min: 8, avg: 109.60975609756098, max: 273)
#
# Run: 83, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 110.12048192771084, max: 273)
#
# Run: 84, exploration: 0.01, score: 210
# Scores: (min: 8, avg: 111.30952380952381, max: 273)
#
# Run: 85, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 111.75294117647059, max: 273)
#
# Run: 86, exploration: 0.01, score: 384
# Scores: (min: 8, avg: 114.9186046511628, max: 384)
#
# Run: 87, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 115.72413793103448, max: 384)
#
# Run: 88, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 116.43181818181819, max: 384)
#
# Run: 89, exploration: 0.01, score: 191
# Scores: (min: 8, avg: 117.26966292134831, max: 384)
#
# Run: 90, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 117.83333333333333, max: 384)
#
# Run: 91, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 118.05494505494505, max: 384)
#
# Run: 92, exploration: 0.01, score: 169
# Scores: (min: 8, avg: 118.6086956521739, max: 384)
#
# Run: 93, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 119.41935483870968, max: 384)
#
# Run: 94, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 119.73404255319149, max: 384)
# Run: 95, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 120.70526315789473, max: 384)
#
# Run: 96, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 121.65625, max: 384)
#
# Run: 97, exploration: 0.01, score: 239
# Scores: (min: 8, avg: 122.8659793814433, max: 384)
#
# Run: 98, exploration: 0.01, score: 294
# Scores: (min: 8, avg: 124.61224489795919, max: 384)
#
# Run: 99, exploration: 0.01, score: 265
# Scores: (min: 8, avg: 126.03030303030303, max: 384)
#
# Run: 100, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 126.63, max: 384)
#
# Run: 101, exploration: 0.01, score: 233
# Scores: (min: 8, avg: 128.79, max: 384)
#
# Run: 102, exploration: 0.01, score: 443
# Scores: (min: 8, avg: 133.01, max: 443)
#
# Run: 103, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 134.65, max: 443)
#
# Run: 104, exploration: 0.01, score: 223
# Scores: (min: 8, avg: 136.78, max: 443)
#
# Run: 105, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 138.77, max: 443)
#
# Run: 106, exploration: 0.01, score: 341
# Scores: (min: 8, avg: 142.09, max: 443)
#
# Run: 107, exploration: 0.01, score: 258
# Scores: (min: 9, avg: 144.59, max: 443)
#
# Run: 108, exploration: 0.01, score: 188
# Scores: (min: 9, avg: 146.37, max: 443)
#
# Run: 109, exploration: 0.01, score: 262
# Scores: (min: 9, avg: 148.88, max: 443)
#
# Run: 110, exploration: 0.01, score: 178
# Scores: (min: 9, avg: 150.55, max: 443)
#
# Run: 111, exploration: 0.01, score: 340
# Scores: (min: 9, avg: 153.86, max: 443)
#
# Run: 112, exploration: 0.01, score: 282
# Scores: (min: 9, avg: 156.55, max: 443)
#
# Run: 113, exploration: 0.01, score: 166
# Scores: (min: 9, avg: 158.06, max: 443)
#
# Run: 114, exploration: 0.01, score: 288
# Scores: (min: 9, avg: 160.67, max: 443)
#
# Run: 115, exploration: 0.01, score: 156
# Scores: (min: 9, avg: 161.83, max: 443)
#
# Run: 116, exploration: 0.01, score: 408
# Scores: (min: 9, avg: 165.75, max: 443)
#
# Run: 117, exploration: 0.01, score: 315
# Scores: (min: 9, avg: 168.8, max: 443)
#
# Run: 118, exploration: 0.01, score: 489
# Scores: (min: 9, avg: 173.02, max: 489)
#
# Run: 119, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 173.87, max: 489)
#
# Run: 120, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 175.12, max: 489)
#
# Run: 121, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 176.19, max: 489)
#
# Run: 122, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 176.15, max: 489)
#
# Run: 123, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 176.17, max: 489)
#
# Run: 124, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 176.16, max: 489)
#
# Run: 125, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 176.18, max: 489)
#
# Run: 126, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 176.17, max: 489)
#
# Run: 127, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 176.05, max: 489)
#
# Run: 128, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 175.64, max: 489)
#
# Run: 129, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 175.38, max: 489)
#
# Run: 130, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 175.26, max: 489)
#
# Run: 131, exploration: 0.01, score: 141
# Scores: (min: 9, avg: 176.34, max: 489)
#
# Run: 132, exploration: 0.01, score: 165
# Scores: (min: 9, avg: 177.14, max: 489)
#
# Run: 133, exploration: 0.01, score: 172
# Scores: (min: 9, avg: 178.26, max: 489)
#
# Run: 134, exploration: 0.01, score: 365
# Scores: (min: 9, avg: 181.01, max: 489)
#
# Run: 135, exploration: 0.01, score: 313
# Scores: (min: 9, avg: 182.91, max: 489)
#
# Run: 136, exploration: 0.01, score: 187
# Scores: (min: 9, avg: 184.23, max: 489)
#
# Run: 137, exploration: 0.01, score: 187
# Scores: (min: 9, avg: 185.37, max: 489)
#
# Run: 138, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 189.67, max: 500)
#
# Run: 139, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 190.4, max: 500)
#
# Run: 140, exploration: 0.01, score: 417
# Scores: (min: 9, avg: 193.63, max: 500)
#
# Run: 141, exploration: 0.01, score: 135
# Scores: (min: 9, avg: 193.84, max: 500)
#
# Run: 142, exploration: 0.01, score: 192
# Scores: (min: 9, avg: 194.33, max: 500)
#
# Run: 143, exploration: 0.01, score: 244
# Scores: (min: 9, avg: 195.37, max: 500)
#
# Solved in 43 runs, 143 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-3851e47cf7c3> in <module>
#       1 EXPLORATION_DECAY = 0.9
#       2
# ----> 3 cartpole()
#       4
#       5 EXPLORATION_DECAY = 0.999
#
# <ipython-input-6-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
EXPLORATION_DECAY = 0.999

cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 11
# Scores: (min: 11, avg: 11, max: 11)
#
# Run: 2, exploration: 0.9900448802097482, score: 19
# Scores: (min: 11, avg: 15, max: 19)
#
# Run: 3, exploration: 0.9792086759647052, score: 12
# Scores: (min: 11, avg: 14, max: 19)
#
# Run: 4, exploration: 0.9240034012385749, score: 59
# Scores: (min: 11, avg: 25.25, max: 59)
#
# Run: 5, exploration: 0.8886435861147077, score: 40
# Scores: (min: 11, avg: 28.2, max: 59)
#
# Run: 6, exploration: 0.8789172357313328, score: 12
# Scores: (min: 11, avg: 25.5, max: 59)
#
# Run: 7, exploration: 0.8615048875706075, score: 21
# Scores: (min: 11, avg: 24.857142857142858, max: 59)
#
# Run: 8, exploration: 0.8520755747117399, score: 12
# Scores: (min: 11, avg: 23.25, max: 59)
#
# Run: 9, exploration: 0.838544138970058, score: 17
# Scores: (min: 11, avg: 22.555555555555557, max: 59)
#
# Run: 10, exploration: 0.8285367691502946, score: 13
# Scores: (min: 11, avg: 21.6, max: 59)
#
# Run: 11, exploration: 0.8064546837933355, score: 28
# Scores: (min: 11, avg: 22.181818181818183, max: 59)
#
# Run: 12, exploration: 0.7968302765754727, score: 13
# Scores: (min: 11, avg: 21.416666666666668, max: 59)
#
# Run: 13, exploration: 0.7802631200940584, score: 22
# Scores: (min: 11, avg: 21.46153846153846, max: 59)
#
# Run: 14, exploration: 0.7671042341100781, score: 18
# Scores: (min: 11, avg: 21.214285714285715, max: 59)
#
# Run: 15, exploration: 0.7489039087598284, score: 25
# Scores: (min: 11, avg: 21.466666666666665, max: 59)
#
# Run: 16, exploration: 0.7377486453075807, score: 16
# Scores: (min: 11, avg: 21.125, max: 59)
#
# Run: 17, exploration: 0.723856864037602, score: 20
# Scores: (min: 11, avg: 21.058823529411764, max: 59)
#
# Run: 18, exploration: 0.7166507822451117, score: 11
# Scores: (min: 11, avg: 20.5, max: 59)
#
# Run: 19, exploration: 0.7010489129476946, score: 23
# Scores: (min: 11, avg: 20.63157894736842, max: 59)
#
# Run: 20, exploration: 0.6562518536710664, score: 67
# Scores: (min: 11, avg: 22.95, max: 67)
#
# Run: 21, exploration: 0.6149322608990545, score: 66
# Scores: (min: 11, avg: 25, max: 67)
#
# Run: 22, exploration: 0.6045616265570569, score: 18
# Scores: (min: 11, avg: 24.681818181818183, max: 67)
#
# Run: 23, exploration: 0.5937715237303958, score: 19
# Scores: (min: 11, avg: 24.434782608695652, max: 67)
#
# Run: 24, exploration: 0.5704779919833761, score: 41
# Scores: (min: 11, avg: 25.125, max: 67)
#
# Run: 25, exploration: 0.5563858806683429, score: 26
# Scores: (min: 11, avg: 25.16, max: 67)
#
# Run: 26, exploration: 0.5308282740091232, score: 48
# Scores: (min: 11, avg: 26.03846153846154, max: 67)
#
# Run: 27, exploration: 0.48706400382327686, score: 87
# Scores: (min: 11, avg: 28.296296296296298, max: 87)
#
# Run: 28, exploration: 0.46469070022213765, score: 48
# Scores: (min: 11, avg: 29, max: 87)
#
# Run: 29, exploration: 0.45185350084291465, score: 29
# Scores: (min: 11, avg: 29, max: 87)
#
# Run: 30, exploration: 0.43717846703394564, score: 34
# Scores: (min: 11, avg: 29.166666666666668, max: 87)
#
# Run: 31, exploration: 0.4133577680476022, score: 57
# Scores: (min: 11, avg: 30.06451612903226, max: 87)
#
# Run: 32, exploration: 0.31708849407160733, score: 266
# Scores: (min: 11, avg: 37.4375, max: 266)
#
# Run: 33, exploration: 0.25367890699899504, score: 224
# Scores: (min: 11, avg: 43.09090909090909, max: 266)
#
# Run: 34, exploration: 0.21680336036122028, score: 158
# Scores: (min: 11, avg: 46.470588235294116, max: 266)
#
# Run: 35, exploration: 0.1945981636633456, score: 109
# Scores: (min: 11, avg: 48.25714285714286, max: 266)
#
# Run: 36, exploration: 0.1731015115206527, score: 118
# Scores: (min: 11, avg: 50.19444444444444, max: 266)
#
# Run: 37, exploration: 0.15490664686436975, score: 112
# Scores: (min: 11, avg: 51.86486486486486, max: 266)
#
# Run: 38, exploration: 0.12517541657221892, score: 214
# Scores: (min: 11, avg: 56.13157894736842, max: 266)
#
# Run: 39, exploration: 0.10496511190976955, score: 177
# Scores: (min: 11, avg: 59.23076923076923, max: 266)
#
# Run: 40, exploration: 0.08696745469521953, score: 189
# Scores: (min: 11, avg: 62.475, max: 266)
#
# Run: 41, exploration: 0.06638020367707664, score: 271
# Scores: (min: 11, avg: 67.5609756097561, max: 271)
#
# Run: 42, exploration: 0.0544509234367423, score: 199
# Scores: (min: 11, avg: 70.69047619047619, max: 271)
#
# Run: 43, exploration: 0.0445316085507844, score: 202
# Scores: (min: 11, avg: 73.74418604651163, max: 271)
#
# Run: 44, exploration: 0.03481596895257846, score: 247
# Scores: (min: 11, avg: 77.68181818181819, max: 271)
#
# Run: 45, exploration: 0.027247276679492435, score: 246
# Scores: (min: 11, avg: 81.42222222222222, max: 271)
#
# Run: 46, exploration: 0.017881075828405323, score: 422
# Scores: (min: 11, avg: 88.82608695652173, max: 422)
#
# Run: 47, exploration: 0.01211625945940831, score: 390
# Scores: (min: 11, avg: 95.23404255319149, max: 422)
#
# Run: 48, exploration: 0.010139708479233867, score: 179
# Scores: (min: 11, avg: 96.97916666666667, max: 422)
#
# Run: 49, exploration: 0.01, score: 157
# Scores: (min: 11, avg: 98.20408163265306, max: 422)
#
# Run: 50, exploration: 0.01, score: 212
# Scores: (min: 11, avg: 100.48, max: 422)
#
# Run: 51, exploration: 0.01, score: 214
# Scores: (min: 11, avg: 102.70588235294117, max: 422)
#
# Run: 52, exploration: 0.01, score: 216
# Scores: (min: 11, avg: 104.88461538461539, max: 422)
#
# Run: 53, exploration: 0.01, score: 267
# Scores: (min: 11, avg: 107.94339622641509, max: 422)
#
# Run: 54, exploration: 0.01, score: 229
# Scores: (min: 11, avg: 110.18518518518519, max: 422)
#
# Run: 55, exploration: 0.01, score: 254
# Scores: (min: 11, avg: 112.8, max: 422)
#
# Run: 56, exploration: 0.01, score: 171
# Scores: (min: 11, avg: 113.83928571428571, max: 422)
#
# Run: 57, exploration: 0.01, score: 192
# Scores: (min: 11, avg: 115.21052631578948, max: 422)
#
# Run: 58, exploration: 0.01, score: 298
# Scores: (min: 11, avg: 118.36206896551724, max: 422)
#
# Run: 59, exploration: 0.01, score: 349
# Scores: (min: 11, avg: 122.27118644067797, max: 422)
#
# Run: 60, exploration: 0.01, score: 235
# Scores: (min: 11, avg: 124.15, max: 422)
#
# Run: 61, exploration: 0.01, score: 260
# Scores: (min: 11, avg: 126.37704918032787, max: 422)
#
# Run: 62, exploration: 0.01, score: 209
# Scores: (min: 11, avg: 127.70967741935483, max: 422)
#
# Run: 63, exploration: 0.01, score: 230
# Scores: (min: 11, avg: 129.33333333333334, max: 422)
#
# Run: 64, exploration: 0.01, score: 175
# Scores: (min: 11, avg: 130.046875, max: 422)
#
# Run: 65, exploration: 0.01, score: 160
# Scores: (min: 11, avg: 130.5076923076923, max: 422)
#
# Run: 66, exploration: 0.01, score: 201
# Scores: (min: 11, avg: 131.57575757575756, max: 422)
#
# Run: 67, exploration: 0.01, score: 214
# Scores: (min: 11, avg: 132.80597014925374, max: 422)
#
# Run: 68, exploration: 0.01, score: 245
# Scores: (min: 11, avg: 134.4558823529412, max: 422)
#
# Run: 69, exploration: 0.01, score: 182
# Scores: (min: 11, avg: 135.14492753623188, max: 422)
#
# Run: 70, exploration: 0.01, score: 155
# Scores: (min: 11, avg: 135.42857142857142, max: 422)
#
# Run: 71, exploration: 0.01, score: 175
# Scores: (min: 11, avg: 135.98591549295776, max: 422)
#
# Run: 72, exploration: 0.01, score: 109
# Scores: (min: 11, avg: 135.61111111111111, max: 422)
#
# Run: 73, exploration: 0.01, score: 197
# Scores: (min: 11, avg: 136.45205479452054, max: 422)
#
# Run: 74, exploration: 0.01, score: 201
# Scores: (min: 11, avg: 137.32432432432432, max: 422)
#
# Run: 75, exploration: 0.01, score: 177
# Scores: (min: 11, avg: 137.85333333333332, max: 422)
#
# Run: 76, exploration: 0.01, score: 202
# Scores: (min: 11, avg: 138.69736842105263, max: 422)
#
# Run: 77, exploration: 0.01, score: 160
# Scores: (min: 11, avg: 138.97402597402598, max: 422)
#
# Run: 78, exploration: 0.01, score: 124
# Scores: (min: 11, avg: 138.78205128205127, max: 422)
#
# Run: 79, exploration: 0.01, score: 122
# Scores: (min: 11, avg: 138.56962025316454, max: 422)
#
# Run: 80, exploration: 0.01, score: 228
# Scores: (min: 11, avg: 139.6875, max: 422)
#
# Run: 81, exploration: 0.01, score: 159
# Scores: (min: 11, avg: 139.92592592592592, max: 422)
#
# Run: 82, exploration: 0.01, score: 218
# Scores: (min: 11, avg: 140.8780487804878, max: 422)
#
# Run: 83, exploration: 0.01, score: 158
# Scores: (min: 11, avg: 141.0843373493976, max: 422)
#
# Run: 84, exploration: 0.01, score: 131
# Scores: (min: 11, avg: 140.96428571428572, max: 422)
#
# Run: 85, exploration: 0.01, score: 217
# Scores: (min: 11, avg: 141.85882352941175, max: 422)
#
# Run: 86, exploration: 0.01, score: 108
# Scores: (min: 11, avg: 141.46511627906978, max: 422)
# Run: 87, exploration: 0.01, score: 141
# Scores: (min: 11, avg: 141.45977011494253, max: 422)
#
# Run: 88, exploration: 0.01, score: 245
# Scores: (min: 11, avg: 142.63636363636363, max: 422)
#
# Run: 89, exploration: 0.01, score: 151
# Scores: (min: 11, avg: 142.73033707865167, max: 422)
#
# Run: 90, exploration: 0.01, score: 158
# Scores: (min: 11, avg: 142.9, max: 422)
#
# Run: 91, exploration: 0.01, score: 202
# Scores: (min: 11, avg: 143.54945054945054, max: 422)
#
# Run: 92, exploration: 0.01, score: 186
# Scores: (min: 11, avg: 144.0108695652174, max: 422)
#
# Run: 93, exploration: 0.01, score: 135
# Scores: (min: 11, avg: 143.91397849462365, max: 422)
#
# Run: 94, exploration: 0.01, score: 173
# Scores: (min: 11, avg: 144.22340425531914, max: 422)
#
# Run: 95, exploration: 0.01, score: 210
# Scores: (min: 11, avg: 144.9157894736842, max: 422)
#
# Run: 96, exploration: 0.01, score: 238
# Scores: (min: 11, avg: 145.88541666666666, max: 422)
#
# Run: 97, exploration: 0.01, score: 251
# Scores: (min: 11, avg: 146.96907216494844, max: 422)
#
# Run: 98, exploration: 0.01, score: 126
# Scores: (min: 11, avg: 146.75510204081633, max: 422)
#
# Run: 99, exploration: 0.01, score: 287
# Scores: (min: 11, avg: 148.17171717171718, max: 422)
#
# Run: 100, exploration: 0.01, score: 170
# Scores: (min: 11, avg: 148.39, max: 422)
#
# Run: 101, exploration: 0.01, score: 381
# Scores: (min: 11, avg: 152.09, max: 422)
#
# Run: 102, exploration: 0.01, score: 214
# Scores: (min: 11, avg: 154.04, max: 422)
#
# Run: 103, exploration: 0.01, score: 230
# Scores: (min: 11, avg: 156.22, max: 422)
#
# Run: 104, exploration: 0.01, score: 145
# Scores: (min: 11, avg: 157.08, max: 422)
#
# Run: 105, exploration: 0.01, score: 221
# Scores: (min: 11, avg: 158.89, max: 422)
#
# Run: 106, exploration: 0.01, score: 314
# Scores: (min: 11, avg: 161.91, max: 422)
#
# Run: 107, exploration: 0.01, score: 145
# Scores: (min: 11, avg: 163.15, max: 422)
#
# Run: 108, exploration: 0.01, score: 248
# Scores: (min: 11, avg: 165.51, max: 422)
#
# Run: 109, exploration: 0.01, score: 114
# Scores: (min: 11, avg: 166.48, max: 422)
#
# Run: 110, exploration: 0.01, score: 134
# Scores: (min: 11, avg: 167.69, max: 422)
#
# Run: 111, exploration: 0.01, score: 235
# Scores: (min: 11, avg: 169.76, max: 422)
#
# Run: 112, exploration: 0.01, score: 319
# Scores: (min: 11, avg: 172.82, max: 422)
#
# Run: 113, exploration: 0.01, score: 164
# Scores: (min: 11, avg: 174.24, max: 422)
#
# Run: 114, exploration: 0.01, score: 171
# Scores: (min: 11, avg: 175.77, max: 422)
#
# Run: 115, exploration: 0.01, score: 123
# Scores: (min: 11, avg: 176.75, max: 422)
#
# Run: 116, exploration: 0.01, score: 105
# Scores: (min: 11, avg: 177.64, max: 422)
#
# Run: 117, exploration: 0.01, score: 103
# Scores: (min: 11, avg: 178.47, max: 422)
#
# Run: 118, exploration: 0.01, score: 142
# Scores: (min: 18, avg: 179.78, max: 422)
#
# Run: 119, exploration: 0.01, score: 229
# Scores: (min: 18, avg: 181.84, max: 422)
#
# Run: 120, exploration: 0.01, score: 176
# Scores: (min: 18, avg: 182.93, max: 422)
#
# Run: 121, exploration: 0.01, score: 122
# Scores: (min: 18, avg: 183.49, max: 422)
#
# Run: 122, exploration: 0.01, score: 176
# Scores: (min: 19, avg: 185.07, max: 422)
#
# Run: 123, exploration: 0.01, score: 182
# Scores: (min: 26, avg: 186.7, max: 422)
#
# Run: 124, exploration: 0.01, score: 143
# Scores: (min: 26, avg: 187.72, max: 422)
#
# Run: 125, exploration: 0.01, score: 131
# Scores: (min: 29, avg: 188.77, max: 422)
#
# Run: 126, exploration: 0.01, score: 132
# Scores: (min: 29, avg: 189.61, max: 422)
#
# Run: 127, exploration: 0.01, score: 286
# Scores: (min: 29, avg: 191.6, max: 422)
#
# Run: 128, exploration: 0.01, score: 168
# Scores: (min: 29, avg: 192.8, max: 422)
#
# Run: 129, exploration: 0.01, score: 282
# Scores: (min: 34, avg: 195.33, max: 422)
#
# Solved in 29 runs, 129 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e891f0c56dc7> in <module>
#       1 EXPLORATION_DECAY = 0.999
#       2
# ----> 3 cartpole()
#
# <ipython-input-6-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
GAMMA = 0.99

cartpole()
# Out:
# Run: 1, exploration: 0.9811700348643991, score: 39
# Scores: (min: 39, avg: 39, max: 39)
#
# Run: 2, exploration: 0.9540649618417361, score: 29
# Scores: (min: 29, avg: 34, max: 39)
#
# Run: 3, exploration: 0.9342286880693633, score: 22
# Scores: (min: 22, avg: 30, max: 39)
#
# Run: 4, exploration: 0.9102399514140735, score: 27
# Scores: (min: 22, avg: 29.25, max: 39)
#
# Run: 5, exploration: 0.9011784036598737, score: 11
# Scores: (min: 11, avg: 25.6, max: 39)
#
# Run: 6, exploration: 0.857205969570888, score: 51
# Scores: (min: 11, avg: 29.833333333333332, max: 51)
#
# Run: 7, exploration: 0.8419067177676068, score: 19
# Scores: (min: 11, avg: 28.285714285714285, max: 51)
#
# Run: 8, exploration: 0.818648829478636, score: 29
# Scores: (min: 11, avg: 28.375, max: 51)
#
# Run: 9, exploration: 0.8064546837933355, score: 16
# Scores: (min: 11, avg: 27, max: 51)
#
# Run: 10, exploration: 0.759467619567903, score: 61
# Scores: (min: 11, avg: 30.4, max: 61)
#
# Run: 11, exploration: 0.7407070321560997, score: 26
# Scores: (min: 11, avg: 30, max: 61)
#
# Run: 12, exploration: 0.7333332049215037, score: 11
# Scores: (min: 11, avg: 28.416666666666668, max: 61)
#
# Run: 13, exploration: 0.7152181973314037, score: 26
# Scores: (min: 11, avg: 28.23076923076923, max: 61)
#
# Run: 14, exploration: 0.704564697832001, score: 16
# Scores: (min: 11, avg: 27.357142857142858, max: 61)
#
# Run: 15, exploration: 0.6940698870404746, score: 16
# Scores: (min: 11, avg: 26.6, max: 61)
#
# Run: 16, exploration: 0.6742211329618302, score: 30
# Scores: (min: 11, avg: 26.8125, max: 61)
#
# Run: 17, exploration: 0.6681773581762521, score: 10
# Scores: (min: 10, avg: 25.823529411764707, max: 61)
#
# Run: 18, exploration: 0.649069069067341, score: 30
# Scores: (min: 10, avg: 26.055555555555557, max: 61)
#
# Run: 19, exploration: 0.6432507594921204, score: 10
# Scores: (min: 10, avg: 25.210526315789473, max: 61)
#
# Run: 20, exploration: 0.6330355783788719, score: 17
# Scores: (min: 10, avg: 24.8, max: 61)
#
# Run: 21, exploration: 0.6273609943589779, score: 10
# Scores: (min: 10, avg: 24.095238095238095, max: 61)
#
# Run: 22, exploration: 0.6155478087077623, score: 20
# Scores: (min: 10, avg: 23.90909090909091, max: 61)
#
# Run: 23, exploration: 0.6033531078655693, score: 21
# Scores: (min: 10, avg: 23.782608695652176, max: 61)
#
# Run: 24, exploration: 0.5913999978901242, score: 21
# Scores: (min: 10, avg: 23.666666666666668, max: 61)
#
# Run: 25, exploration: 0.5837577583990794, score: 14
# Scores: (min: 10, avg: 23.28, max: 61)
#
# Run: 26, exploration: 0.5664966061305491, score: 31
# Scores: (min: 10, avg: 23.576923076923077, max: 61)
#
# Run: 27, exploration: 0.5513983909676525, score: 28
# Scores: (min: 10, avg: 23.74074074074074, max: 61)
#
# Run: 28, exploration: 0.5115370697939825, score: 76
# Scores: (min: 10, avg: 25.607142857142858, max: 76)
#
# Run: 29, exploration: 0.48028925378937887, score: 64
# Scores: (min: 10, avg: 26.93103448275862, max: 76)
#
# Run: 30, exploration: 0.45321177699177073, score: 59
# Scores: (min: 10, avg: 28, max: 76)
#
# Run: 31, exploration: 0.41501534097911913, score: 89
# Scores: (min: 10, avg: 29.967741935483872, max: 89)
#
# Run: 32, exploration: 0.3452343370855593, score: 185
# Scores: (min: 10, avg: 34.8125, max: 185)
#
# Run: 33, exploration: 0.30556495775503617, score: 123
# Scores: (min: 10, avg: 37.484848484848484, max: 185)
#
# Run: 34, exploration: 0.28262568595092585, score: 79
# Scores: (min: 10, avg: 38.705882352941174, max: 185)
#
# Run: 35, exploration: 0.2637729867768368, score: 70
# Scores: (min: 10, avg: 39.6, max: 185)
#
# Run: 36, exploration: 0.2341657727166659, score: 120
# Scores: (min: 10, avg: 41.833333333333336, max: 185)
#
# Run: 37, exploration: 0.1805304042562526, score: 261
# Scores: (min: 10, avg: 47.75675675675676, max: 261)
#
# Run: 38, exploration: 0.14631972697965345, score: 211
# Scores: (min: 10, avg: 52.05263157894737, max: 261)
#
# Run: 39, exploration: 0.11057057941158951, score: 281
# Scores: (min: 10, avg: 57.92307692307692, max: 281)
#
# Run: 40, exploration: 0.09346340681465164, score: 169
# Scores: (min: 10, avg: 60.7, max: 281)
#
# Run: 41, exploration: 0.07140982029180207, score: 270
# Scores: (min: 10, avg: 65.8048780487805, max: 281)
#
# Run: 42, exploration: 0.058284362418015906, score: 204
# Scores: (min: 10, avg: 69.0952380952381, max: 281)
#
# Run: 43, exploration: 0.047619043934701566, score: 203
# Scores: (min: 10, avg: 72.20930232558139, max: 281)
#
# Run: 44, exploration: 0.03851803962216637, score: 213
# Scores: (min: 10, avg: 75.4090909090909, max: 281)
#
# Run: 45, exploration: 0.030478137250104044, score: 235
# Scores: (min: 10, avg: 78.95555555555555, max: 281)
#
# Run: 46, exploration: 0.024801559800907015, score: 207
# Scores: (min: 10, avg: 81.73913043478261, max: 281)
#
# Run: 47, exploration: 0.020880599807498616, score: 173
# Scores: (min: 10, avg: 83.68085106382979, max: 281)
#
# Run: 48, exploration: 0.01731766236478993, score: 188
# Scores: (min: 10, avg: 85.85416666666667, max: 281)
#
# Run: 49, exploration: 0.01430531809549558, score: 192
# Scores: (min: 10, avg: 88.0204081632653, max: 281)
#
# Run: 50, exploration: 0.011947730008373113, score: 181
# Scores: (min: 10, avg: 89.88, max: 281)
#
# Run: 51, exploration: 0.01, score: 195
# Scores: (min: 10, avg: 91.94117647058823, max: 281)
#
# Run: 52, exploration: 0.01, score: 255
# Scores: (min: 10, avg: 95.07692307692308, max: 281)
#
# Run: 53, exploration: 0.01, score: 174
# Scores: (min: 10, avg: 96.56603773584905, max: 281)
#
# Run: 54, exploration: 0.01, score: 165
# Scores: (min: 10, avg: 97.83333333333333, max: 281)
#
# Run: 55, exploration: 0.01, score: 219
# Scores: (min: 10, avg: 100.03636363636363, max: 281)
#
# Run: 56, exploration: 0.01, score: 254
# Scores: (min: 10, avg: 102.78571428571429, max: 281)
#
# Run: 57, exploration: 0.01, score: 359
# Scores: (min: 10, avg: 107.28070175438596, max: 359)
#
# Run: 58, exploration: 0.01, score: 323
# Scores: (min: 10, avg: 111, max: 359)
#
# Run: 59, exploration: 0.01, score: 298
# Scores: (min: 10, avg: 114.16949152542372, max: 359)
#
# Run: 60, exploration: 0.01, score: 317
# Scores: (min: 10, avg: 117.55, max: 359)
#
# Run: 61, exploration: 0.01, score: 338
# Scores: (min: 10, avg: 121.1639344262295, max: 359)
#
# Run: 62, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 127.2741935483871, max: 500)
#
# Run: 63, exploration: 0.01, score: 428
# Scores: (min: 10, avg: 132.04761904761904, max: 500)
#
# Run: 64, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 137.796875, max: 500)
#
# Run: 65, exploration: 0.01, score: 487
# Scores: (min: 10, avg: 143.16923076923078, max: 500)
#
# Run: 66, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 148.57575757575756, max: 500)
#
# Run: 67, exploration: 0.01, score: 325
# Scores: (min: 10, avg: 151.2089552238806, max: 500)
#
# Run: 68, exploration: 0.01, score: 302
# Scores: (min: 10, avg: 153.4264705882353, max: 500)
#
# Run: 69, exploration: 0.01, score: 216
# Scores: (min: 10, avg: 154.33333333333334, max: 500)
#
# Run: 70, exploration: 0.01, score: 220
# Scores: (min: 10, avg: 155.27142857142857, max: 500)
#
# Run: 71, exploration: 0.01, score: 170
# Scores: (min: 10, avg: 155.4788732394366, max: 500)
#
# Run: 72, exploration: 0.01, score: 222
# Scores: (min: 10, avg: 156.40277777777777, max: 500)
#
# Run: 73, exploration: 0.01, score: 160
# Scores: (min: 10, avg: 156.45205479452054, max: 500)
#
# Run: 74, exploration: 0.01, score: 224
# Scores: (min: 10, avg: 157.36486486486487, max: 500)
#
# Run: 75, exploration: 0.01, score: 456
# Scores: (min: 10, avg: 161.34666666666666, max: 500)
#
# Run: 76, exploration: 0.01, score: 236
# Scores: (min: 10, avg: 162.32894736842104, max: 500)
#
# Run: 77, exploration: 0.01, score: 211
# Scores: (min: 10, avg: 162.96103896103895, max: 500)
#
# Run: 78, exploration: 0.01, score: 177
# Scores: (min: 10, avg: 163.14102564102564, max: 500)
#
# Run: 79, exploration: 0.01, score: 179
# Scores: (min: 10, avg: 163.34177215189874, max: 500)
#
# Run: 80, exploration: 0.01, score: 173
# Scores: (min: 10, avg: 163.4625, max: 500)
#
# Run: 81, exploration: 0.01, score: 196
# Scores: (min: 10, avg: 163.8641975308642, max: 500)
#
# Run: 82, exploration: 0.01, score: 194
# Scores: (min: 10, avg: 164.23170731707316, max: 500)
#
# Run: 83, exploration: 0.01, score: 189
# Scores: (min: 10, avg: 164.53012048192772, max: 500)
#
# Run: 84, exploration: 0.01, score: 142
# Scores: (min: 10, avg: 164.26190476190476, max: 500)
#
# Run: 85, exploration: 0.01, score: 196
# Scores: (min: 10, avg: 164.63529411764705, max: 500)
# Run: 86, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 168.53488372093022, max: 500)
#
# Run: 87, exploration: 0.01, score: 225
# Scores: (min: 10, avg: 169.183908045977, max: 500)
#
# Run: 88, exploration: 0.01, score: 264
# Scores: (min: 10, avg: 170.26136363636363, max: 500)
#
# Run: 89, exploration: 0.01, score: 149
# Scores: (min: 10, avg: 170.02247191011236, max: 500)
#
# Run: 90, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 168.23333333333332, max: 500)
#
# Run: 91, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 166.4945054945055, max: 500)
#
# Run: 92, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 164.7826086956522, max: 500)
#
# Run: 93, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 163.11827956989248, max: 500)
#
# Run: 94, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 161.4787234042553, max: 500)
#
# Run: 95, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 159.8842105263158, max: 500)
#
# Run: 96, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 158.32291666666666, max: 500)
#
# Run: 97, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 156.79381443298968, max: 500)
#
# Run: 98, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 155.28571428571428, max: 500)
#
# Run: 99, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 153.8080808080808, max: 500)
#
# Run: 100, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 152.37, max: 500)
#
# Run: 101, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 152.08, max: 500)
#
# Run: 102, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 151.89, max: 500)
#
# Run: 103, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 151.77, max: 500)
#
# Run: 104, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 151.6, max: 500)
#
# Run: 105, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 151.57, max: 500)
#
# Run: 106, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 151.15, max: 500)
#
# Run: 107, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 151.05, max: 500)
#
# Run: 108, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 150.86, max: 500)
#
# Run: 109, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 150.8, max: 500)
#
# Run: 110, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 150.29, max: 500)
#
# Run: 111, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 150.11, max: 500)
#
# Run: 112, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 150.09, max: 500)
#
# Run: 113, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 149.92, max: 500)
#
# Run: 114, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 149.86, max: 500)
#
# Run: 115, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 149.8, max: 500)
#
# Run: 116, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 149.6, max: 500)
#
# Run: 117, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 149.75, max: 500)
#
# Run: 118, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 149.58, max: 500)
#
# Run: 119, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 149.61, max: 500)
#
# Run: 120, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 149.62, max: 500)
#
# Run: 121, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 149.63, max: 500)
#
# Run: 122, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 149.52, max: 500)
#
# Run: 123, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 149.42, max: 500)
#
# Run: 124, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 149.31, max: 500)
#
# Run: 125, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 149.28, max: 500)
#
# Run: 126, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 149.06, max: 500)
#
# Run: 127, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 148.88, max: 500)
#
# Run: 128, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 148.21, max: 500)
#
# Run: 129, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 147.67, max: 500)
#
# Run: 130, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 147.18, max: 500)
#
# Run: 131, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 146.38, max: 500)
#
# Run: 132, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 144.61, max: 500)
#
# Run: 133, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 143.48, max: 500)
#
# Run: 134, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 142.79, max: 500)
#
# Run: 135, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 142.19, max: 500)
#
# Run: 136, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 141.08, max: 500)
#
# Run: 137, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 138.57, max: 500)
#
# Run: 138, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 136.54, max: 500)
#
# Run: 139, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 133.83, max: 500)
#
# Run: 140, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 132.24, max: 500)
#
# Run: 141, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 129.63, max: 500)
#
# Run: 142, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 127.68, max: 500)
#
# Run: 143, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 125.74, max: 500)
#
# Run: 144, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 123.72, max: 500)
#
# Run: 145, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 121.47, max: 500)
#
# Run: 146, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 119.48, max: 500)
#
# Run: 147, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 117.86, max: 500)
#
# Run: 148, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 116.07, max: 500)
#
# Run: 149, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 114.25, max: 500)
#
# Run: 150, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 112.54, max: 500)
#
# Run: 151, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 110.68, max: 500)
#
# Run: 152, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 108.23, max: 500)
#
# Run: 153, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 106.58, max: 500)
#
# Run: 154, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 105.03, max: 500)
#
# Run: 155, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 102.94, max: 500)
#
# Run: 156, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 100.5, max: 500)
#
# Run: 157, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 97, max: 500)
#
# Run: 158, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 93.87, max: 500)
#
# Run: 159, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 90.98, max: 500)
#
# Run: 160, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 87.89, max: 500)
#
# Run: 161, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 84.6, max: 500)
#
# Run: 162, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 79.69, max: 500)
#
# Run: 163, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 75.51, max: 500)
#
# Run: 164, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 70.61, max: 500)
#
# Run: 165, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 65.82, max: 500)
#
# Run: 166, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 60.9, max: 500)
#
# Run: 167, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 57.75, max: 500)
#
# Run: 168, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 54.81, max: 500)
#
# Run: 169, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 52.75, max: 500)
#
# Run: 170, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 50.63, max: 500)
#
# Run: 171, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 49.01, max: 500)
#
# Run: 172, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 46.87, max: 500)
#
# Run: 173, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 45.37, max: 500)
#
# Run: 174, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 43.23, max: 500)
#
# Run: 175, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 38.76, max: 500)
#
# Run: 176, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 36.5, max: 500)
#
# Run: 177, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 34.48, max: 500)
#
# Run: 178, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 32.8, max: 500)
#
# Run: 179, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 31.1, max: 500)
#
# Run: 180, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.47, max: 500)
#
# Run: 181, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.6, max: 500)
#
# Run: 182, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.75, max: 500)
#
# Run: 183, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.95, max: 500)
#
# Run: 184, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 22.65, max: 500)
#
# Run: 185, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 20.85, max: 500)
#
# Run: 186, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.98, max: 264)
#
# Run: 187, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.85, max: 264)
# Run: 188, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 11.62, max: 149)
#
# Run: 189, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 10.31, max: 41)
#
# Run: 190, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 11.17, max: 95)
#
# Run: 191, exploration: 0.01, score: 118
# Scores: (min: 8, avg: 12.25, max: 118)
#
# Run: 192, exploration: 0.01, score: 428
# Scores: (min: 8, avg: 16.44, max: 428)
#
# Run: 193, exploration: 0.01, score: 203
# Scores: (min: 8, avg: 18.37, max: 428)
#
# Run: 194, exploration: 0.01, score: 355
# Scores: (min: 8, avg: 21.83, max: 428)
#
# Run: 195, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 23.39, max: 428)
#
# Run: 196, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 24.86, max: 428)
#
# Run: 197, exploration: 0.01, score: 210
# Scores: (min: 8, avg: 26.86, max: 428)
#
# Run: 198, exploration: 0.01, score: 221
# Scores: (min: 8, avg: 28.98, max: 428)
#
# Run: 199, exploration: 0.01, score: 218
# Scores: (min: 8, avg: 31.07, max: 428)
#
# Run: 200, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 35.97, max: 500)
#
# Run: 201, exploration: 0.01, score: 169
# Scores: (min: 8, avg: 37.56, max: 500)
#
# Run: 202, exploration: 0.01, score: 197
# Scores: (min: 8, avg: 39.43, max: 500)
#
# Run: 203, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 44.33, max: 500)
#
# Run: 204, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 46.21, max: 500)
#
# Run: 205, exploration: 0.01, score: 360
# Scores: (min: 8, avg: 49.73, max: 500)
#
# Run: 206, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 49.86, max: 500)
#
# Run: 207, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 49.88, max: 500)
#
# Run: 208, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 49.88, max: 500)
#
# Run: 209, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 49.86, max: 500)
#
# Run: 210, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 49.86, max: 500)
#
# Run: 211, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 49.89, max: 500)
#
# Run: 212, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 49.9, max: 500)
#
# Run: 213, exploration: 0.01, score: 243
# Scores: (min: 8, avg: 52.24, max: 500)
#
# Run: 214, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 53.47, max: 500)
#
# Run: 215, exploration: 0.01, score: 118
# Scores: (min: 8, avg: 54.55, max: 500)
#
# Run: 216, exploration: 0.01, score: 358
# Scores: (min: 8, avg: 58.03, max: 500)
#
# Run: 217, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 59.25, max: 500)
#
# Run: 218, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 60.68, max: 500)
#
# Run: 219, exploration: 0.01, score: 136
# Scores: (min: 8, avg: 61.91, max: 500)
#
# Run: 220, exploration: 0.01, score: 115
# Scores: (min: 8, avg: 62.88, max: 500)
#
# Run: 221, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 64.33, max: 500)
#
# Run: 222, exploration: 0.01, score: 159
# Scores: (min: 8, avg: 65.83, max: 500)
#
# Run: 223, exploration: 0.01, score: 113
# Scores: (min: 8, avg: 66.85, max: 500)
#
# Run: 224, exploration: 0.01, score: 129
# Scores: (min: 8, avg: 68.04, max: 500)
#
# Run: 225, exploration: 0.01, score: 130
# Scores: (min: 8, avg: 69.23, max: 500)
#
# Run: 226, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 70.56, max: 500)
#
# Run: 227, exploration: 0.01, score: 159
# Scores: (min: 8, avg: 72.05, max: 500)
#
# Run: 228, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 73.63, max: 500)
#
# Run: 229, exploration: 0.01, score: 159
# Scores: (min: 8, avg: 75.12, max: 500)
#
# Run: 230, exploration: 0.01, score: 219
# Scores: (min: 8, avg: 77.21, max: 500)
#
# Run: 231, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 77.21, max: 500)
#
# Run: 232, exploration: 0.01, score: 81
# Scores: (min: 8, avg: 77.94, max: 500)
#
# Run: 233, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 77.93, max: 500)
#
# Run: 234, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 77.93, max: 500)
#
# Run: 235, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 77.92, max: 500)
#
# Run: 236, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 77.94, max: 500)
#
# Run: 237, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 77.93, max: 500)
#
# Run: 238, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 77.93, max: 500)
#
# Run: 239, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 77.93, max: 500)
#
# Run: 240, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 77.92, max: 500)
#
# Run: 241, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 77.93, max: 500)
#
# Run: 242, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 77.94, max: 500)
#
# Run: 243, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 77.95, max: 500)
#
# Run: 244, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 77.93, max: 500)
#
# Run: 245, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 77.92, max: 500)
#
# Run: 246, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 77.93, max: 500)
#
# Run: 247, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 77.93, max: 500)
#
# Run: 248, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 77.93, max: 500)
#
# Run: 249, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 77.97, max: 500)
#
# Run: 250, exploration: 0.01, score: 125
# Scores: (min: 8, avg: 79.12, max: 500)
#
# Run: 251, exploration: 0.01, score: 234
# Scores: (min: 8, avg: 81.37, max: 500)
#
# Run: 252, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 82.66, max: 500)
#
# Run: 253, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 87.57, max: 500)
#
# Run: 254, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 89.04, max: 500)
#
# Run: 255, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 90.7, max: 500)
#
# Run: 256, exploration: 0.01, score: 275
# Scores: (min: 8, avg: 93.35, max: 500)
#
# Run: 257, exploration: 0.01, score: 333
# Scores: (min: 8, avg: 96.59, max: 500)
#
# Run: 258, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 98.09, max: 500)
#
# Run: 259, exploration: 0.01, score: 309
# Scores: (min: 8, avg: 101.09, max: 500)
#
# Run: 260, exploration: 0.01, score: 131
# Scores: (min: 8, avg: 102.32, max: 500)
#
# Run: 261, exploration: 0.01, score: 165
# Scores: (min: 8, avg: 103.88, max: 500)
#
# Run: 262, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 105.5, max: 500)
#
# Run: 263, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 107, max: 500)
#
# Run: 264, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 108.88, max: 500)
#
# Run: 265, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 110.36, max: 500)
#
# Run: 266, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 111.92, max: 500)
#
# Run: 267, exploration: 0.01, score: 131
# Scores: (min: 8, avg: 113.13, max: 500)
#
# Run: 268, exploration: 0.01, score: 158
# Scores: (min: 8, avg: 114.63, max: 500)
#
# Run: 269, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 115.97, max: 500)
#
# Run: 270, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 117.32, max: 500)
#
# Run: 271, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 117.34, max: 500)
#
# Run: 272, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 117.35, max: 500)
#
# Run: 273, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 117.34, max: 500)
#
# Run: 274, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 117.34, max: 500)
#
# Run: 275, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 117.34, max: 500)
#
# Run: 276, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 117.33, max: 500)
#
# Run: 277, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 117.34, max: 500)
#
# Run: 278, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 117.35, max: 500)
#
# Run: 279, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 117.34, max: 500)
#
# Run: 280, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 117.33, max: 500)
#
# Run: 281, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 117.34, max: 500)
#
# Run: 282, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 117.33, max: 500)
#
# Run: 283, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 117.33, max: 500)
#
# Run: 284, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 117.3, max: 500)
#
# Run: 285, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 117.23, max: 500)
#
# Run: 286, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 117.2, max: 500)
#
# Run: 287, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 117.17, max: 500)
#
# Run: 288, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 116.86, max: 500)
#
# Run: 289, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 116.77, max: 500)
#
# Run: 290, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 115.92, max: 500)
#
# Run: 291, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 114.83, max: 500)
# Run: 292, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 110.65, max: 500)
#
# Run: 293, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 108.71, max: 500)
#
# Run: 294, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 105.26, max: 500)
#
# Run: 295, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 103.7, max: 500)
#
# Run: 296, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 102.24, max: 500)
#
# Run: 297, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 100.24, max: 500)
#
# Run: 298, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 98.12, max: 500)
#
# Run: 299, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 96.03, max: 500)
#
# Run: 300, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 91.13, max: 500)
#
# Run: 301, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 89.53, max: 500)
#
# Run: 302, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 87.64, max: 500)
#
# Run: 303, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 82.74, max: 500)
#
# Run: 304, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 80.86, max: 500)
#
# Run: 305, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 77.37, max: 500)
#
# Run: 306, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 77.24, max: 500)
#
# Run: 307, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 77.23, max: 500)
#
# Run: 308, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 77.23, max: 500)
#
# Run: 309, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 77.24, max: 500)
#
# Run: 310, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 77.23, max: 500)
#
# Run: 311, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 77.22, max: 500)
#
# Run: 312, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 77.21, max: 500)
#
# Run: 313, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 74.87, max: 500)
#
# Run: 314, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 73.63, max: 500)
#
# Run: 315, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 72.55, max: 500)
#
# Run: 316, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 69.06, max: 500)
#
# Run: 317, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 67.69, max: 500)
#
# Run: 318, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 66.23, max: 500)
#
# Run: 319, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 64.97, max: 500)
#
# Run: 320, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 63.91, max: 500)
#
# Run: 321, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 62.45, max: 500)
#
# Run: 322, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 60.96, max: 500)
#
# Run: 323, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 59.92, max: 500)
#
# Run: 324, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 58.72, max: 500)
#
# Run: 325, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 57.52, max: 500)
#
# Run: 326, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 56.19, max: 500)
#
# Run: 327, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 54.7, max: 500)
#
# Run: 328, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 53.13, max: 500)
#
# Run: 329, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 51.64, max: 500)
#
# Run: 330, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 49.55, max: 500)
#
# Run: 331, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 49.56, max: 500)
#
# Run: 332, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 48.84, max: 500)
#
# Run: 333, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 48.84, max: 500)
#
# Run: 334, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 48.84, max: 500)
#
# Run: 335, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 48.85, max: 500)
#
# Run: 336, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 48.83, max: 500)
#
# Run: 337, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 48.85, max: 500)
#
# Run: 338, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 48.86, max: 500)
#
# Run: 339, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 48.84, max: 500)
#
# Run: 340, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 48.84, max: 500)
#
# Run: 341, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 48.83, max: 500)
#
# Run: 342, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 48.93, max: 500)
#
# Run: 343, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 50.3, max: 500)
#
# Run: 344, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 50.34, max: 500)
#
# Run: 345, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 50.37, max: 500)
#
# Run: 346, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 50.39, max: 500)
#
# Run: 347, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 50.41, max: 500)
#
# Run: 348, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 50.43, max: 500)
#
# Run: 349, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 50.41, max: 500)
#
# Run: 350, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 49.28, max: 500)
#
# Run: 351, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 47.04, max: 500)
#
# Run: 352, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 45.75, max: 500)
#
# Run: 353, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 40.84, max: 333)
#
# Run: 354, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 39.36, max: 333)
#
# Run: 355, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 37.69, max: 333)
#
# Run: 356, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 35.06, max: 333)
#
# Run: 357, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.83, max: 309)
#
# Run: 358, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 30.34, max: 309)
#
# Run: 359, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 27.35, max: 198)
#
# Run: 360, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.13, max: 198)
#
# Run: 361, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 24.62, max: 198)
#
# Run: 362, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23, max: 198)
#
# Run: 363, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 21.49, max: 198)
#
# Run: 364, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.61, max: 164)
#
# Run: 365, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.15, max: 164)
#
# Run: 366, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 16.6, max: 158)
#
# Run: 367, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.39, max: 158)
#
# Run: 368, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 13.89, max: 147)
#
# Run: 369, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 12.6, max: 147)
#
# Run: 370, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.3, max: 147)
#
# Run: 371, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.37, max: 147)
#
# Run: 372, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.43, max: 147)
#
# Run: 373, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.51, max: 147)
#
# Run: 374, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.57, max: 147)
#
# Run: 375, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 11.66, max: 147)
#
# Run: 376, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 11.7, max: 147)
#
# Run: 377, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.71, max: 147)
#
# Run: 378, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 11.75, max: 147)
#
# Run: 379, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 11.89, max: 147)
#
# Run: 380, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 12.14, max: 147)
#
# Run: 381, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 12.33, max: 147)
#
# Run: 382, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 12.85, max: 147)
#
# Run: 383, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 13.27, max: 147)
#
# Run: 384, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 13.81, max: 147)
#
# Run: 385, exploration: 0.01, score: 120
# Scores: (min: 8, avg: 14.92, max: 147)
#
# Run: 386, exploration: 0.01, score: 217
# Scores: (min: 8, avg: 16.99, max: 217)
#
# Run: 387, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 17.45, max: 217)
#
# Run: 388, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 17.74, max: 217)
#
# Run: 389, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 18.03, max: 217)
#
# Run: 390, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 18.68, max: 217)
#
# Run: 391, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 19.26, max: 217)
#
# Run: 392, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 19.63, max: 217)
#
# Run: 393, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 20.08, max: 217)
#
# Run: 394, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 20.27, max: 217)
#
# Run: 395, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 20.9, max: 217)
#
# Run: 396, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 22.53, max: 217)
# Run: 397, exploration: 0.01, score: 103
# Scores: (min: 8, avg: 23.46, max: 217)
#
# Run: 398, exploration: 0.01, score: 124
# Scores: (min: 8, avg: 24.61, max: 217)
#
# Run: 399, exploration: 0.01, score: 92
# Scores: (min: 8, avg: 25.44, max: 217)
#
# Run: 400, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 26.56, max: 217)
#
# Run: 401, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 27.94, max: 217)
#
# Run: 402, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 29.19, max: 217)
#
# Run: 403, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 30.37, max: 217)
#
# Run: 404, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 31.65, max: 217)
#
# Run: 405, exploration: 0.01, score: 261
# Scores: (min: 8, avg: 34.15, max: 261)
#
# Run: 406, exploration: 0.01, score: 225
# Scores: (min: 8, avg: 36.31, max: 261)
#
# Run: 407, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 38.1, max: 261)
#
# Run: 408, exploration: 0.01, score: 310
# Scores: (min: 8, avg: 41.1, max: 310)
#
# Run: 409, exploration: 0.01, score: 424
# Scores: (min: 8, avg: 45.25, max: 424)
#
# Run: 410, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 46.43, max: 424)
#
# Run: 411, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 47.99, max: 424)
#
# Run: 412, exploration: 0.01, score: 154
# Scores: (min: 8, avg: 49.44, max: 424)
#
# Run: 413, exploration: 0.01, score: 219
# Scores: (min: 8, avg: 51.54, max: 424)
#
# Run: 414, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 52.68, max: 424)
#
# Run: 415, exploration: 0.01, score: 92
# Scores: (min: 8, avg: 53.5, max: 424)
#
# Run: 416, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 53.55, max: 424)
#
# Run: 417, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 53.54, max: 424)
#
# Run: 418, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 53.53, max: 424)
#
# Run: 419, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 53.53, max: 424)
#
# Run: 420, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 53.53, max: 424)
#
# Run: 421, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 53.53, max: 424)
#
# Run: 422, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 53.52, max: 424)
#
# Run: 423, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 53.52, max: 424)
#
# Run: 424, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 53.53, max: 424)
#
# Run: 425, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 53.53, max: 424)
#
# Run: 426, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 53.53, max: 424)
#
# Run: 427, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 53.53, max: 424)
#
# Run: 428, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 53.53, max: 424)
#
# Run: 429, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 53.53, max: 424)
#
# Run: 430, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 53.51, max: 424)
#
# Run: 431, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 53.5, max: 424)
#
# Run: 432, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 53.51, max: 424)
#
# Run: 433, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 53.52, max: 424)
#
# Run: 434, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 53.52, max: 424)
#
# Run: 435, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 53.52, max: 424)
#
# Run: 436, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 53.53, max: 424)
#
# Run: 437, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 53.5, max: 424)
#
# Run: 438, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 53.51, max: 424)
#
# Run: 439, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 53.52, max: 424)
#
# Run: 440, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 53.51, max: 424)
#
# Run: 441, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 53.52, max: 424)
#
# Run: 442, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 53.42, max: 424)
#
# Run: 443, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 52.04, max: 424)
#
# Run: 444, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 52, max: 424)
#
# Run: 445, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 51.97, max: 424)
#
# Run: 446, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 51.96, max: 424)
#
# Run: 447, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 51.92, max: 424)
#
# Run: 448, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 51.91, max: 424)
#
# Run: 449, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 51.88, max: 424)
#
# Run: 450, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 51.86, max: 424)
#
# Run: 451, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 51.85, max: 424)
#
# Run: 452, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 51.85, max: 424)
#
# Run: 453, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 51.86, max: 424)
#
# Run: 454, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 51.89, max: 424)
#
# Run: 455, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 51.9, max: 424)
#
# Run: 456, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 51.86, max: 424)
#
# Run: 457, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 51.84, max: 424)
#
# Run: 458, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 51.84, max: 424)
#
# Run: 459, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 51.84, max: 424)
#
# Run: 460, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 51.84, max: 424)
#
# Run: 461, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 51.79, max: 424)
#
# Run: 462, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 51.8, max: 424)
#
# Run: 463, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 51.79, max: 424)
#
# Run: 464, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 51.78, max: 424)
#
# Run: 465, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 51.8, max: 424)
#
# Run: 466, exploration: 0.01, score: 98
# Scores: (min: 8, avg: 52.69, max: 424)
#
# Run: 467, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 53.01, max: 424)
#
# Run: 468, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 53.21, max: 424)
#
# Run: 469, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 53.2, max: 424)
#
# Run: 470, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 53.19, max: 424)
#
# Run: 471, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 53.14, max: 424)
#
# Run: 472, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 53.09, max: 424)
#
# Run: 473, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 53.02, max: 424)
#
# Run: 474, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 52.95, max: 424)
#
# Run: 475, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 52.87, max: 424)
#
# Run: 476, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 52.83, max: 424)
#
# Run: 477, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 52.82, max: 424)
#
# Run: 478, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 52.77, max: 424)
#
# Run: 479, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 52.64, max: 424)
#
# Run: 480, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 52.39, max: 424)
#
# Run: 481, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 52.19, max: 424)
#
# Run: 482, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 51.69, max: 424)
#
# Run: 483, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 51.29, max: 424)
#
# Run: 484, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 50.74, max: 424)
#
# Run: 485, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 49.63, max: 424)
#
# Run: 486, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 47.56, max: 424)
#
# Run: 487, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 47.11, max: 424)
#
# Run: 488, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 46.82, max: 424)
#
# Run: 489, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 46.53, max: 424)
#
# Run: 490, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 45.88, max: 424)
#
# Run: 491, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 45.31, max: 424)
#
# Run: 492, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 44.92, max: 424)
#
# Run: 493, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 44.48, max: 424)
#
# Run: 494, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 44.28, max: 424)
#
# Run: 495, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 43.65, max: 424)
#
# Run: 496, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 42, max: 424)
#
# Run: 497, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 41.07, max: 424)
#
# Run: 498, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 39.93, max: 424)
#
# Run: 499, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 39.11, max: 424)
#
# Run: 500, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 37.98, max: 424)
#
# Run: 501, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 36.61, max: 424)
# Run: 502, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 35.37, max: 424)
#
# Run: 503, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 34.18, max: 424)
#
# Run: 504, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 32.89, max: 424)
#
# Run: 505, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.38, max: 424)
#
# Run: 506, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.23, max: 424)
#
# Run: 507, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 26.43, max: 424)
#
# Run: 508, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.43, max: 424)
#
# Run: 509, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.28, max: 219)
#
# Run: 510, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 18.09, max: 219)
#
# Run: 511, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 16.51, max: 219)
#
# Run: 512, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.06, max: 219)
#
# Run: 513, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.97, max: 123)
#
# Run: 514, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.86, max: 98)
#
# Run: 515, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.03, max: 98)
#
# Run: 516, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.01, max: 98)
#
# Run: 517, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 11.04, max: 98)
#
# Run: 518, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.1, max: 98)
#
# Run: 519, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 11.16, max: 98)
#
# Run: 520, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 11.25, max: 98)
#
# Run: 521, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 11.36, max: 98)
#
# Run: 522, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.42, max: 98)
#
# Run: 523, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 11.51, max: 98)
#
# Run: 524, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 11.62, max: 98)
#
# Run: 525, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.72, max: 98)
#
# Run: 526, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 11.88, max: 98)
#
# Run: 527, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 11.97, max: 98)
#
# Run: 528, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 12.01, max: 98)
#
# Run: 529, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 12.1, max: 98)
#
# Run: 530, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 12.24, max: 98)
#
# Run: 531, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 12.42, max: 98)
#
# Run: 532, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 12.56, max: 98)
#
# Run: 533, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 12.86, max: 98)
#
# Run: 534, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 13.43, max: 98)
#
# Run: 535, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 13.9, max: 98)
#
# Run: 536, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 14.48, max: 98)
#
# Run: 537, exploration: 0.01, score: 201
# Scores: (min: 8, avg: 16.41, max: 201)
#
# Run: 538, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 16.82, max: 201)
#
# Run: 539, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 17.46, max: 201)
#
# Run: 540, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 18.03, max: 201)
#
# Run: 541, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 18.64, max: 201)
#
# Run: 542, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 19.15, max: 201)
#
# Run: 543, exploration: 0.01, score: 81
# Scores: (min: 8, avg: 19.87, max: 201)
#
# Run: 544, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 20.29, max: 201)
#
# Run: 545, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 20.76, max: 201)
#
# Run: 546, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 21.37, max: 201)
#
# Run: 547, exploration: 0.01, score: 91
# Scores: (min: 8, avg: 22.19, max: 201)
#
# Run: 548, exploration: 0.01, score: 103
# Scores: (min: 8, avg: 23.12, max: 201)
#
# Run: 549, exploration: 0.01, score: 121
# Scores: (min: 8, avg: 24.24, max: 201)
#
# Run: 550, exploration: 0.01, score: 132
# Scores: (min: 8, avg: 25.46, max: 201)
#
# Run: 551, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 26.41, max: 201)
#
# Run: 552, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 27.74, max: 201)
#
# Run: 553, exploration: 0.01, score: 184
# Scores: (min: 8, avg: 29.48, max: 201)
#
# Run: 554, exploration: 0.01, score: 256
# Scores: (min: 8, avg: 31.92, max: 256)
#
# Run: 555, exploration: 0.01, score: 120
# Scores: (min: 8, avg: 33.02, max: 256)
#
# Run: 556, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 33.89, max: 256)
#
# Run: 557, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 35.42, max: 256)
#
# Run: 558, exploration: 0.01, score: 287
# Scores: (min: 8, avg: 38.18, max: 287)
#
# Run: 559, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 38.23, max: 287)
#
# Run: 560, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 38.85, max: 287)
#
# Run: 561, exploration: 0.01, score: 285
# Scores: (min: 8, avg: 41.61, max: 287)
#
# Run: 562, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 43.04, max: 287)
#
# Run: 563, exploration: 0.01, score: 125
# Scores: (min: 8, avg: 44.21, max: 287)
#
# Run: 564, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 44.97, max: 287)
#
# Run: 565, exploration: 0.01, score: 205
# Scores: (min: 8, avg: 46.9, max: 287)
#
# Run: 566, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 46.87, max: 287)
#
# Run: 567, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 47.44, max: 287)
#
# Run: 568, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 48.54, max: 287)
#
# Run: 569, exploration: 0.01, score: 231
# Scores: (min: 8, avg: 50.71, max: 287)
#
# Run: 570, exploration: 0.01, score: 356
# Scores: (min: 8, avg: 54.15, max: 356)
#
# Run: 571, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 56.02, max: 356)
#
# Run: 572, exploration: 0.01, score: 216
# Scores: (min: 8, avg: 58.08, max: 356)
#
# Run: 573, exploration: 0.01, score: 88
# Scores: (min: 8, avg: 58.86, max: 356)
#
# Run: 574, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 59.86, max: 356)
#
# Run: 575, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 61.7, max: 356)
#
# Run: 576, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 62.69, max: 356)
#
# Run: 577, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 64.04, max: 356)
#
# Run: 578, exploration: 0.01, score: 118
# Scores: (min: 8, avg: 65.13, max: 356)
#
# Run: 579, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 65.45, max: 356)
#
# Run: 580, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 67.03, max: 356)
#
# Run: 581, exploration: 0.01, score: 329
# Scores: (min: 8, avg: 70.23, max: 356)
#
# Run: 582, exploration: 0.01, score: 170
# Scores: (min: 8, avg: 71.83, max: 356)
#
# Run: 583, exploration: 0.01, score: 120
# Scores: (min: 8, avg: 72.92, max: 356)
#
# Run: 584, exploration: 0.01, score: 120
# Scores: (min: 8, avg: 74.04, max: 356)
#
# Run: 585, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 74.66, max: 356)
#
# Run: 586, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 75.46, max: 356)
#
# Run: 587, exploration: 0.01, score: 125
# Scores: (min: 8, avg: 76.61, max: 356)
#
# Run: 588, exploration: 0.01, score: 239
# Scores: (min: 8, avg: 78.9, max: 356)
#
# Run: 589, exploration: 0.01, score: 116
# Scores: (min: 8, avg: 79.97, max: 356)
#
# Run: 590, exploration: 0.01, score: 81
# Scores: (min: 8, avg: 80.68, max: 356)
#
# Run: 591, exploration: 0.01, score: 333
# Scores: (min: 8, avg: 83.91, max: 356)
#
# Run: 592, exploration: 0.01, score: 300
# Scores: (min: 8, avg: 86.83, max: 356)
#
# Run: 593, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 87.99, max: 356)
#
# Run: 594, exploration: 0.01, score: 310
# Scores: (min: 8, avg: 91, max: 356)
#
# Run: 595, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 92.75, max: 356)
#
# Run: 596, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 94.3, max: 356)
#
# Run: 597, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 95.67, max: 356)
#
# Run: 598, exploration: 0.01, score: 100
# Scores: (min: 8, avg: 96.57, max: 356)
#
# Run: 599, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 97.75, max: 356)
#
# Run: 600, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 98.83, max: 356)
#
# Run: 601, exploration: 0.01, score: 158
# Scores: (min: 8, avg: 100.31, max: 356)
#
# Run: 602, exploration: 0.01, score: 233
# Scores: (min: 8, avg: 102.55, max: 356)
#
# Run: 603, exploration: 0.01, score: 294
# Scores: (min: 8, avg: 105.4, max: 356)
#
# Run: 604, exploration: 0.01, score: 125
# Scores: (min: 8, avg: 106.56, max: 356)
#
# Run: 605, exploration: 0.01, score: 127
# Scores: (min: 8, avg: 107.73, max: 356)
# Run: 606, exploration: 0.01, score: 258
# Scores: (min: 8, avg: 110.21, max: 356)
#
# Run: 607, exploration: 0.01, score: 96
# Scores: (min: 8, avg: 111.08, max: 356)
#
# Run: 608, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 112.76, max: 356)
#
# Run: 609, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 114.69, max: 356)
#
# Run: 610, exploration: 0.01, score: 292
# Scores: (min: 8, avg: 117.53, max: 356)
#
# Run: 611, exploration: 0.01, score: 262
# Scores: (min: 9, avg: 120.07, max: 356)
#
# Run: 612, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 121.15, max: 356)
#
# Run: 613, exploration: 0.01, score: 232
# Scores: (min: 9, avg: 123.37, max: 356)
#
# Run: 614, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 124.88, max: 356)
#
# Run: 615, exploration: 0.01, score: 138
# Scores: (min: 12, avg: 126.17, max: 356)
#
# Run: 616, exploration: 0.01, score: 161
# Scores: (min: 12, avg: 127.66, max: 356)
#
# Run: 617, exploration: 0.01, score: 301
# Scores: (min: 14, avg: 130.55, max: 356)
#
# Run: 618, exploration: 0.01, score: 113
# Scores: (min: 14, avg: 131.53, max: 356)
#
# Run: 619, exploration: 0.01, score: 272
# Scores: (min: 14, avg: 134.09, max: 356)
#
# Run: 620, exploration: 0.01, score: 107
# Scores: (min: 14, avg: 134.98, max: 356)
#
# Run: 621, exploration: 0.01, score: 134
# Scores: (min: 14, avg: 136.11, max: 356)
#
# Run: 622, exploration: 0.01, score: 228
# Scores: (min: 14, avg: 138.24, max: 356)

# %%
GAMMA = 0.5

cartpole()
# Out:
# Run: 1, exploration: 0.9275689688183278, score: 35
# Scores: (min: 35, avg: 35, max: 35)
#
# Run: 2, exploration: 0.8603841919146962, score: 16
# Scores: (min: 16, avg: 25.5, max: 35)
#
# Run: 3, exploration: 0.7861544476842928, score: 19
# Scores: (min: 16, avg: 23.333333333333332, max: 35)
#
# Run: 4, exploration: 0.7292124703704616, score: 16
# Scores: (min: 16, avg: 21.5, max: 35)
#
# Run: 5, exploration: 0.6866430931872001, score: 13
# Scores: (min: 13, avg: 19.8, max: 35)
#
# Run: 6, exploration: 0.6433260027715241, score: 14
# Scores: (min: 13, avg: 18.833333333333332, max: 35)
#
# Run: 7, exploration: 0.5535075230322891, score: 31
# Scores: (min: 13, avg: 20.571428571428573, max: 35)
#
# Run: 8, exploration: 0.510849320360386, score: 17
# Scores: (min: 13, avg: 20.125, max: 35)
#
# Run: 9, exploration: 0.4159480862733536, score: 42
# Scores: (min: 13, avg: 22.555555555555557, max: 42)
#
# Run: 10, exploration: 0.37627099809304654, score: 21
# Scores: (min: 13, avg: 22.4, max: 42)
#
# Run: 11, exploration: 0.3455358541129786, score: 18
# Scores: (min: 13, avg: 22, max: 42)
#
# Run: 12, exploration: 0.322118930542046, score: 15
# Scores: (min: 13, avg: 21.416666666666668, max: 42)
#
# Run: 13, exploration: 0.2987875242397482, score: 16
# Scores: (min: 13, avg: 21, max: 42)
#
# Run: 14, exploration: 0.27853872940185365, score: 15
# Scores: (min: 13, avg: 20.571428571428573, max: 42)
#
# Run: 15, exploration: 0.2507092085103961, score: 22
# Scores: (min: 13, avg: 20.666666666666668, max: 42)
#
# Run: 16, exploration: 0.20931540516921554, score: 37
# Scores: (min: 13, avg: 21.6875, max: 42)
#
# Run: 17, exploration: 0.1912566947289212, score: 19
# Scores: (min: 13, avg: 21.529411764705884, max: 42)
#
# Run: 18, exploration: 0.15650920157696743, score: 41
# Scores: (min: 13, avg: 22.61111111111111, max: 42)
#
# Run: 19, exploration: 0.13331482894782642, score: 33
# Scores: (min: 13, avg: 23.157894736842106, max: 42)
#
# Run: 20, exploration: 0.11820406108847166, score: 25
# Scores: (min: 13, avg: 23.25, max: 42)
#
# Run: 21, exploration: 0.052214913061211746, score: 164
# Scores: (min: 13, avg: 29.952380952380953, max: 164)
#
# Run: 22, exploration: 0.027350922279685573, score: 130
# Scores: (min: 13, avg: 34.5, max: 164)
#
# Run: 23, exploration: 0.015917127532080494, score: 109
# Scores: (min: 13, avg: 37.73913043478261, max: 164)
#
# Run: 24, exploration: 0.011606967888870102, score: 64
# Scores: (min: 13, avg: 38.833333333333336, max: 164)
#
# Run: 25, exploration: 0.01, score: 244
# Scores: (min: 13, avg: 47.04, max: 244)
#
# Run: 26, exploration: 0.01, score: 49
# Scores: (min: 13, avg: 47.11538461538461, max: 244)
#
# Run: 27, exploration: 0.01, score: 122
# Scores: (min: 13, avg: 49.888888888888886, max: 244)
#
# Run: 28, exploration: 0.01, score: 37
# Scores: (min: 13, avg: 49.42857142857143, max: 244)
#
# Run: 29, exploration: 0.01, score: 28
# Scores: (min: 13, avg: 48.689655172413794, max: 244)
#
# Run: 30, exploration: 0.01, score: 30
# Scores: (min: 13, avg: 48.06666666666667, max: 244)
#
# Run: 31, exploration: 0.01, score: 36
# Scores: (min: 13, avg: 47.67741935483871, max: 244)
#
# Run: 32, exploration: 0.01, score: 58
# Scores: (min: 13, avg: 48, max: 244)
#
# Run: 33, exploration: 0.01, score: 40
# Scores: (min: 13, avg: 47.75757575757576, max: 244)
#
# Run: 34, exploration: 0.01, score: 92
# Scores: (min: 13, avg: 49.05882352941177, max: 244)
#
# Run: 35, exploration: 0.01, score: 153
# Scores: (min: 13, avg: 52.02857142857143, max: 244)
#
# Run: 36, exploration: 0.01, score: 168
# Scores: (min: 13, avg: 55.25, max: 244)
#
# Run: 37, exploration: 0.01, score: 53
# Scores: (min: 13, avg: 55.189189189189186, max: 244)
#
# Run: 38, exploration: 0.01, score: 46
# Scores: (min: 13, avg: 54.94736842105263, max: 244)
#
# Run: 39, exploration: 0.01, score: 156
# Scores: (min: 13, avg: 57.53846153846154, max: 244)
#
# Run: 40, exploration: 0.01, score: 55
# Scores: (min: 13, avg: 57.475, max: 244)
#
# Run: 41, exploration: 0.01, score: 167
# Scores: (min: 13, avg: 60.146341463414636, max: 244)
#
# Run: 42, exploration: 0.01, score: 153
# Scores: (min: 13, avg: 62.357142857142854, max: 244)
#
# Run: 43, exploration: 0.01, score: 155
# Scores: (min: 13, avg: 64.51162790697674, max: 244)
#
# Run: 44, exploration: 0.01, score: 117
# Scores: (min: 13, avg: 65.70454545454545, max: 244)
#
# Run: 45, exploration: 0.01, score: 105
# Scores: (min: 13, avg: 66.57777777777778, max: 244)
#
# Run: 46, exploration: 0.01, score: 31
# Scores: (min: 13, avg: 65.80434782608695, max: 244)
#
# Run: 47, exploration: 0.01, score: 29
# Scores: (min: 13, avg: 65.02127659574468, max: 244)
#
# Run: 48, exploration: 0.01, score: 18
# Scores: (min: 13, avg: 64.04166666666667, max: 244)
#
# Run: 49, exploration: 0.01, score: 191
# Scores: (min: 13, avg: 66.63265306122449, max: 244)
#
# Run: 50, exploration: 0.01, score: 109
# Scores: (min: 13, avg: 67.48, max: 244)
#
# Run: 51, exploration: 0.01, score: 48
# Scores: (min: 13, avg: 67.09803921568627, max: 244)
#
# Run: 52, exploration: 0.01, score: 80
# Scores: (min: 13, avg: 67.34615384615384, max: 244)
#
# Run: 53, exploration: 0.01, score: 53
# Scores: (min: 13, avg: 67.0754716981132, max: 244)
#
# Run: 54, exploration: 0.01, score: 21
# Scores: (min: 13, avg: 66.22222222222223, max: 244)
#
# Run: 55, exploration: 0.01, score: 213
# Scores: (min: 13, avg: 68.89090909090909, max: 244)
#
# Run: 56, exploration: 0.01, score: 101
# Scores: (min: 13, avg: 69.46428571428571, max: 244)
#
# Run: 57, exploration: 0.01, score: 105
# Scores: (min: 13, avg: 70.08771929824562, max: 244)
#
# Run: 58, exploration: 0.01, score: 214
# Scores: (min: 13, avg: 72.56896551724138, max: 244)
#
# Run: 59, exploration: 0.01, score: 68
# Scores: (min: 13, avg: 72.49152542372882, max: 244)
#
# Run: 60, exploration: 0.01, score: 114
# Scores: (min: 13, avg: 73.18333333333334, max: 244)
#
# Run: 61, exploration: 0.01, score: 15
# Scores: (min: 13, avg: 72.22950819672131, max: 244)
#
# Run: 62, exploration: 0.01, score: 52
# Scores: (min: 13, avg: 71.90322580645162, max: 244)
#
# Run: 63, exploration: 0.01, score: 49
# Scores: (min: 13, avg: 71.53968253968254, max: 244)
#
# Run: 64, exploration: 0.01, score: 144
# Scores: (min: 13, avg: 72.671875, max: 244)
#
# Run: 65, exploration: 0.01, score: 52
# Scores: (min: 13, avg: 72.35384615384615, max: 244)
#
# Run: 66, exploration: 0.01, score: 131
# Scores: (min: 13, avg: 73.24242424242425, max: 244)
#
# Run: 67, exploration: 0.01, score: 68
# Scores: (min: 13, avg: 73.16417910447761, max: 244)
#
# Run: 68, exploration: 0.01, score: 64
# Scores: (min: 13, avg: 73.02941176470588, max: 244)
#
# Run: 69, exploration: 0.01, score: 39
# Scores: (min: 13, avg: 72.53623188405797, max: 244)
#
# Run: 70, exploration: 0.01, score: 67
# Scores: (min: 13, avg: 72.45714285714286, max: 244)
#
# Run: 71, exploration: 0.01, score: 85
# Scores: (min: 13, avg: 72.63380281690141, max: 244)
#
# Run: 72, exploration: 0.01, score: 111
# Scores: (min: 13, avg: 73.16666666666667, max: 244)
#
# Run: 73, exploration: 0.01, score: 486
# Scores: (min: 13, avg: 78.82191780821918, max: 486)
#
# Run: 74, exploration: 0.01, score: 159
# Scores: (min: 13, avg: 79.9054054054054, max: 486)
#
# Run: 75, exploration: 0.01, score: 67
# Scores: (min: 13, avg: 79.73333333333333, max: 486)
#
# Run: 76, exploration: 0.01, score: 258
# Scores: (min: 13, avg: 82.07894736842105, max: 486)
#
# Run: 77, exploration: 0.01, score: 147
# Scores: (min: 13, avg: 82.92207792207792, max: 486)
#
# Run: 78, exploration: 0.01, score: 174
# Scores: (min: 13, avg: 84.08974358974359, max: 486)
#
# Run: 79, exploration: 0.01, score: 32
# Scores: (min: 13, avg: 83.43037974683544, max: 486)
#
# Run: 80, exploration: 0.01, score: 30
# Scores: (min: 13, avg: 82.7625, max: 486)
#
# Run: 81, exploration: 0.01, score: 15
# Scores: (min: 13, avg: 81.92592592592592, max: 486)
#
# Run: 82, exploration: 0.01, score: 134
# Scores: (min: 13, avg: 82.5609756097561, max: 486)
#
# Run: 83, exploration: 0.01, score: 46
# Scores: (min: 13, avg: 82.12048192771084, max: 486)
#
# Run: 84, exploration: 0.01, score: 362
# Scores: (min: 13, avg: 85.45238095238095, max: 486)
#
# Run: 85, exploration: 0.01, score: 63
# Scores: (min: 13, avg: 85.18823529411765, max: 486)
#
# Run: 86, exploration: 0.01, score: 65
# Scores: (min: 13, avg: 84.95348837209302, max: 486)
#
# Run: 87, exploration: 0.01, score: 145
# Scores: (min: 13, avg: 85.64367816091954, max: 486)
#
# Run: 88, exploration: 0.01, score: 173
# Scores: (min: 13, avg: 86.63636363636364, max: 486)
#
# Run: 89, exploration: 0.01, score: 84
# Scores: (min: 13, avg: 86.6067415730337, max: 486)
# Run: 90, exploration: 0.01, score: 34
# Scores: (min: 13, avg: 86.02222222222223, max: 486)
#
# Run: 91, exploration: 0.01, score: 53
# Scores: (min: 13, avg: 85.65934065934066, max: 486)
#
# Run: 92, exploration: 0.01, score: 122
# Scores: (min: 13, avg: 86.05434782608695, max: 486)
#
# Run: 93, exploration: 0.01, score: 189
# Scores: (min: 13, avg: 87.16129032258064, max: 486)
#
# Run: 94, exploration: 0.01, score: 22
# Scores: (min: 13, avg: 86.46808510638297, max: 486)
#
# Run: 95, exploration: 0.01, score: 19
# Scores: (min: 13, avg: 85.7578947368421, max: 486)
#
# Run: 96, exploration: 0.01, score: 41
# Scores: (min: 13, avg: 85.29166666666667, max: 486)
#
# Run: 97, exploration: 0.01, score: 61
# Scores: (min: 13, avg: 85.04123711340206, max: 486)
#
# Run: 98, exploration: 0.01, score: 15
# Scores: (min: 13, avg: 84.3265306122449, max: 486)
#
# Run: 99, exploration: 0.01, score: 42
# Scores: (min: 13, avg: 83.8989898989899, max: 486)
#
# Run: 100, exploration: 0.01, score: 38
# Scores: (min: 13, avg: 83.44, max: 486)
#
# Run: 101, exploration: 0.01, score: 89
# Scores: (min: 13, avg: 83.98, max: 486)
#
# Run: 102, exploration: 0.01, score: 21
# Scores: (min: 13, avg: 84.03, max: 486)
#
# Run: 103, exploration: 0.01, score: 48
# Scores: (min: 13, avg: 84.32, max: 486)
#
# Run: 104, exploration: 0.01, score: 61
# Scores: (min: 13, avg: 84.77, max: 486)
#
# Run: 105, exploration: 0.01, score: 24
# Scores: (min: 14, avg: 84.88, max: 486)
#
# Run: 106, exploration: 0.01, score: 184
# Scores: (min: 15, avg: 86.58, max: 486)
#
# Run: 107, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 86.39, max: 486)
#
# Run: 108, exploration: 0.01, score: 73
# Scores: (min: 12, avg: 86.95, max: 486)
#
# Run: 109, exploration: 0.01, score: 38
# Scores: (min: 12, avg: 86.91, max: 486)
#
# Run: 110, exploration: 0.01, score: 28
# Scores: (min: 12, avg: 86.98, max: 486)
#
# Run: 111, exploration: 0.01, score: 30
# Scores: (min: 12, avg: 87.1, max: 486)
#
# Run: 112, exploration: 0.01, score: 24
# Scores: (min: 12, avg: 87.19, max: 486)
#
# Run: 113, exploration: 0.01, score: 74
# Scores: (min: 12, avg: 87.77, max: 486)
#
# Run: 114, exploration: 0.01, score: 69
# Scores: (min: 12, avg: 88.31, max: 486)
#
# Run: 115, exploration: 0.01, score: 39
# Scores: (min: 12, avg: 88.48, max: 486)
#
# Run: 116, exploration: 0.01, score: 87
# Scores: (min: 12, avg: 88.98, max: 486)
#
# Run: 117, exploration: 0.01, score: 191
# Scores: (min: 12, avg: 90.7, max: 486)
#
# Run: 118, exploration: 0.01, score: 25
# Scores: (min: 12, avg: 90.54, max: 486)
#
# Run: 119, exploration: 0.01, score: 46
# Scores: (min: 12, avg: 90.67, max: 486)
#
# Run: 120, exploration: 0.01, score: 33
# Scores: (min: 12, avg: 90.75, max: 486)
#
# Run: 121, exploration: 0.01, score: 57
# Scores: (min: 12, avg: 89.68, max: 486)
#
# Run: 122, exploration: 0.01, score: 73
# Scores: (min: 12, avg: 89.11, max: 486)
#
# Run: 123, exploration: 0.01, score: 55
# Scores: (min: 12, avg: 88.57, max: 486)
#
# Run: 124, exploration: 0.01, score: 52
# Scores: (min: 12, avg: 88.45, max: 486)
#
# Run: 125, exploration: 0.01, score: 47
# Scores: (min: 12, avg: 86.48, max: 486)
#
# Run: 126, exploration: 0.01, score: 105
# Scores: (min: 12, avg: 87.04, max: 486)
#
# Run: 127, exploration: 0.01, score: 31
# Scores: (min: 12, avg: 86.13, max: 486)
#
# Run: 128, exploration: 0.01, score: 28
# Scores: (min: 12, avg: 86.04, max: 486)
#
# Run: 129, exploration: 0.01, score: 55
# Scores: (min: 12, avg: 86.31, max: 486)
#
# Run: 130, exploration: 0.01, score: 14
# Scores: (min: 12, avg: 86.15, max: 486)
#
# Run: 131, exploration: 0.01, score: 40
# Scores: (min: 12, avg: 86.19, max: 486)
#
# Run: 132, exploration: 0.01, score: 171
# Scores: (min: 12, avg: 87.32, max: 486)
#
# Run: 133, exploration: 0.01, score: 50
# Scores: (min: 12, avg: 87.42, max: 486)
#
# Run: 134, exploration: 0.01, score: 29
# Scores: (min: 12, avg: 86.79, max: 486)
#
# Run: 135, exploration: 0.01, score: 93
# Scores: (min: 12, avg: 86.19, max: 486)
#
# Run: 136, exploration: 0.01, score: 39
# Scores: (min: 12, avg: 84.9, max: 486)
#
# Run: 137, exploration: 0.01, score: 28
# Scores: (min: 12, avg: 84.65, max: 486)
#
# Run: 138, exploration: 0.01, score: 35
# Scores: (min: 12, avg: 84.54, max: 486)
#
# Run: 139, exploration: 0.01, score: 23
# Scores: (min: 12, avg: 83.21, max: 486)
#
# Run: 140, exploration: 0.01, score: 65
# Scores: (min: 12, avg: 83.31, max: 486)
#
# Run: 141, exploration: 0.01, score: 29
# Scores: (min: 12, avg: 81.93, max: 486)
#
# Run: 142, exploration: 0.01, score: 28
# Scores: (min: 12, avg: 80.68, max: 486)
#
# Run: 143, exploration: 0.01, score: 184
# Scores: (min: 12, avg: 80.97, max: 486)
#
# Run: 144, exploration: 0.01, score: 136
# Scores: (min: 12, avg: 81.16, max: 486)
#
# Run: 145, exploration: 0.01, score: 16
# Scores: (min: 12, avg: 80.27, max: 486)
#
# Run: 146, exploration: 0.01, score: 81
# Scores: (min: 12, avg: 80.77, max: 486)
#
# Run: 147, exploration: 0.01, score: 46
# Scores: (min: 12, avg: 80.94, max: 486)
#
# Run: 148, exploration: 0.01, score: 34
# Scores: (min: 12, avg: 81.1, max: 486)
#
# Run: 149, exploration: 0.01, score: 36
# Scores: (min: 12, avg: 79.55, max: 486)
#
# Run: 150, exploration: 0.01, score: 38
# Scores: (min: 12, avg: 78.84, max: 486)
#
# Run: 151, exploration: 0.01, score: 34
# Scores: (min: 12, avg: 78.7, max: 486)
#
# Run: 152, exploration: 0.01, score: 33
# Scores: (min: 12, avg: 78.23, max: 486)
#
# Run: 153, exploration: 0.01, score: 46
# Scores: (min: 12, avg: 78.16, max: 486)
#
# Run: 154, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 78.07, max: 486)
#
# Run: 155, exploration: 0.01, score: 46
# Scores: (min: 12, avg: 76.4, max: 486)
#
# Run: 156, exploration: 0.01, score: 50
# Scores: (min: 12, avg: 75.89, max: 486)
#
# Run: 157, exploration: 0.01, score: 36
# Scores: (min: 12, avg: 75.2, max: 486)
#
# Run: 158, exploration: 0.01, score: 34
# Scores: (min: 12, avg: 73.4, max: 486)
#
# Run: 159, exploration: 0.01, score: 176
# Scores: (min: 12, avg: 74.48, max: 486)
#
# Run: 160, exploration: 0.01, score: 422
# Scores: (min: 12, avg: 77.56, max: 486)
#
# Run: 161, exploration: 0.01, score: 71
# Scores: (min: 12, avg: 78.12, max: 486)
#
# Run: 162, exploration: 0.01, score: 186
# Scores: (min: 12, avg: 79.46, max: 486)
#
# Run: 163, exploration: 0.01, score: 27
# Scores: (min: 12, avg: 79.24, max: 486)
#
# Run: 164, exploration: 0.01, score: 120
# Scores: (min: 12, avg: 79, max: 486)
#
# Run: 165, exploration: 0.01, score: 88
# Scores: (min: 12, avg: 79.36, max: 486)
#
# Run: 166, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 78.16, max: 486)
#
# Run: 167, exploration: 0.01, score: 14
# Scores: (min: 11, avg: 77.62, max: 486)
#
# Run: 168, exploration: 0.01, score: 16
# Scores: (min: 11, avg: 77.14, max: 486)
#
# Run: 169, exploration: 0.01, score: 101
# Scores: (min: 11, avg: 77.76, max: 486)
#
# Run: 170, exploration: 0.01, score: 78
# Scores: (min: 11, avg: 77.87, max: 486)
#
# Run: 171, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 77.13, max: 486)
#
# Run: 172, exploration: 0.01, score: 34
# Scores: (min: 11, avg: 76.36, max: 486)
#
# Run: 173, exploration: 0.01, score: 15
# Scores: (min: 11, avg: 71.65, max: 422)
#
# Run: 174, exploration: 0.01, score: 28
# Scores: (min: 11, avg: 70.34, max: 422)
#
# Run: 175, exploration: 0.01, score: 13
# Scores: (min: 11, avg: 69.8, max: 422)
#
# Run: 176, exploration: 0.01, score: 42
# Scores: (min: 11, avg: 67.64, max: 422)
#
# Run: 177, exploration: 0.01, score: 35
# Scores: (min: 11, avg: 66.52, max: 422)
#
# Run: 178, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 64.9, max: 422)
#
# Run: 179, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 64.68, max: 422)
#
# Run: 180, exploration: 0.01, score: 109
# Scores: (min: 10, avg: 65.47, max: 422)
#
# Run: 181, exploration: 0.01, score: 36
# Scores: (min: 10, avg: 65.68, max: 422)
#
# Run: 182, exploration: 0.01, score: 30
# Scores: (min: 10, avg: 64.64, max: 422)
#
# Run: 183, exploration: 0.01, score: 87
# Scores: (min: 10, avg: 65.05, max: 422)
#
# Run: 184, exploration: 0.01, score: 36
# Scores: (min: 10, avg: 61.79, max: 422)
#
# Run: 185, exploration: 0.01, score: 42
# Scores: (min: 10, avg: 61.58, max: 422)
#
# Run: 186, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 61.07, max: 422)
#
# Run: 187, exploration: 0.01, score: 69
# Scores: (min: 10, avg: 60.31, max: 422)
#
# Run: 188, exploration: 0.01, score: 116
# Scores: (min: 10, avg: 59.74, max: 422)
#
# Run: 189, exploration: 0.01, score: 112
# Scores: (min: 10, avg: 60.02, max: 422)
#
# Run: 190, exploration: 0.01, score: 60
# Scores: (min: 10, avg: 60.28, max: 422)
#
# Run: 191, exploration: 0.01, score: 105
# Scores: (min: 10, avg: 60.8, max: 422)
# Run: 192, exploration: 0.01, score: 67
# Scores: (min: 10, avg: 60.25, max: 422)
#
# Run: 193, exploration: 0.01, score: 116
# Scores: (min: 10, avg: 59.52, max: 422)
#
# Run: 194, exploration: 0.01, score: 84
# Scores: (min: 10, avg: 60.14, max: 422)
#
# Run: 195, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 60.07, max: 422)
#
# Run: 196, exploration: 0.01, score: 122
# Scores: (min: 10, avg: 60.88, max: 422)
#
# Run: 197, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 60.38, max: 422)
#
# Run: 198, exploration: 0.01, score: 44
# Scores: (min: 10, avg: 60.67, max: 422)
#
# Run: 199, exploration: 0.01, score: 40
# Scores: (min: 10, avg: 60.65, max: 422)
#
# Run: 200, exploration: 0.01, score: 64
# Scores: (min: 10, avg: 60.91, max: 422)
#
# Run: 201, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 60.13, max: 422)
#
# Run: 202, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 60.03, max: 422)
#
# Run: 203, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 59.86, max: 422)
#
# Run: 204, exploration: 0.01, score: 110
# Scores: (min: 10, avg: 60.35, max: 422)
#
# Run: 205, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 60.31, max: 422)
#
# Run: 206, exploration: 0.01, score: 88
# Scores: (min: 10, avg: 59.35, max: 422)
#
# Run: 207, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 59.39, max: 422)
#
# Run: 208, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 58.97, max: 422)
#
# Run: 209, exploration: 0.01, score: 125
# Scores: (min: 10, avg: 59.84, max: 422)
#
# Run: 210, exploration: 0.01, score: 42
# Scores: (min: 10, avg: 59.98, max: 422)
#
# Run: 211, exploration: 0.01, score: 19
# Scores: (min: 10, avg: 59.87, max: 422)
#
# Run: 212, exploration: 0.01, score: 107
# Scores: (min: 10, avg: 60.7, max: 422)
#
# Run: 213, exploration: 0.01, score: 84
# Scores: (min: 10, avg: 60.8, max: 422)
#
# Run: 214, exploration: 0.01, score: 35
# Scores: (min: 10, avg: 60.46, max: 422)
#
# Run: 215, exploration: 0.01, score: 175
# Scores: (min: 10, avg: 61.82, max: 422)
#
# Run: 216, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 61.07, max: 422)
#
# Run: 217, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 59.3, max: 422)
#
# Run: 218, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 59.16, max: 422)
#
# Run: 219, exploration: 0.01, score: 100
# Scores: (min: 10, avg: 59.7, max: 422)
#
# Run: 220, exploration: 0.01, score: 92
# Scores: (min: 10, avg: 60.29, max: 422)
#
# Run: 221, exploration: 0.01, score: 69
# Scores: (min: 10, avg: 60.41, max: 422)
#
# Run: 222, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 60.76, max: 422)
#
# Run: 223, exploration: 0.01, score: 55
# Scores: (min: 10, avg: 60.76, max: 422)
#
# Run: 224, exploration: 0.01, score: 28
# Scores: (min: 10, avg: 60.52, max: 422)
#
# Run: 225, exploration: 0.01, score: 63
# Scores: (min: 10, avg: 60.68, max: 422)
#
# Run: 226, exploration: 0.01, score: 24
# Scores: (min: 10, avg: 59.87, max: 422)
#
# Run: 227, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 59.87, max: 422)
#
# Run: 228, exploration: 0.01, score: 35
# Scores: (min: 10, avg: 59.94, max: 422)
#
# Run: 229, exploration: 0.01, score: 113
# Scores: (min: 10, avg: 60.52, max: 422)
#
# Run: 230, exploration: 0.01, score: 24
# Scores: (min: 10, avg: 60.62, max: 422)
#
# Run: 231, exploration: 0.01, score: 47
# Scores: (min: 10, avg: 60.69, max: 422)
#
# Run: 232, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 59.13, max: 422)
#
# Run: 233, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 58.9, max: 422)
#
# Run: 234, exploration: 0.01, score: 91
# Scores: (min: 10, avg: 59.52, max: 422)
#
# Run: 235, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 58.9, max: 422)
#
# Run: 236, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 58.71, max: 422)
#
# Run: 237, exploration: 0.01, score: 30
# Scores: (min: 10, avg: 58.73, max: 422)
#
# Run: 238, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 58.5, max: 422)
#
# Run: 239, exploration: 0.01, score: 88
# Scores: (min: 10, avg: 59.15, max: 422)
#
# Run: 240, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 58.81, max: 422)
#
# Run: 241, exploration: 0.01, score: 130
# Scores: (min: 10, avg: 59.82, max: 422)
#
# Run: 242, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 59.64, max: 422)
#
# Run: 243, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 57.95, max: 422)
#
# Run: 244, exploration: 0.01, score: 50
# Scores: (min: 10, avg: 57.09, max: 422)
#
# Run: 245, exploration: 0.01, score: 91
# Scores: (min: 10, avg: 57.84, max: 422)
#
# Run: 246, exploration: 0.01, score: 30
# Scores: (min: 10, avg: 57.33, max: 422)
#
# Run: 247, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 57.18, max: 422)
#
# Run: 248, exploration: 0.01, score: 62
# Scores: (min: 10, avg: 57.46, max: 422)
#
# Run: 249, exploration: 0.01, score: 54
# Scores: (min: 10, avg: 57.64, max: 422)
#
# Run: 250, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 57.36, max: 422)
#
# Run: 251, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 57.15, max: 422)
#
# Run: 252, exploration: 0.01, score: 25
# Scores: (min: 10, avg: 57.07, max: 422)
#
# Run: 253, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 56.77, max: 422)
#
# Run: 254, exploration: 0.01, score: 33
# Scores: (min: 10, avg: 56.98, max: 422)
#
# Run: 255, exploration: 0.01, score: 69
# Scores: (min: 10, avg: 57.21, max: 422)
#
# Run: 256, exploration: 0.01, score: 124
# Scores: (min: 10, avg: 57.95, max: 422)
#
# Run: 257, exploration: 0.01, score: 67
# Scores: (min: 10, avg: 58.26, max: 422)
#
# Run: 258, exploration: 0.01, score: 140
# Scores: (min: 10, avg: 59.32, max: 422)
#
# Run: 259, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 57.72, max: 422)
#
# Run: 260, exploration: 0.01, score: 94
# Scores: (min: 10, avg: 54.44, max: 186)
#
# Run: 261, exploration: 0.01, score: 37
# Scores: (min: 10, avg: 54.1, max: 186)
#
# Run: 262, exploration: 0.01, score: 85
# Scores: (min: 10, avg: 53.09, max: 175)
#
# Run: 263, exploration: 0.01, score: 125
# Scores: (min: 10, avg: 54.07, max: 175)
#
# Run: 264, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 53.18, max: 175)
#
# Run: 265, exploration: 0.01, score: 106
# Scores: (min: 10, avg: 53.36, max: 175)
#
# Run: 266, exploration: 0.01, score: 83
# Scores: (min: 10, avg: 54.08, max: 175)
#
# Run: 267, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 54.04, max: 175)
#
# Run: 268, exploration: 0.01, score: 22
# Scores: (min: 10, avg: 54.1, max: 175)
#
# Run: 269, exploration: 0.01, score: 41
# Scores: (min: 10, avg: 53.5, max: 175)
#
# Run: 270, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 52.84, max: 175)
#
# Run: 271, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 52.9, max: 175)
#
# Run: 272, exploration: 0.01, score: 119
# Scores: (min: 10, avg: 53.75, max: 175)
#
# Run: 273, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 53.72, max: 175)
#
# Run: 274, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 53.55, max: 175)
#
# Run: 275, exploration: 0.01, score: 29
# Scores: (min: 10, avg: 53.71, max: 175)
#
# Run: 276, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 53.45, max: 175)
#
# Run: 277, exploration: 0.01, score: 95
# Scores: (min: 10, avg: 54.05, max: 175)
#
# Run: 278, exploration: 0.01, score: 106
# Scores: (min: 10, avg: 54.99, max: 175)
#
# Run: 279, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 55.01, max: 175)
#
# Run: 280, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 54.07, max: 175)
#
# Run: 281, exploration: 0.01, score: 52
# Scores: (min: 10, avg: 54.23, max: 175)
#
# Run: 282, exploration: 0.01, score: 47
# Scores: (min: 10, avg: 54.4, max: 175)
#
# Run: 283, exploration: 0.01, score: 26
# Scores: (min: 10, avg: 53.79, max: 175)
#
# Run: 284, exploration: 0.01, score: 23
# Scores: (min: 10, avg: 53.66, max: 175)
#
# Run: 285, exploration: 0.01, score: 66
# Scores: (min: 10, avg: 53.9, max: 175)
#
# Run: 286, exploration: 0.01, score: 47
# Scores: (min: 10, avg: 54.23, max: 175)
#
# Run: 287, exploration: 0.01, score: 96
# Scores: (min: 10, avg: 54.5, max: 175)
#
# Run: 288, exploration: 0.01, score: 88
# Scores: (min: 10, avg: 54.22, max: 175)
#
# Run: 289, exploration: 0.01, score: 73
# Scores: (min: 10, avg: 53.83, max: 175)
#
# Run: 290, exploration: 0.01, score: 105
# Scores: (min: 10, avg: 54.28, max: 175)
#
# Run: 291, exploration: 0.01, score: 103
# Scores: (min: 10, avg: 54.26, max: 175)
#
# Run: 292, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 53.7, max: 175)
#
# Run: 293, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 52.7, max: 175)
#
# Run: 294, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 51.98, max: 175)
# Run: 295, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 52.02, max: 175)
#
# Run: 296, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 50.92, max: 175)
#
# Run: 297, exploration: 0.01, score: 32
# Scores: (min: 10, avg: 51.13, max: 175)
#
# Run: 298, exploration: 0.01, score: 90
# Scores: (min: 10, avg: 51.59, max: 175)
#
# Run: 299, exploration: 0.01, score: 52
# Scores: (min: 10, avg: 51.71, max: 175)
#
# Run: 300, exploration: 0.01, score: 35
# Scores: (min: 10, avg: 51.42, max: 175)
#
# Run: 301, exploration: 0.01, score: 57
# Scores: (min: 10, avg: 51.88, max: 175)
#
# Run: 302, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 51.9, max: 175)
#
# Run: 303, exploration: 0.01, score: 30
# Scores: (min: 10, avg: 51.89, max: 175)
#
# Run: 304, exploration: 0.01, score: 76
# Scores: (min: 10, avg: 51.55, max: 175)
#
# Run: 305, exploration: 0.01, score: 99
# Scores: (min: 10, avg: 52.34, max: 175)
#
# Run: 306, exploration: 0.01, score: 94
# Scores: (min: 10, avg: 52.4, max: 175)
#
# Run: 307, exploration: 0.01, score: 52
# Scores: (min: 10, avg: 52.76, max: 175)
#
# Run: 308, exploration: 0.01, score: 61
# Scores: (min: 10, avg: 53.06, max: 175)
#
# Run: 309, exploration: 0.01, score: 135
# Scores: (min: 10, avg: 53.16, max: 175)
#
# Run: 310, exploration: 0.01, score: 99
# Scores: (min: 10, avg: 53.73, max: 175)
#
# Run: 311, exploration: 0.01, score: 117
# Scores: (min: 10, avg: 54.71, max: 175)
#
# Run: 312, exploration: 0.01, score: 81
# Scores: (min: 10, avg: 54.45, max: 175)
#
# Run: 313, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 53.72, max: 175)
#
# Run: 314, exploration: 0.01, score: 55
# Scores: (min: 10, avg: 53.92, max: 175)
#
# Run: 315, exploration: 0.01, score: 52
# Scores: (min: 10, avg: 52.69, max: 140)
#
# Run: 316, exploration: 0.01, score: 32
# Scores: (min: 10, avg: 52.89, max: 140)
#
# Run: 317, exploration: 0.01, score: 34
# Scores: (min: 10, avg: 53.09, max: 140)
#
# Run: 318, exploration: 0.01, score: 47
# Scores: (min: 10, avg: 53.45, max: 140)
#
# Run: 319, exploration: 0.01, score: 43
# Scores: (min: 10, avg: 52.88, max: 140)
#
# Run: 320, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 52.06, max: 140)
#
# Run: 321, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 51.5, max: 140)
#
# Run: 322, exploration: 0.01, score: 38
# Scores: (min: 10, avg: 50.8, max: 140)
#
# Run: 323, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 50.4, max: 140)
#
# Run: 324, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 50.28, max: 140)
#
# Run: 325, exploration: 0.01, score: 90
# Scores: (min: 10, avg: 50.55, max: 140)
#
# Run: 326, exploration: 0.01, score: 69
# Scores: (min: 10, avg: 51, max: 140)
#
# Run: 327, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 50.8, max: 140)
#
# Run: 328, exploration: 0.01, score: 90
# Scores: (min: 10, avg: 51.35, max: 140)
#
# Run: 329, exploration: 0.01, score: 91
# Scores: (min: 10, avg: 51.13, max: 140)
#
# Run: 330, exploration: 0.01, score: 46
# Scores: (min: 10, avg: 51.35, max: 140)
#
# Run: 331, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 51.05, max: 140)
#
# Run: 332, exploration: 0.01, score: 92
# Scores: (min: 10, avg: 51.82, max: 140)
#
# Run: 333, exploration: 0.01, score: 52
# Scores: (min: 10, avg: 52.07, max: 140)
#
# Run: 334, exploration: 0.01, score: 90
# Scores: (min: 10, avg: 52.06, max: 140)
#
# Run: 335, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 51.95, max: 140)
#
# Run: 336, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 51.88, max: 140)
#
# Run: 337, exploration: 0.01, score: 39
# Scores: (min: 10, avg: 51.97, max: 140)
#
# Run: 338, exploration: 0.01, score: 38
# Scores: (min: 10, avg: 52.23, max: 140)
#
# Run: 339, exploration: 0.01, score: 166
# Scores: (min: 10, avg: 53.01, max: 166)
#
# Run: 340, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 52.9, max: 166)
#
# Run: 341, exploration: 0.01, score: 111
# Scores: (min: 10, avg: 52.71, max: 166)
#
# Run: 342, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 52.76, max: 166)
#
# Run: 343, exploration: 0.01, score: 34
# Scores: (min: 10, avg: 52.95, max: 166)
#
# Run: 344, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 52.55, max: 166)
#
# Run: 345, exploration: 0.01, score: 37
# Scores: (min: 10, avg: 52.01, max: 166)
#
# Run: 346, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 51.85, max: 166)
#
# Run: 347, exploration: 0.01, score: 93
# Scores: (min: 10, avg: 52.47, max: 166)
#
# Run: 348, exploration: 0.01, score: 36
# Scores: (min: 10, avg: 52.21, max: 166)
#
# Run: 349, exploration: 0.01, score: 84
# Scores: (min: 10, avg: 52.51, max: 166)
#
# Run: 350, exploration: 0.01, score: 67
# Scores: (min: 10, avg: 53.08, max: 166)
#
# Run: 351, exploration: 0.01, score: 57
# Scores: (min: 10, avg: 53.52, max: 166)
#
# Run: 352, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 53.38, max: 166)
#
# Run: 353, exploration: 0.01, score: 30
# Scores: (min: 10, avg: 53.52, max: 166)
#
# Run: 354, exploration: 0.01, score: 93
# Scores: (min: 10, avg: 54.12, max: 166)
#
# Run: 355, exploration: 0.01, score: 26
# Scores: (min: 10, avg: 53.69, max: 166)
#
# Run: 356, exploration: 0.01, score: 53
# Scores: (min: 10, avg: 52.98, max: 166)
#
# Run: 357, exploration: 0.01, score: 32
# Scores: (min: 10, avg: 52.63, max: 166)
#
# Run: 358, exploration: 0.01, score: 30
# Scores: (min: 10, avg: 51.53, max: 166)
#
# Run: 359, exploration: 0.01, score: 54
# Scores: (min: 10, avg: 51.91, max: 166)
#
# Run: 360, exploration: 0.01, score: 30
# Scores: (min: 10, avg: 51.27, max: 166)
#
# Run: 361, exploration: 0.01, score: 77
# Scores: (min: 10, avg: 51.67, max: 166)
#
# Run: 362, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 50.93, max: 166)
#
# Run: 363, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 49.79, max: 166)
#
# Run: 364, exploration: 0.01, score: 45
# Scores: (min: 10, avg: 49.93, max: 166)
#
# Run: 365, exploration: 0.01, score: 50
# Scores: (min: 10, avg: 49.37, max: 166)
#
# Run: 366, exploration: 0.01, score: 81
# Scores: (min: 10, avg: 49.35, max: 166)
#
# Run: 367, exploration: 0.01, score: 99
# Scores: (min: 10, avg: 50.24, max: 166)
#
# Run: 368, exploration: 0.01, score: 52
# Scores: (min: 10, avg: 50.54, max: 166)
#
# Run: 369, exploration: 0.01, score: 57
# Scores: (min: 10, avg: 50.7, max: 166)
#
# Run: 370, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 50.71, max: 166)
#
# Run: 371, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 50.66, max: 166)
#
# Run: 372, exploration: 0.01, score: 30
# Scores: (min: 10, avg: 49.77, max: 166)
#
# Run: 373, exploration: 0.01, score: 102
# Scores: (min: 10, avg: 50.67, max: 166)
#
# Run: 374, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 50.71, max: 166)
#
# Run: 375, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 50.69, max: 166)
#
# Run: 376, exploration: 0.01, score: 18
# Scores: (min: 10, avg: 50.71, max: 166)
#
# Run: 377, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 49.96, max: 166)
#
# Run: 378, exploration: 0.01, score: 46
# Scores: (min: 10, avg: 49.36, max: 166)
#
# Run: 379, exploration: 0.01, score: 61
# Scores: (min: 10, avg: 49.85, max: 166)
#
# Run: 380, exploration: 0.01, score: 103
# Scores: (min: 10, avg: 50.73, max: 166)
#
# Run: 381, exploration: 0.01, score: 51
# Scores: (min: 10, avg: 50.72, max: 166)
#
# Run: 382, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 50.37, max: 166)
#
# Run: 383, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 50.23, max: 166)
#
# Run: 384, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 50.12, max: 166)
#
# Run: 385, exploration: 0.01, score: 87
# Scores: (min: 10, avg: 50.33, max: 166)
#
# Run: 386, exploration: 0.01, score: 29
# Scores: (min: 10, avg: 50.15, max: 166)
#
# Run: 387, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 49.31, max: 166)
#
# Run: 388, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 48.54, max: 166)
#
# Run: 389, exploration: 0.01, score: 117
# Scores: (min: 10, avg: 48.98, max: 166)
#
# Run: 390, exploration: 0.01, score: 122
# Scores: (min: 10, avg: 49.15, max: 166)
#
# Run: 391, exploration: 0.01, score: 47
# Scores: (min: 10, avg: 48.59, max: 166)
#
# Run: 392, exploration: 0.01, score: 43
# Scores: (min: 10, avg: 48.91, max: 166)
#
# Run: 393, exploration: 0.01, score: 28
# Scores: (min: 10, avg: 49.03, max: 166)
#
# Run: 394, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 49.03, max: 166)
#
# Run: 395, exploration: 0.01, score: 40
# Scores: (min: 10, avg: 49.27, max: 166)
#
# Run: 396, exploration: 0.01, score: 21
# Scores: (min: 10, avg: 49.36, max: 166)
#
# Run: 397, exploration: 0.01, score: 36
# Scores: (min: 10, avg: 49.4, max: 166)
# Run: 398, exploration: 0.01, score: 87
# Scores: (min: 10, avg: 49.37, max: 166)
#
# Run: 399, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 48.96, max: 166)
#
# Run: 400, exploration: 0.01, score: 65
# Scores: (min: 10, avg: 49.26, max: 166)
#
# Run: 401, exploration: 0.01, score: 73
# Scores: (min: 10, avg: 49.42, max: 166)
#
# Run: 402, exploration: 0.01, score: 48
# Scores: (min: 10, avg: 49.77, max: 166)
#
# Run: 403, exploration: 0.01, score: 18
# Scores: (min: 10, avg: 49.65, max: 166)
#
# Run: 404, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 49.2, max: 166)
#
# Run: 405, exploration: 0.01, score: 70
# Scores: (min: 10, avg: 48.91, max: 166)
#
# Run: 406, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 48.28, max: 166)
#
# Run: 407, exploration: 0.01, score: 28
# Scores: (min: 10, avg: 48.04, max: 166)
#
# Run: 408, exploration: 0.01, score: 104
# Scores: (min: 10, avg: 48.47, max: 166)
#
# Run: 409, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 47.39, max: 166)
#
# Run: 410, exploration: 0.01, score: 47
# Scores: (min: 10, avg: 46.87, max: 166)
#
# Run: 411, exploration: 0.01, score: 71
# Scores: (min: 10, avg: 46.41, max: 166)
#
# Run: 412, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 45.71, max: 166)
#
# Run: 413, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 45.74, max: 166)
#
# Run: 414, exploration: 0.01, score: 109
# Scores: (min: 10, avg: 46.28, max: 166)
#
# Run: 415, exploration: 0.01, score: 23
# Scores: (min: 10, avg: 45.99, max: 166)
#
# Run: 416, exploration: 0.01, score: 19
# Scores: (min: 10, avg: 45.86, max: 166)
#
# Run: 417, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 45.64, max: 166)
#
# Run: 418, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 45.3, max: 166)
#
# Run: 419, exploration: 0.01, score: 42
# Scores: (min: 10, avg: 45.29, max: 166)
#
# Run: 420, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 45.29, max: 166)
#
# Run: 421, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 45.47, max: 166)
#
# Run: 422, exploration: 0.01, score: 51
# Scores: (min: 10, avg: 45.6, max: 166)
#
# Run: 423, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 45.65, max: 166)
#
# Run: 424, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 45.62, max: 166)
#
# Run: 425, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 44.82, max: 166)
#
# Run: 426, exploration: 0.01, score: 18
# Scores: (min: 10, avg: 44.31, max: 166)
#
# Run: 427, exploration: 0.01, score: 50
# Scores: (min: 10, avg: 44.7, max: 166)
#
# Run: 428, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 44, max: 166)
#
# Run: 429, exploration: 0.01, score: 59
# Scores: (min: 10, avg: 43.68, max: 166)
#
# Run: 430, exploration: 0.01, score: 59
# Scores: (min: 10, avg: 43.81, max: 166)
#
# Run: 431, exploration: 0.01, score: 101
# Scores: (min: 10, avg: 44.65, max: 166)
#
# Run: 432, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 43.9, max: 166)
#
# Run: 433, exploration: 0.01, score: 57
# Scores: (min: 10, avg: 43.95, max: 166)
#
# Run: 434, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 43.32, max: 166)
#
# Run: 435, exploration: 0.01, score: 66
# Scores: (min: 10, avg: 43.78, max: 166)
#
# Run: 436, exploration: 0.01, score: 79
# Scores: (min: 10, avg: 44.44, max: 166)
#
# Run: 437, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 44.16, max: 166)
#
# Run: 438, exploration: 0.01, score: 44
# Scores: (min: 10, avg: 44.22, max: 166)
#
# Run: 439, exploration: 0.01, score: 42
# Scores: (min: 10, avg: 42.98, max: 122)
#
# Run: 440, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 42.95, max: 122)
#
# Run: 441, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 41.98, max: 122)
#
# Run: 442, exploration: 0.01, score: 70
# Scores: (min: 10, avg: 42.53, max: 122)
#
# Run: 443, exploration: 0.01, score: 90
# Scores: (min: 10, avg: 43.09, max: 122)
#
# Run: 444, exploration: 0.01, score: 134
# Scores: (min: 10, avg: 44.33, max: 134)
#
# Run: 445, exploration: 0.01, score: 26
# Scores: (min: 10, avg: 44.22, max: 134)
#
# Run: 446, exploration: 0.01, score: 18
# Scores: (min: 10, avg: 44.26, max: 134)
#
# Run: 447, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 43.48, max: 134)
#
# Run: 448, exploration: 0.01, score: 129
# Scores: (min: 10, avg: 44.41, max: 134)
#
# Run: 449, exploration: 0.01, score: 94
# Scores: (min: 10, avg: 44.51, max: 134)
#
# Run: 450, exploration: 0.01, score: 41
# Scores: (min: 10, avg: 44.25, max: 134)
#
# Run: 451, exploration: 0.01, score: 51
# Scores: (min: 10, avg: 44.19, max: 134)
#
# Run: 452, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 44.18, max: 134)
#
# Run: 453, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 44, max: 134)
#
# Run: 454, exploration: 0.01, score: 105
# Scores: (min: 10, avg: 44.12, max: 134)
#
# Run: 455, exploration: 0.01, score: 79
# Scores: (min: 10, avg: 44.65, max: 134)
#
# Run: 456, exploration: 0.01, score: 136
# Scores: (min: 10, avg: 45.48, max: 136)
#
# Run: 457, exploration: 0.01, score: 29
# Scores: (min: 10, avg: 45.45, max: 136)
#
# Run: 458, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 45.3, max: 136)
#
# Run: 459, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 44.87, max: 136)
#
# Run: 460, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 44.69, max: 136)
#
# Run: 461, exploration: 0.01, score: 43
# Scores: (min: 10, avg: 44.35, max: 136)
#
# Run: 462, exploration: 0.01, score: 40
# Scores: (min: 10, avg: 44.64, max: 136)
#
# Run: 463, exploration: 0.01, score: 53
# Scores: (min: 10, avg: 45.06, max: 136)
#
# Run: 464, exploration: 0.01, score: 99
# Scores: (min: 10, avg: 45.6, max: 136)
#
# Run: 465, exploration: 0.01, score: 40
# Scores: (min: 10, avg: 45.5, max: 136)
#
# Run: 466, exploration: 0.01, score: 68
# Scores: (min: 10, avg: 45.37, max: 136)
#
# Run: 467, exploration: 0.01, score: 58
# Scores: (min: 10, avg: 44.96, max: 136)
#
# Run: 468, exploration: 0.01, score: 71
# Scores: (min: 10, avg: 45.15, max: 136)
#
# Run: 469, exploration: 0.01, score: 21
# Scores: (min: 10, avg: 44.79, max: 136)
#
# Run: 470, exploration: 0.01, score: 58
# Scores: (min: 10, avg: 45.24, max: 136)
#
# Run: 471, exploration: 0.01, score: 38
# Scores: (min: 10, avg: 45.5, max: 136)
#
# Run: 472, exploration: 0.01, score: 97
# Scores: (min: 10, avg: 46.17, max: 136)
#
# Run: 473, exploration: 0.01, score: 116
# Scores: (min: 10, avg: 46.31, max: 136)
#
# Run: 474, exploration: 0.01, score: 95
# Scores: (min: 10, avg: 47.11, max: 136)
#
# Run: 475, exploration: 0.01, score: 19
# Scores: (min: 10, avg: 47.03, max: 136)
#
# Run: 476, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 47.01, max: 136)
#
# Run: 477, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 46.93, max: 136)
#
# Run: 478, exploration: 0.01, score: 103
# Scores: (min: 10, avg: 47.5, max: 136)
#
# Run: 479, exploration: 0.01, score: 50
# Scores: (min: 10, avg: 47.39, max: 136)
#
# Run: 480, exploration: 0.01, score: 54
# Scores: (min: 10, avg: 46.9, max: 136)
#
# Run: 481, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 46.53, max: 136)
#
# Run: 482, exploration: 0.01, score: 54
# Scores: (min: 10, avg: 46.95, max: 136)
#
# Run: 483, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 46.96, max: 136)
#
# Run: 484, exploration: 0.01, score: 23
# Scores: (min: 10, avg: 47.07, max: 136)
#
# Run: 485, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 46.33, max: 136)
#
# Run: 486, exploration: 0.01, score: 70
# Scores: (min: 10, avg: 46.74, max: 136)
#
# Run: 487, exploration: 0.01, score: 57
# Scores: (min: 10, avg: 47.19, max: 136)
#
# Run: 488, exploration: 0.01, score: 68
# Scores: (min: 10, avg: 47.76, max: 136)
#
# Run: 489, exploration: 0.01, score: 86
# Scores: (min: 10, avg: 47.45, max: 136)
#
# Run: 490, exploration: 0.01, score: 77
# Scores: (min: 10, avg: 47, max: 136)
#
# Run: 491, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 46.84, max: 136)
#
# Run: 492, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 46.51, max: 136)
#
# Run: 493, exploration: 0.01, score: 105
# Scores: (min: 10, avg: 47.28, max: 136)
#
# Run: 494, exploration: 0.01, score: 36
# Scores: (min: 10, avg: 47.52, max: 136)
#
# Run: 495, exploration: 0.01, score: 75
# Scores: (min: 10, avg: 47.87, max: 136)
#
# Run: 496, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 47.83, max: 136)
#
# Run: 497, exploration: 0.01, score: 49
# Scores: (min: 10, avg: 47.96, max: 136)
#
# Run: 498, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 47.2, max: 136)
#
# Run: 499, exploration: 0.01, score: 35
# Scores: (min: 10, avg: 47.44, max: 136)
#
# Run: 500, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 46.93, max: 136)
# Run: 501, exploration: 0.01, score: 36
# Scores: (min: 10, avg: 46.56, max: 136)
#
# Run: 502, exploration: 0.01, score: 124
# Scores: (min: 10, avg: 47.32, max: 136)
#
# Run: 503, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 47.29, max: 136)
#
# Run: 504, exploration: 0.01, score: 44
# Scores: (min: 10, avg: 47.42, max: 136)
#
# Run: 505, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 46.89, max: 136)
#
# Run: 506, exploration: 0.01, score: 37
# Scores: (min: 10, avg: 46.95, max: 136)
#
# Run: 507, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 46.78, max: 136)
#
# Run: 508, exploration: 0.01, score: 107
# Scores: (min: 10, avg: 46.81, max: 136)
#
# Run: 509, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 47.62, max: 136)
#
# Run: 510, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 47.27, max: 136)
#
# Run: 511, exploration: 0.01, score: 130
# Scores: (min: 10, avg: 47.86, max: 136)
#
# Run: 512, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 47.87, max: 136)
#
# Run: 513, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 47.84, max: 136)
#
# Run: 514, exploration: 0.01, score: 92
# Scores: (min: 10, avg: 47.67, max: 136)
#
# Run: 515, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 47.54, max: 136)
#
# Run: 516, exploration: 0.01, score: 26
# Scores: (min: 10, avg: 47.61, max: 136)
#
# Run: 517, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 47.59, max: 136)
#
# Run: 518, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 47.73, max: 136)
#
# Run: 519, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 47.42, max: 136)
#
# Run: 520, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 47.45, max: 136)
#
# Run: 521, exploration: 0.01, score: 69
# Scores: (min: 10, avg: 47.83, max: 136)
#
# Run: 522, exploration: 0.01, score: 64
# Scores: (min: 10, avg: 47.96, max: 136)
#
# Run: 523, exploration: 0.01, score: 88
# Scores: (min: 10, avg: 48.64, max: 136)
#
# Run: 524, exploration: 0.01, score: 82
# Scores: (min: 10, avg: 49.33, max: 136)
#
# Run: 525, exploration: 0.01, score: 137
# Scores: (min: 10, avg: 50.6, max: 137)
#
# Run: 526, exploration: 0.01, score: 143
# Scores: (min: 10, avg: 51.85, max: 143)
#
# Run: 527, exploration: 0.01, score: 42
# Scores: (min: 10, avg: 51.77, max: 143)
#
# Run: 528, exploration: 0.01, score: 63
# Scores: (min: 10, avg: 52.2, max: 143)
#
# Run: 529, exploration: 0.01, score: 60
# Scores: (min: 10, avg: 52.21, max: 143)
#
# Run: 530, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 51.74, max: 143)
#
# Run: 531, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 50.86, max: 143)
#
# Run: 532, exploration: 0.01, score: 23
# Scores: (min: 10, avg: 50.92, max: 143)
#
# Run: 533, exploration: 0.01, score: 31
# Scores: (min: 10, avg: 50.66, max: 143)
#
# Run: 534, exploration: 0.01, score: 59
# Scores: (min: 10, avg: 50.98, max: 143)
#
# Run: 535, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 50.43, max: 143)
#
# Run: 536, exploration: 0.01, score: 28
# Scores: (min: 10, avg: 49.92, max: 143)
#
# Run: 537, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 49.94, max: 143)
#
# Run: 538, exploration: 0.01, score: 57
# Scores: (min: 10, avg: 50.07, max: 143)
#
# Run: 539, exploration: 0.01, score: 65
# Scores: (min: 10, avg: 50.3, max: 143)
#
# Run: 540, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 50.28, max: 143)
#
# Run: 541, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 50.31, max: 143)
#
# Run: 542, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 49.72, max: 143)
#
# Run: 543, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 48.92, max: 143)
#
# Run: 544, exploration: 0.01, score: 23
# Scores: (min: 10, avg: 47.81, max: 143)
#
# Run: 545, exploration: 0.01, score: 89
# Scores: (min: 10, avg: 48.44, max: 143)
#
# Run: 546, exploration: 0.01, score: 52
# Scores: (min: 10, avg: 48.78, max: 143)
#
# Run: 547, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 48.75, max: 143)
#
# Run: 548, exploration: 0.01, score: 85
# Scores: (min: 10, avg: 48.31, max: 143)
#
# Run: 549, exploration: 0.01, score: 35
# Scores: (min: 10, avg: 47.72, max: 143)
#
# Run: 550, exploration: 0.01, score: 30
# Scores: (min: 10, avg: 47.61, max: 143)
#
# Run: 551, exploration: 0.01, score: 30
# Scores: (min: 10, avg: 47.4, max: 143)
#
# Run: 552, exploration: 0.01, score: 33
# Scores: (min: 10, avg: 47.63, max: 143)
#
# Run: 553, exploration: 0.01, score: 100
# Scores: (min: 10, avg: 48.51, max: 143)
#
# Run: 554, exploration: 0.01, score: 89
# Scores: (min: 10, avg: 48.35, max: 143)
#
# Run: 555, exploration: 0.01, score: 42
# Scores: (min: 10, avg: 47.98, max: 143)
#
# Run: 556, exploration: 0.01, score: 94
# Scores: (min: 10, avg: 47.56, max: 143)
#
# Run: 557, exploration: 0.01, score: 58
# Scores: (min: 10, avg: 47.85, max: 143)
#
# Run: 558, exploration: 0.01, score: 43
# Scores: (min: 10, avg: 48.13, max: 143)
#
# Run: 559, exploration: 0.01, score: 47
# Scores: (min: 10, avg: 48.49, max: 143)
#
# Run: 560, exploration: 0.01, score: 149
# Scores: (min: 10, avg: 49.86, max: 149)
#
# Run: 561, exploration: 0.01, score: 36
# Scores: (min: 10, avg: 49.79, max: 149)
#
# Run: 562, exploration: 0.01, score: 100
# Scores: (min: 10, avg: 50.39, max: 149)
#
# Run: 563, exploration: 0.01, score: 48
# Scores: (min: 10, avg: 50.34, max: 149)
#
# Run: 564, exploration: 0.01, score: 93
# Scores: (min: 10, avg: 50.28, max: 149)
#
# Run: 565, exploration: 0.01, score: 55
# Scores: (min: 10, avg: 50.43, max: 149)
#
# Run: 566, exploration: 0.01, score: 33
# Scores: (min: 10, avg: 50.08, max: 149)
#
# Run: 567, exploration: 0.01, score: 46
# Scores: (min: 10, avg: 49.96, max: 149)
#
# Run: 568, exploration: 0.01, score: 60
# Scores: (min: 10, avg: 49.85, max: 149)
#
# Run: 569, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 49.79, max: 149)
#
# Run: 570, exploration: 0.01, score: 56
# Scores: (min: 10, avg: 49.77, max: 149)
#
# Run: 571, exploration: 0.01, score: 66
# Scores: (min: 10, avg: 50.05, max: 149)
#
# Run: 572, exploration: 0.01, score: 121
# Scores: (min: 10, avg: 50.29, max: 149)
#
# Run: 573, exploration: 0.01, score: 135
# Scores: (min: 10, avg: 50.48, max: 149)
#
# Run: 574, exploration: 0.01, score: 41
# Scores: (min: 10, avg: 49.94, max: 149)
#
# Run: 575, exploration: 0.01, score: 35
# Scores: (min: 10, avg: 50.1, max: 149)
#
# Run: 576, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 50.1, max: 149)
#
# Run: 577, exploration: 0.01, score: 129
# Scores: (min: 10, avg: 51.27, max: 149)
#
# Run: 578, exploration: 0.01, score: 103
# Scores: (min: 10, avg: 51.27, max: 149)
#
# Run: 579, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 50.87, max: 149)
#
# Run: 580, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 50.49, max: 149)
#
# Run: 581, exploration: 0.01, score: 48
# Scores: (min: 10, avg: 50.83, max: 149)
#
# Run: 582, exploration: 0.01, score: 67
# Scores: (min: 10, avg: 50.96, max: 149)
#
# Run: 583, exploration: 0.01, score: 62
# Scores: (min: 10, avg: 51.45, max: 149)
#
# Run: 584, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 51.34, max: 149)
#
# Run: 585, exploration: 0.01, score: 15
# ...
# Scores: (min: 9, avg: 38.63, max: 142)
#
# Run: 2796, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 37.48, max: 142)
#
# Run: 2797, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 37.43, max: 142)
#
# Run: 2798, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 37.33, max: 142)
#
# Run: 2799, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 37.39, max: 142)
#
# Run: 2800, exploration: 0.01, score: 73
# Scores: (min: 9, avg: 37.68, max: 142)
#
# Run: 2801, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 37.15, max: 142)
#
# Run: 2802, exploration: 0.01, score: 65
# Scores: (min: 9, avg: 37.13, max: 142)
#
# Run: 2803, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 36.87, max: 142)
#
# Run: 2804, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 36.93, max: 142)
#
# Run: 2805, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 37.03, max: 142)
#
# Run: 2806, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 36.82, max: 142)
#
# Run: 2807, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 36.51, max: 142)
#
# Run: 2808, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 36.58, max: 142)
#
# Run: 2809, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 36.41, max: 142)
#
# Run: 2810, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 36.43, max: 142)
#
# Run: 2811, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 36.42, max: 142)
#
# Run: 2812, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 36.45, max: 142)
#
# Run: 2813, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 36.53, max: 142)
#
# Run: 2814, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 36.64, max: 142)
#
# Run: 2815, exploration: 0.01, score: 89
# Scores: (min: 9, avg: 37.43, max: 142)
#
# Run: 2816, exploration: 0.01, score: 72
# Scores: (min: 9, avg: 37.62, max: 142)
#
# Run: 2817, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 37.08, max: 142)
#
# Run: 2818, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 36.73, max: 142)
#
# Run: 2819, exploration: 0.01, score: 60
# Scores: (min: 9, avg: 36.68, max: 142)
#
# Run: 2820, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 36.52, max: 142)
#
# Run: 2821, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 36.19, max: 142)
#
# Run: 2822, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 35.77, max: 142)
#
# Run: 2823, exploration: 0.01, score: 102
# Scores: (min: 9, avg: 36.01, max: 142)
#
# Run: 2824, exploration: 0.01, score: 95
# Scores: (min: 9, avg: 36.09, max: 142)
#
# Run: 2825, exploration: 0.01, score: 61
# Scores: (min: 9, avg: 36.32, max: 142)
#
# Run: 2826, exploration: 0.01, score: 90
# Scores: (min: 9, avg: 36.62, max: 142)
#
# Run: 2827, exploration: 0.01, score: 58
# Scores: (min: 9, avg: 36.98, max: 142)
#
# Run: 2828, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 36.84, max: 142)
#
# Run: 2829, exploration: 0.01, score: 89
# Scores: (min: 9, avg: 37.63, max: 142)
#
# Run: 2830, exploration: 0.01, score: 158
# Scores: (min: 9, avg: 39.11, max: 158)
#
# Run: 2831, exploration: 0.01, score: 74
# Scores: (min: 9, avg: 39.75, max: 158)
#
# Run: 2832, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 39.42, max: 158)
#
# Run: 2833, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 39.39, max: 158)
#
# Run: 2834, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 39.26, max: 158)
#
# Run: 2835, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 39.31, max: 158)
#
# Run: 2836, exploration: 0.01, score: 70
# Scores: (min: 9, avg: 38.59, max: 158)
#
# Run: 2837, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 39.8, max: 158)
#
# Run: 2838, exploration: 0.01, score: 148
# Scores: (min: 9, avg: 41.11, max: 158)
#
# Run: 2839, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 41.07, max: 158)
#
# Run: 2840, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 41.16, max: 158)
#
# Run: 2841, exploration: 0.01, score: 102
# Scores: (min: 9, avg: 41.39, max: 158)
#
# Run: 2842, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 41.27, max: 158)
#
# Run: 2843, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 40.65, max: 158)
#
# Run: 2844, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 40.38, max: 158)
#
# Run: 2845, exploration: 0.01, score: 38
# Scores: (min: 9, avg: 39.9, max: 158)
#
# Run: 2846, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 39.94, max: 158)
#
# Run: 2847, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 40.08, max: 158)
#
# Run: 2848, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 39.21, max: 158)
#
# Run: 2849, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 38.99, max: 158)
#
# Run: 2850, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 38.77, max: 158)
#
# Run: 2851, exploration: 0.01, score: 51
# Scores: (min: 9, avg: 38.58, max: 158)
#
# Run: 2852, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 37.85, max: 158)
#
# Run: 2853, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 37.01, max: 158)
#
# Run: 2854, exploration: 0.01, score: 53
# Scores: (min: 9, avg: 36.55, max: 158)
#
# Run: 2855, exploration: 0.01, score: 57
# Scores: (min: 9, avg: 37.02, max: 158)
#
# Run: 2856, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 37.09, max: 158)
#
# Run: 2857, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 37.07, max: 158)
#
# Run: 2858, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 37.05, max: 158)
#
# Run: 2859, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 37.22, max: 158)
#
# Run: 2860, exploration: 0.01, score: 68
# Scores: (min: 9, avg: 37.07, max: 158)
#
# Run: 2861, exploration: 0.01, score: 68
# Scores: (min: 9, avg: 36.78, max: 158)
#
# Run: 2862, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 36.88, max: 158)
#
# Run: 2863, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 36.92, max: 158)
#
# Run: 2864, exploration: 0.01, score: 85
# Scores: (min: 9, avg: 37.65, max: 158)
#
# Run: 2865, exploration: 0.01, score: 138
# Scores: (min: 9, avg: 38.9, max: 158)
#
# Run: 2866, exploration: 0.01, score: 91
# Scores: (min: 9, avg: 39.25, max: 158)
#
# Run: 2867, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 39.33, max: 158)
# Run: 2868, exploration: 0.01, score: 69
# Scores: (min: 9, avg: 39.91, max: 158)
#
# Run: 2869, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 39.4, max: 158)
#
# Run: 2870, exploration: 0.01, score: 69
# Scores: (min: 9, avg: 39.9, max: 158)
#
# Run: 2871, exploration: 0.01, score: 93
# Scores: (min: 9, avg: 39.89, max: 158)
#
# Run: 2872, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 39.93, max: 158)
#
# Run: 2873, exploration: 0.01, score: 69
# Scores: (min: 9, avg: 40.5, max: 158)
#
# Run: 2874, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 40.51, max: 158)
#
# Run: 2875, exploration: 0.01, score: 98
# Scores: (min: 9, avg: 40.3, max: 158)
#
# Run: 2876, exploration: 0.01, score: 98
# Scores: (min: 9, avg: 40.99, max: 158)
#
# Run: 2877, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 41.03, max: 158)
#
# Run: 2878, exploration: 0.01, score: 92
# Scores: (min: 9, avg: 41.33, max: 158)
#
# Run: 2879, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 41.32, max: 158)
#
# Run: 2880, exploration: 0.01, score: 66
# Scores: (min: 9, avg: 41.85, max: 158)
#
# Run: 2881, exploration: 0.01, score: 86
# Scores: (min: 9, avg: 42.34, max: 158)
#
# Run: 2882, exploration: 0.01, score: 44
# Scores: (min: 9, avg: 42.68, max: 158)
#
# Run: 2883, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 42.66, max: 158)
#
# Run: 2884, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 42.62, max: 158)
#
# Run: 2885, exploration: 0.01, score: 57
# Scores: (min: 9, avg: 42.5, max: 158)
#
# Run: 2886, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 42.47, max: 158)
#
# Run: 2887, exploration: 0.01, score: 44
# Scores: (min: 9, avg: 42.57, max: 158)
#
# Run: 2888, exploration: 0.01, score: 41
# Scores: (min: 9, avg: 42.87, max: 158)
#
# Run: 2889, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 42.18, max: 158)
#
# Run: 2890, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 41.88, max: 158)
#
# Run: 2891, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 41.81, max: 158)
#
# Run: 2892, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 41.99, max: 158)
#
# Run: 2893, exploration: 0.01, score: 69
# Scores: (min: 9, avg: 42.07, max: 158)
#
# Run: 2894, exploration: 0.01, score: 105
# Scores: (min: 9, avg: 42.87, max: 158)
#
# Run: 2895, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 42.77, max: 158)
#
# Run: 2896, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 42.78, max: 158)
#
# Run: 2897, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 42.74, max: 158)
#
# Run: 2898, exploration: 0.01, score: 95
# Scores: (min: 9, avg: 43.59, max: 158)
#
# Run: 2899, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 43.51, max: 158)
#
# Run: 2900, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 42.94, max: 158)
#
# Run: 2901, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 42.96, max: 158)
#
# Run: 2902, exploration: 0.01, score: 83
# Scores: (min: 9, avg: 43.14, max: 158)
#
# Run: 2903, exploration: 0.01, score: 44
# Scores: (min: 9, avg: 43.47, max: 158)
#
# Run: 2904, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 43.4, max: 158)
#
# Run: 2905, exploration: 0.01, score: 51
# Scores: (min: 9, avg: 43.69, max: 158)
#
# Run: 2906, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 43.49, max: 158)
#
# Run: 2907, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 43.56, max: 158)
#
# Run: 2908, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 43.49, max: 158)
#
# Run: 2909, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 44.39, max: 158)
#
# Run: 2910, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 44.44, max: 158)
#
# Run: 2911, exploration: 0.01, score: 108
# Scores: (min: 9, avg: 45.41, max: 158)
#
# Run: 2912, exploration: 0.01, score: 73
# Scores: (min: 9, avg: 46, max: 158)
#
# Run: 2913, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 46.14, max: 158)
#
# Run: 2914, exploration: 0.01, score: 112
# Scores: (min: 9, avg: 47.05, max: 158)
#
# Run: 2915, exploration: 0.01, score: 97
# Scores: (min: 9, avg: 47.13, max: 158)
#
# Run: 2916, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 46.84, max: 158)
#
# Run: 2917, exploration: 0.01, score: 93
# Scores: (min: 9, avg: 47.64, max: 158)
#
# Run: 2918, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 47.6, max: 158)
#
# Run: 2919, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 47.14, max: 158)
#
# Run: 2920, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 47.11, max: 158)
#
# Run: 2921, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 47.05, max: 158)
#
# Run: 2922, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 46.92, max: 158)
#
# Run: 2923, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 46.13, max: 158)
#
# Run: 2924, exploration: 0.01, score: 42
# Scores: (min: 9, avg: 45.6, max: 158)
#
# Run: 2925, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 45.09, max: 158)
#
# Run: 2926, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 44.39, max: 158)
#
# Run: 2927, exploration: 0.01, score: 69
# Scores: (min: 9, avg: 44.5, max: 158)
#
# Run: 2928, exploration: 0.01, score: 106
# Scores: (min: 9, avg: 45.46, max: 158)
#
# Run: 2929, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 46.09, max: 158)
#
# Run: 2930, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 44.62, max: 152)
#
# Run: 2931, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 44.02, max: 152)
#
# Run: 2932, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 44.06, max: 152)
#
# Run: 2933, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 44.1, max: 152)
#
# Run: 2934, exploration: 0.01, score: 64
# Scores: (min: 9, avg: 44.64, max: 152)
#
# Run: 2935, exploration: 0.01, score: 169
# Scores: (min: 9, avg: 46.14, max: 169)
#
# Run: 2936, exploration: 0.01, score: 99
# Scores: (min: 9, avg: 46.43, max: 169)
#
# Run: 2937, exploration: 0.01, score: 69
# Scores: (min: 9, avg: 45.79, max: 169)
#
# Run: 2938, exploration: 0.01, score: 47
# Scores: (min: 9, avg: 44.78, max: 169)
#
# Run: 2939, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 44.79, max: 169)
#
# Run: 2940, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 44.71, max: 169)
#
# Run: 2941, exploration: 0.01, score: 61
# Scores: (min: 9, avg: 44.3, max: 169)
#
# Run: 2942, exploration: 0.01, score: 73
# Scores: (min: 9, avg: 44.83, max: 169)
#
# Run: 2943, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 45.09, max: 169)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-fe544489a747> in <module>
#       1 GAMMA = 0.5
#       2
# ----> 3 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      86                 score_logger.add_score(step, run)
#      87                 break
# ---> 88             dqn_solver.experience_replay()
#      89
#
# <ipython-input-1-bea6327a4fd8> in experience_replay(self)
#      53             q_update = reward
#      54             if not terminal:
# ---> 55                 q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
#      56             q_values = self.model.predict(state)
#      57             q_values[0][action] = q_update
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
GAMMA = 0.95
LEARNING_RATE = 0.01

cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 20
# Scores: (min: 20, avg: 20, max: 20)
#
# Run: 2, exploration: 0.8020760579717637, score: 45
# Scores: (min: 20, avg: 32.5, max: 45)
#
# Run: 3, exploration: 0.7111635524897149, score: 25
# Scores: (min: 20, avg: 30, max: 45)
#
# Run: 4, exploration: 0.6629680834613705, score: 15
# Scores: (min: 15, avg: 26.25, max: 45)
#
# Run: 5, exploration: 0.6180388156137953, score: 15
# Scores: (min: 15, avg: 24, max: 45)
#
# Run: 6, exploration: 0.5907768628656763, score: 10
# Scores: (min: 10, avg: 21.666666666666668, max: 45)
#
# Run: 7, exploration: 0.5562889678716474, score: 13
# Scores: (min: 10, avg: 20.428571428571427, max: 45)
#
# Run: 8, exploration: 0.4907693883854626, score: 26
# Scores: (min: 10, avg: 21.125, max: 45)
#
# Run: 9, exploration: 0.47147873742168567, score: 9
# Scores: (min: 9, avg: 19.77777777777778, max: 45)
#
# Run: 10, exploration: 0.4506816115185697, score: 10
# Scores: (min: 9, avg: 18.8, max: 45)
#
# Run: 11, exploration: 0.4036245882390106, score: 23
# Scores: (min: 9, avg: 19.181818181818183, max: 45)
#
# Run: 12, exploration: 0.38389143477919885, score: 11
# Scores: (min: 9, avg: 18.5, max: 45)
#
# Run: 13, exploration: 0.36512303261753626, score: 11
# Scores: (min: 9, avg: 17.923076923076923, max: 45)
#
# Run: 14, exploration: 0.3386767948568688, score: 16
# Scores: (min: 9, avg: 17.785714285714285, max: 45)
#
# Run: 15, exploration: 0.322118930542046, score: 11
# Scores: (min: 9, avg: 17.333333333333332, max: 45)
#
# Run: 16, exploration: 0.285607880564032, score: 25
# Scores: (min: 9, avg: 17.8125, max: 45)
#
# Run: 17, exploration: 0.2730095965279488, score: 10
# Scores: (min: 9, avg: 17.352941176470587, max: 45)
#
# Run: 18, exploration: 0.25966219297210513, score: 11
# Scores: (min: 9, avg: 17, max: 45)
#
# Run: 19, exploration: 0.2494556624678441, score: 9
# Scores: (min: 9, avg: 16.57894736842105, max: 45)
#
# Run: 20, exploration: 0.2384520680152932, score: 10
# Scores: (min: 9, avg: 16.25, max: 45)
#
# Run: 21, exploration: 0.22793384675362674, score: 10
# Scores: (min: 9, avg: 15.952380952380953, max: 45)
#
# Run: 22, exploration: 0.21355457002808648, score: 14
# Scores: (min: 9, avg: 15.863636363636363, max: 45)
#
# Run: 23, exploration: 0.2031139149609751, score: 11
# Scores: (min: 9, avg: 15.652173913043478, max: 45)
#
# Run: 24, exploration: 0.19415447453059972, score: 10
# Scores: (min: 9, avg: 15.416666666666666, max: 45)
#
# Run: 25, exploration: 0.1846622876013121, score: 11
# Scores: (min: 9, avg: 15.24, max: 45)
#
# Run: 26, exploration: 0.17740377510930716, score: 9
# Scores: (min: 9, avg: 15, max: 45)
#
# Run: 27, exploration: 0.17043057265153258, score: 9
# Scores: (min: 9, avg: 14.777777777777779, max: 45)
#
# Run: 28, exploration: 0.16373146555890544, score: 9
# Scores: (min: 9, avg: 14.571428571428571, max: 45)
#
# Run: 29, exploration: 0.1572956799768517, score: 9
# Scores: (min: 9, avg: 14.379310344827585, max: 45)
#
# Run: 30, exploration: 0.11585765144771248, score: 62
# Scores: (min: 9, avg: 15.966666666666667, max: 62)
#
# Run: 31, exploration: 0.1063939893092943, score: 18
# Scores: (min: 9, avg: 16.032258064516128, max: 62)
#
# Run: 32, exploration: 0.10221196540767843, score: 9
# Scores: (min: 9, avg: 15.8125, max: 62)
#
# Run: 33, exploration: 0.09819432413732986, score: 9
# Scores: (min: 9, avg: 15.606060606060606, max: 62)
#
# Run: 34, exploration: 0.09246201511725258, score: 13
# Scores: (min: 9, avg: 15.529411764705882, max: 62)
#
# Run: 35, exploration: 0.0888276147181114, score: 9
# Scores: (min: 9, avg: 15.342857142857143, max: 62)
#
# Run: 36, exploration: 0.08490939117940327, score: 10
# Scores: (min: 9, avg: 15.194444444444445, max: 62)
#
# Run: 37, exploration: 0.07836551983717477, score: 17
# Scores: (min: 9, avg: 15.243243243243244, max: 62)
#
# Run: 38, exploration: 0.0716045256805401, score: 19
# Scores: (min: 9, avg: 15.342105263157896, max: 62)
#
# Run: 39, exploration: 0.058010934765067, score: 43
# Scores: (min: 9, avg: 16.05128205128205, max: 62)
#
# Run: 40, exploration: 0.05327239673939179, score: 18
# Scores: (min: 9, avg: 16.1, max: 62)
#
# Run: 41, exploration: 0.05066791621302729, score: 11
# Scores: (min: 9, avg: 15.975609756097562, max: 62)
#
# Run: 42, exploration: 0.048432933065126825, score: 10
# Scores: (min: 9, avg: 15.833333333333334, max: 62)
#
# Run: 43, exploration: 0.046065053286412784, score: 11
# Scores: (min: 9, avg: 15.720930232558139, max: 62)
#
# Run: 44, exploration: 0.03904210656169572, score: 34
# Scores: (min: 9, avg: 16.136363636363637, max: 62)
#
# Run: 45, exploration: 0.037133343065552986, score: 11
# Scores: (min: 9, avg: 16.022222222222222, max: 62)
#
# Run: 46, exploration: 0.032433008066058915, score: 28
# Scores: (min: 9, avg: 16.282608695652176, max: 62)
#
# Run: 47, exploration: 0.0279048474362789, score: 31
# Scores: (min: 9, avg: 16.595744680851062, max: 62)
#
# Run: 48, exploration: 0.026275840769466357, score: 13
# Scores: (min: 9, avg: 16.520833333333332, max: 62)
#
# Run: 49, exploration: 0.022494281437179946, score: 32
# Scores: (min: 9, avg: 16.836734693877553, max: 62)
#
# Run: 50, exploration: 0.015523158778943369, score: 75
# Scores: (min: 9, avg: 18, max: 75)
#
# Run: 51, exploration: 0.014398800381387675, score: 16
# Scores: (min: 9, avg: 17.96078431372549, max: 75)
#
# Run: 52, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 20.53846153846154, max: 152)
#
# Run: 53, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 20.49056603773585, max: 152)
#
# Run: 54, exploration: 0.01, score: 51
# Scores: (min: 9, avg: 21.055555555555557, max: 152)
#
# Run: 55, exploration: 0.01, score: 115
# Scores: (min: 9, avg: 22.763636363636362, max: 152)
#
# Run: 56, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 22.678571428571427, max: 152)
#
# Run: 57, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 22.719298245614034, max: 152)
#
# Run: 58, exploration: 0.01, score: 69
# Scores: (min: 9, avg: 23.517241379310345, max: 152)
#
# Run: 59, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 23.54237288135593, max: 152)
#
# Run: 60, exploration: 0.01, score: 46
# Scores: (min: 9, avg: 23.916666666666668, max: 152)
#
# Run: 61, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 23.770491803278688, max: 152)
#
# Run: 62, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 23.85483870967742, max: 152)
#
# Run: 63, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 23.96825396825397, max: 152)
#
# Run: 64, exploration: 0.01, score: 49
# Scores: (min: 9, avg: 24.359375, max: 152)
#
# Run: 65, exploration: 0.01, score: 62
# Scores: (min: 9, avg: 24.93846153846154, max: 152)
#
# Run: 66, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 25.075757575757574, max: 152)
#
# Run: 67, exploration: 0.01, score: 109
# Scores: (min: 9, avg: 26.328358208955223, max: 152)
#
# Run: 68, exploration: 0.01, score: 161
# Scores: (min: 9, avg: 28.308823529411764, max: 161)
#
# Run: 69, exploration: 0.01, score: 42
# Scores: (min: 9, avg: 28.507246376811594, max: 161)
#
# Run: 70, exploration: 0.01, score: 45
# Scores: (min: 9, avg: 28.742857142857144, max: 161)
#
# Run: 71, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 28.507042253521128, max: 161)
#
# Run: 72, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 28.26388888888889, max: 161)
#
# Run: 73, exploration: 0.01, score: 95
# Scores: (min: 9, avg: 29.17808219178082, max: 161)
#
# Run: 74, exploration: 0.01, score: 65
# Scores: (min: 9, avg: 29.66216216216216, max: 161)
#
# Run: 75, exploration: 0.01, score: 37
# Scores: (min: 9, avg: 29.76, max: 161)
#
# Run: 76, exploration: 0.01, score: 62
# Scores: (min: 9, avg: 30.18421052631579, max: 161)
#
# Run: 77, exploration: 0.01, score: 46
# Scores: (min: 9, avg: 30.38961038961039, max: 161)
#
# Run: 78, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 30.205128205128204, max: 161)
#
# Run: 79, exploration: 0.01, score: 35
# Scores: (min: 9, avg: 30.265822784810126, max: 161)
#
# Run: 80, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 30.1125, max: 161)
#
# Run: 81, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 30.037037037037038, max: 161)
#
# Run: 82, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 30.085365853658537, max: 161)
#
# Run: 83, exploration: 0.01, score: 56
# Scores: (min: 9, avg: 30.397590361445783, max: 161)
#
# Run: 84, exploration: 0.01, score: 38
# Scores: (min: 9, avg: 30.488095238095237, max: 161)
#
# Run: 85, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 30.529411764705884, max: 161)
#
# Run: 86, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 30.569767441860463, max: 161)
# Run: 87, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 30.448275862068964, max: 161)
#
# Run: 88, exploration: 0.01, score: 59
# Scores: (min: 9, avg: 30.772727272727273, max: 161)
#
# Run: 89, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 30.651685393258425, max: 161)
#
# Run: 90, exploration: 0.01, score: 65
# Scores: (min: 9, avg: 31.033333333333335, max: 161)
#
# Run: 91, exploration: 0.01, score: 58
# Scores: (min: 9, avg: 31.32967032967033, max: 161)
#
# Run: 92, exploration: 0.01, score: 74
# Scores: (min: 9, avg: 31.793478260869566, max: 161)
#
# Run: 93, exploration: 0.01, score: 74
# Scores: (min: 9, avg: 32.24731182795699, max: 161)
#
# Run: 94, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 32.1063829787234, max: 161)
#
# Run: 95, exploration: 0.01, score: 99
# Scores: (min: 9, avg: 32.810526315789474, max: 161)
#
# Run: 96, exploration: 0.01, score: 59
# Scores: (min: 9, avg: 33.083333333333336, max: 161)
#
# Run: 97, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 32.845360824742265, max: 161)
#
# Run: 98, exploration: 0.01, score: 80
# Scores: (min: 9, avg: 33.326530612244895, max: 161)
#
# Run: 99, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 33.101010101010104, max: 161)
#
# Run: 100, exploration: 0.01, score: 78
# Scores: (min: 9, avg: 33.55, max: 161)
#
# Run: 101, exploration: 0.01, score: 47
# Scores: (min: 9, avg: 33.82, max: 161)
#
# Run: 102, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 33.46, max: 161)
#
# Run: 103, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 33.34, max: 161)
#
# Run: 104, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 33.27, max: 161)
#
# Run: 105, exploration: 0.01, score: 89
# Scores: (min: 8, avg: 34.01, max: 161)
#
# Run: 106, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 34.24, max: 161)
#
# Run: 107, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 34.5, max: 161)
#
# Run: 108, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 34.34, max: 161)
#
# Run: 109, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 34.38, max: 161)
#
# Run: 110, exploration: 0.01, score: 148
# Scores: (min: 8, avg: 35.76, max: 161)
#
# Run: 111, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 35.97, max: 161)
#
# Run: 112, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 36.4, max: 161)
#
# Run: 113, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 36.89, max: 161)
#
# Run: 114, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 36.98, max: 161)
#
# Run: 115, exploration: 0.01, score: 78
# Scores: (min: 8, avg: 37.65, max: 161)
#
# Run: 116, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 37.67, max: 161)
#
# Run: 117, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 38.1, max: 161)
#
# Run: 118, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 38.49, max: 161)
#
# Run: 119, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 38.92, max: 161)
#
# Run: 120, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 39.24, max: 161)
#
# Run: 121, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 39.43, max: 161)
#
# Run: 122, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 39.39, max: 161)
#
# Run: 123, exploration: 0.01, score: 92
# Scores: (min: 8, avg: 40.2, max: 161)
#
# Run: 124, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 40.66, max: 161)
#
# Run: 125, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 41.06, max: 161)
#
# Run: 126, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 41.39, max: 161)
#
# Run: 127, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 41.42, max: 161)
#
# Run: 128, exploration: 0.01, score: 106
# Scores: (min: 8, avg: 42.39, max: 161)
#
# Run: 129, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 42.68, max: 161)
#
# Run: 130, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 42.16, max: 161)
#
# Run: 131, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 42.07, max: 161)
#
# Run: 132, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 42.51, max: 161)
#
# Run: 133, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 42.97, max: 161)
#
# Run: 134, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 43.14, max: 161)
#
# Run: 135, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 43.68, max: 161)
#
# Run: 136, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 43.8, max: 161)
#
# Run: 137, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 43.88, max: 161)
#
# Run: 138, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 44.42, max: 161)
#
# Run: 139, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 44.42, max: 161)
#
# Run: 140, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 45.04, max: 161)
#
# Run: 141, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 45.46, max: 161)
#
# Run: 142, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 45.55, max: 161)
#
# Run: 143, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 45.63, max: 161)
#
# Run: 144, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 45.39, max: 161)
#
# Run: 145, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 45.58, max: 161)
#
# Run: 146, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 45.71, max: 161)
#
# Run: 147, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 45.62, max: 161)
#
# Run: 148, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 45.6, max: 161)
#
# Run: 149, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 46.39, max: 161)
#
# Run: 150, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 45.82, max: 161)
#
# Run: 151, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 45.76, max: 161)
#
# Run: 152, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 44.36, max: 161)
#
# Run: 153, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 44.27, max: 161)
#
# Run: 154, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 43.87, max: 161)
#
# Run: 155, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 42.8, max: 161)
#
# Run: 156, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 42.72, max: 161)
#
# Run: 157, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 42.57, max: 161)
#
# Run: 158, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 42.05, max: 161)
#
# Run: 159, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 41.89, max: 161)
#
# Run: 160, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 41.51, max: 161)
#
# Run: 161, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 41.46, max: 161)
#
# Run: 162, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 41.27, max: 161)
#
# Run: 163, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 41.05, max: 161)
#
# Run: 164, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 40.64, max: 161)
#
# Run: 165, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 40.12, max: 161)
#
# Run: 166, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 39.89, max: 161)
#
# Run: 167, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 38.91, max: 161)
#
# Run: 168, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 37.46, max: 148)
#
# Run: 169, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 37.35, max: 148)
#
# Run: 170, exploration: 0.01, score: 105
# Scores: (min: 8, avg: 37.95, max: 148)
#
# Run: 171, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 38.59, max: 148)
#
# Run: 172, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 38.58, max: 148)
#
# Run: 173, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 38.36, max: 148)
#
# Run: 174, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 38.42, max: 148)
#
# Run: 175, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 38.29, max: 148)
#
# Run: 176, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 37.89, max: 148)
#
# Run: 177, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 37.54, max: 148)
#
# Run: 178, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 37.81, max: 148)
#
# Run: 179, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 38.14, max: 148)
#
# Run: 180, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 38.2, max: 148)
#
# Run: 181, exploration: 0.01, score: 78
# Scores: (min: 8, avg: 38.74, max: 148)
#
# Run: 182, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 38.94, max: 148)
#
# Run: 183, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 38.5, max: 148)
#
# Run: 184, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 38.85, max: 148)
#
# Run: 185, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 38.64, max: 148)
#
# Run: 186, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 38.48, max: 148)
#
# Run: 187, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 38.49, max: 148)
#
# Run: 188, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 38.64, max: 148)
# Run: 189, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 38.73, max: 148)
#
# Run: 190, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 38.25, max: 148)
#
# Run: 191, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 37.96, max: 148)
#
# Run: 192, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 37.48, max: 148)
#
# Run: 193, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 36.99, max: 148)
#
# Run: 194, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 36.9, max: 148)
#
# Run: 195, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 36.49, max: 148)
#
# Run: 196, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 36.31, max: 148)
#
# Run: 197, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 36.78, max: 148)
#
# Run: 198, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 36.18, max: 148)
#
# Run: 199, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 36.61, max: 148)
#
# Run: 200, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 35.93, max: 148)
#
# Run: 201, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 36.16, max: 148)
#
# Run: 202, exploration: 0.01, score: 121
# Scores: (min: 8, avg: 37.28, max: 148)
#
# Run: 203, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 38.64, max: 149)
#
# Run: 204, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 38.8, max: 149)
#
# Run: 205, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 38.36, max: 149)
#
# Run: 206, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 38.57, max: 149)
#
# Run: 207, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 39.12, max: 149)
#
# Run: 208, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 39.46, max: 149)
#
# Run: 209, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 39.46, max: 149)
#
# Run: 210, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 38.88, max: 149)
#
# Run: 211, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 38.76, max: 149)
#
# Run: 212, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 38.53, max: 149)
#
# Run: 213, exploration: 0.01, score: 140
# Scores: (min: 8, avg: 39.33, max: 149)
#
# Run: 214, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 39.46, max: 149)
#
# Run: 215, exploration: 0.01, score: 143
# Scores: (min: 8, avg: 40.11, max: 149)
#
# Run: 216, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 40.14, max: 149)
#
# Run: 217, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 39.81, max: 149)
#
# Run: 218, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 39.56, max: 149)
#
# Run: 219, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 39.14, max: 149)
#
# Run: 220, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 38.94, max: 149)
#
# Run: 221, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 38.8, max: 149)
#
# Run: 222, exploration: 0.01, score: 134
# Scores: (min: 8, avg: 40.04, max: 149)
#
# Run: 223, exploration: 0.01, score: 193
# Scores: (min: 8, avg: 41.05, max: 193)
#
# Run: 224, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 41.39, max: 193)
#
# Run: 225, exploration: 0.01, score: 117
# Scores: (min: 8, avg: 42.05, max: 193)
#
# Run: 226, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 42.13, max: 193)
#
# Run: 227, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 42.19, max: 193)
#
# Run: 228, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 41.46, max: 193)
#
# Run: 229, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 41.28, max: 193)
#
# Run: 230, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 41.28, max: 193)
#
# Run: 231, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 41.29, max: 193)
#
# Run: 232, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 40.9, max: 193)
#
# Run: 233, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 40.43, max: 193)
#
# Run: 234, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 40.67, max: 193)
#
# Run: 235, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 40.28, max: 193)
#
# Run: 236, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 40.24, max: 193)
#
# Run: 237, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 40.31, max: 193)
#
# Run: 238, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 39.94, max: 193)
#
# Run: 239, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 40.35, max: 193)
#
# Run: 240, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 40.02, max: 193)
#
# Run: 241, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 39.63, max: 193)
#
# Run: 242, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 39.7, max: 193)
#
# Run: 243, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 39.61, max: 193)
#
# Run: 244, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 39.66, max: 193)
#
# Run: 245, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 39.64, max: 193)
#
# Run: 246, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 40.79, max: 193)
#
# Run: 247, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 41.31, max: 193)
#
# Run: 248, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 41.29, max: 193)
#
# Run: 249, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 40.46, max: 193)
#
# Run: 250, exploration: 0.01, score: 135
# Scores: (min: 8, avg: 41.63, max: 193)
#
# Run: 251, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 41.81, max: 193)
#
# Run: 252, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 42.02, max: 193)
#
# Run: 253, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 42.02, max: 193)
#
# Run: 254, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 42.16, max: 193)
#
# Run: 255, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 42.39, max: 193)
#
# Run: 256, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 42.53, max: 193)
#
# Run: 257, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 42.98, max: 193)
#
# Run: 258, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 42.98, max: 193)
#
# Run: 259, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 43.05, max: 193)
#
# Run: 260, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 43.09, max: 193)
#
# Run: 261, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 43.19, max: 193)
#
# Run: 262, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 43.35, max: 193)
#
# Run: 263, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 43.45, max: 193)
#
# Run: 264, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 43.61, max: 193)
#
# Run: 265, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 43.79, max: 193)
#
# Run: 266, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 44.76, max: 193)
#
# Run: 267, exploration: 0.01, score: 140
# Scores: (min: 8, avg: 46.05, max: 193)
#
# Run: 268, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 46, max: 193)
#
# Run: 269, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 45.79, max: 193)
#
# Run: 270, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 44.83, max: 193)
#
# Run: 271, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 44.16, max: 193)
#
# Run: 272, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 44.16, max: 193)
#
# Run: 273, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 43.53, max: 193)
#
# Run: 274, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 42.97, max: 193)
#
# Run: 275, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 42.83, max: 193)
#
# Run: 276, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 42.69, max: 193)
#
# Run: 277, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 42.68, max: 193)
#
# Run: 278, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 42.34, max: 193)
#
# Run: 279, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 41.76, max: 193)
#
# Run: 280, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 41.62, max: 193)
#
# Run: 281, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 40.94, max: 193)
#
# Run: 282, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 40.49, max: 193)
#
# Run: 283, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 40.46, max: 193)
#
# Run: 284, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 39.83, max: 193)
#
# Run: 285, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 39.79, max: 193)
#
# Run: 286, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 39.8, max: 193)
#
# Run: 287, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 39.68, max: 193)
#
# Run: 288, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 39.03, max: 193)
#
# Run: 289, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 38.82, max: 193)
#
# Run: 290, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 38.75, max: 193)
#
# Run: 291, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 38.55, max: 193)
#
# Run: 292, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 38.39, max: 193)
# Run: 293, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 38.23, max: 193)
#
# Run: 294, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 38.21, max: 193)
#
# Run: 295, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 37.73, max: 193)
#
# Run: 296, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 37.42, max: 193)
#
# Run: 297, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 36.95, max: 193)
#
# Run: 298, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 36.84, max: 193)
#
# Run: 299, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 36.69, max: 193)
#
# Run: 300, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 37.09, max: 193)
#
# Run: 301, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 36.49, max: 193)
#
# Run: 302, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 35.38, max: 193)
#
# Run: 303, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 33.98, max: 193)
#
# Run: 304, exploration: 0.01, score: 115
# Scores: (min: 8, avg: 34.89, max: 193)
#
# Run: 305, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 34.8, max: 193)
#
# Run: 306, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 34.36, max: 193)
#
# Run: 307, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 33.52, max: 193)
#
# Run: 308, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 33.47, max: 193)
#
# Run: 309, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 33.57, max: 193)
#
# Run: 310, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 32.77, max: 193)
#
# Run: 311, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 32.54, max: 193)
#
# Run: 312, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 32.32, max: 193)
#
# Run: 313, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.02, max: 193)
#
# Run: 314, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 30.83, max: 193)
#
# Run: 315, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 29.58, max: 193)
#
# Run: 316, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 29.56, max: 193)
#
# Run: 317, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 29.49, max: 193)
#
# Run: 318, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 30.28, max: 193)
#
# Run: 319, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 30.35, max: 193)
#
# Run: 320, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 30.65, max: 193)
#
# Run: 321, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 31.21, max: 193)
#
# Run: 322, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.97, max: 193)
#
# Run: 323, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 28.13, max: 156)
#
# Run: 324, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 27.32, max: 156)
#
# Run: 325, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 26.27, max: 156)
#
# Run: 326, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 25.99, max: 156)
#
# Run: 327, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 25.99, max: 156)
#
# Run: 328, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 25.78, max: 156)
#
# Run: 329, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 25.76, max: 156)
#
# Run: 330, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.75, max: 156)
#
# Run: 331, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.74, max: 156)
#
# Run: 332, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 25.73, max: 156)
#
# Run: 333, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 25.82, max: 156)
#
# Run: 334, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 25.42, max: 156)
#
# Run: 335, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 25.29, max: 156)
#
# Run: 336, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 25.35, max: 156)
#
# Run: 337, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 25.39, max: 156)
#
# Run: 338, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 25.15, max: 156)
#
# Run: 339, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 24.89, max: 156)
#
# Run: 340, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 24.64, max: 156)
#
# Run: 341, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 25.02, max: 156)
#
# Run: 342, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 25.2, max: 156)
#
# Run: 343, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 25.68, max: 156)
#
# Run: 344, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 25.65, max: 156)
#
# Run: 345, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.46, max: 156)
#
# Run: 346, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 24.03, max: 140)
#
# Run: 347, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 23.57, max: 140)
#
# Run: 348, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 23.6, max: 140)
#
# Run: 349, exploration: 0.01, score: 91
# Scores: (min: 8, avg: 24.23, max: 140)
#
# Run: 350, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 24.26, max: 140)
#
# Run: 351, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 24.28, max: 140)
#
# Run: 352, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 24.07, max: 140)
#
# Run: 353, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 24.09, max: 140)
#
# Run: 354, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 24.02, max: 140)
#
# Run: 355, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 24.05, max: 140)
#
# Run: 356, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 24.33, max: 140)
#
# Run: 357, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 23.92, max: 140)
#
# Run: 358, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 23.97, max: 140)
#
# Run: 359, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.91, max: 140)
#
# Run: 360, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 23.99, max: 140)
#
# Run: 361, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 24.04, max: 140)
#
# Run: 362, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 24.01, max: 140)
#
# Run: 363, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 24.03, max: 140)
#
# Run: 364, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 23.98, max: 140)
#
# Run: 365, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 24.16, max: 140)
#
# Run: 366, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 23.48, max: 140)
#
# Run: 367, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 22.16, max: 138)
#
# Run: 368, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 22.41, max: 138)
#
# Run: 369, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 22.51, max: 138)
#
# Run: 370, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 22.5, max: 138)
#
# Run: 371, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 22.63, max: 138)
#
# Run: 372, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 22.82, max: 138)
#
# Run: 373, exploration: 0.01, score: 86
# Scores: (min: 8, avg: 23.58, max: 138)
#
# Run: 374, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 23.52, max: 138)
#
# Run: 375, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 23.58, max: 138)
#
# Run: 376, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 23.92, max: 138)
#
# Run: 377, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.92, max: 138)
#
# Run: 378, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.93, max: 138)
#
# Run: 379, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 24.02, max: 138)
#
# Run: 380, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 24.11, max: 138)
#
# Run: 381, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 24.17, max: 138)
#
# Run: 382, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 24.28, max: 138)
#
# Run: 383, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 24.38, max: 138)
#
# Run: 384, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 24.38, max: 138)
#
# Run: 385, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 24.48, max: 138)
#
# Run: 386, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 24.39, max: 138)
#
# Run: 387, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 24.4, max: 138)
#
# Run: 388, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 24.46, max: 138)
#
# Run: 389, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 24.59, max: 138)
#
# Run: 390, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 24.65, max: 138)
#
# Run: 391, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 24.65, max: 138)
#
# Run: 392, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 24.67, max: 138)
#
# Run: 393, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 24.71, max: 138)
#
# Run: 394, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 24.72, max: 138)
#
# Run: 395, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 24.78, max: 138)
#
# Run: 396, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 24.8, max: 138)
# Run: 397, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 24.85, max: 138)
#
# Run: 398, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 25.09, max: 138)
#
# Run: 399, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 24.9, max: 138)
#
# Run: 400, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 24.56, max: 138)
#
# Run: 401, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 24.61, max: 138)
#
# Run: 402, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 24.61, max: 138)
#
# Run: 403, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 24.73, max: 138)
#
# Run: 404, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 23.81, max: 138)
#
# Run: 405, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 23.59, max: 138)
#
# Run: 406, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 23.6, max: 138)
#
# Run: 407, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 23.79, max: 138)
#
# Run: 408, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 23.51, max: 138)
#
# Run: 409, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 23.44, max: 138)
#
# Run: 410, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 23.45, max: 138)
#
# Run: 411, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 23.62, max: 138)
#
# Run: 412, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 23.65, max: 138)
#
# Run: 413, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 23.72, max: 138)
#
# Run: 414, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 23.64, max: 138)
#
# Run: 415, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 23.64, max: 138)
#
# Run: 416, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 23.57, max: 138)
#
# Run: 417, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 23.55, max: 138)
#
# Run: 418, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 22.65, max: 138)
#
# Run: 419, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 22.66, max: 138)
#
# Run: 420, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 22.22, max: 138)
#
# Run: 421, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 21.69, max: 138)
#
# Run: 422, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 21.8, max: 138)
#
# Run: 423, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 21.83, max: 138)
#
# Run: 424, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 22.19, max: 138)
#
# Run: 425, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 22.28, max: 138)
#
# Run: 426, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 22.17, max: 138)
#
# Run: 427, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.09, max: 138)
#
# Run: 428, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 22.18, max: 138)
#
# Run: 429, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 22.12, max: 138)
#
# Run: 430, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.12, max: 138)
#
# Run: 431, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 22.16, max: 138)
#
# Run: 432, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 22.21, max: 138)
#
# Run: 433, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 22.23, max: 138)
#
# Run: 434, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 22.27, max: 138)
#
# Run: 435, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 22.36, max: 138)
#
# Run: 436, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 22.21, max: 138)
#
# Run: 437, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.95, max: 138)
#
# Run: 438, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 21.93, max: 138)
#
# Run: 439, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 21.61, max: 138)
#
# Run: 440, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 21.66, max: 138)
#
# Run: 441, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 21.38, max: 138)
#
# Run: 442, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 21.07, max: 138)
#
# Run: 443, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 20.71, max: 138)
#
# Run: 444, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 20.9, max: 138)
#
# Run: 445, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 20.89, max: 138)
#
# Run: 446, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 20.93, max: 138)
#
# Run: 447, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 20.85, max: 138)
#
# Run: 448, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 20.87, max: 138)
#
# Run: 449, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 20.06, max: 138)
#
# Run: 450, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 18.8, max: 86)
#
# Run: 451, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 18.63, max: 86)
#
# Run: 452, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 18.66, max: 86)
#
# Run: 453, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.65, max: 86)
#
# Run: 454, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 18.55, max: 86)
#
# Run: 455, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 18.43, max: 86)
#
# Run: 456, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 18.2, max: 86)
#
# Run: 457, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 18.17, max: 86)
#
# Run: 458, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 18.2, max: 86)
#
# Run: 459, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 18.22, max: 86)
#
# Run: 460, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.12, max: 86)
#
# Run: 461, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 18.05, max: 86)
#
# Run: 462, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 17.96, max: 86)
#
# Run: 463, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 18.02, max: 86)
#
# Run: 464, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 18.08, max: 86)
#
# Run: 465, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 17.79, max: 86)
#
# Run: 466, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 17.69, max: 86)
#
# Run: 467, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.73, max: 86)
#
# Run: 468, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 17.78, max: 86)
#
# Run: 469, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17.69, max: 86)
#
# Run: 470, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 18.1, max: 86)
#
# Run: 471, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 18.02, max: 86)
#
# Run: 472, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 17.88, max: 86)
#
# Run: 473, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 17.31, max: 49)
#
# Run: 474, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 17.51, max: 49)
#
# Run: 475, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 17.68, max: 49)
#
# Run: 476, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 17.39, max: 49)
#
# Run: 477, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 17.4, max: 49)
#
# Run: 478, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 17.49, max: 49)
#
# Run: 479, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.4, max: 49)
#
# Run: 480, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 17.34, max: 49)
#
# Run: 481, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 17.31, max: 49)
#
# Run: 482, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 17.43, max: 49)
#
# Run: 483, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 17.54, max: 49)
#
# Run: 484, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 17.65, max: 49)
#
# Run: 485, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 17.68, max: 49)
#
# Run: 486, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 17.66, max: 49)
#
# Run: 487, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 17.7, max: 49)
#
# Run: 488, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 18.2, max: 65)
#
# Run: 489, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 18.24, max: 65)
#
# Run: 490, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 18.39, max: 65)
#
# Run: 491, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 18.7, max: 65)
#
# Run: 492, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 19.03, max: 65)
#
# Run: 493, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 19.02, max: 65)
#
# Run: 494, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.03, max: 65)
#
# Run: 495, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 18.99, max: 65)
#
# Run: 496, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 19.05, max: 65)
#
# Run: 497, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 19.15, max: 65)
#
# Run: 498, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 18.97, max: 65)
#
# Run: 499, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 18.94, max: 65)
#
# Run: 500, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 18.9, max: 65)
#
# Run: 501, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.85, max: 65)
# Run: 502, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 18.9, max: 65)
#
# Run: 503, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 18.83, max: 65)
#
# Run: 504, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 18.71, max: 65)
#
# Run: 505, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 18.65, max: 65)
#
# Run: 506, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 18.76, max: 65)
#
# Run: 507, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 18.72, max: 65)
#
# Run: 508, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 19.03, max: 65)
#
# Run: 509, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 18.99, max: 65)
#
# Run: 510, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 19.01, max: 65)
#
# Run: 511, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 18.96, max: 65)
#
# Run: 512, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 19.06, max: 65)
#
# Run: 513, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 19.06, max: 65)
#
# Run: 514, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 19.03, max: 65)
#
# Run: 515, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 18.97, max: 65)
#
# Run: 516, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.86, max: 65)
#
# Run: 517, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 18.9, max: 65)
#
# Run: 518, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 19.01, max: 65)
#
# Run: 519, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 18.98, max: 65)
#
# Run: 520, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 19.05, max: 65)
#
# Run: 521, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 19.49, max: 65)
#
# Run: 522, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 19.36, max: 65)
#
# Run: 523, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 19.37, max: 65)
#
# Run: 524, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.01, max: 65)
#
# Run: 525, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 18.99, max: 65)
#
# Run: 526, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 19.02, max: 65)
#
# Run: 527, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.01, max: 65)
#
# Run: 528, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 18.95, max: 65)
#
# Run: 529, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 18.94, max: 65)
#
# Run: 530, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 19.02, max: 65)
#
# Run: 531, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 19.13, max: 65)
#
# Run: 532, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.05, max: 65)
#
# Run: 533, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 18.97, max: 65)
#
# Run: 534, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.88, max: 65)
#
# Run: 535, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.78, max: 65)
#
# Run: 536, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 19.06, max: 65)
#
# Run: 537, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 19.07, max: 65)
#
# Run: 538, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 19.07, max: 65)
#
# Run: 539, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 18.94, max: 65)
#
# Run: 540, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 18.85, max: 65)
#
# Run: 541, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 18.77, max: 65)
#
# Run: 542, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 18.81, max: 65)
#
# Run: 543, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.68, max: 65)
#
# Run: 544, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 18.54, max: 65)
#
# Run: 545, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 18.54, max: 65)
#
# Run: 546, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 18.52, max: 65)
#
# Run: 547, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 18.64, max: 65)
#
# Run: 548, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 18.69, max: 65)
#
# Run: 549, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 18.71, max: 65)
#
# Run: 550, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 18.71, max: 65)
#
# Run: 551, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 18.72, max: 65)
#
# Run: 552, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 18.98, max: 65)
#
# Run: 553, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 19.04, max: 65)
#
# Run: 554, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 19.42, max: 65)
#
# Run: 555, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.29, max: 65)
#
# Run: 556, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 19.13, max: 65)
#
# Run: 557, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.11, max: 65)
#
# Run: 558, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.95, max: 65)
#
# Run: 559, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 19.01, max: 65)
#
# Run: 560, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 19.02, max: 65)
#
# Run: 561, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 19.14, max: 65)
#
# Run: 562, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.09, max: 65)
#
# Run: 563, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 19.02, max: 65)
#
# Run: 564, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.86, max: 65)
#
# Run: 565, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 18.97, max: 65)
#
# Run: 566, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 18.84, max: 65)
#
# Run: 567, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 18.85, max: 65)
#
# Run: 568, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 18.58, max: 65)
#
# Run: 569, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 18.61, max: 65)
#
# Run: 570, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 18.31, max: 65)
#
# Run: 571, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 18.31, max: 65)
#
# Run: 572, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 18.47, max: 65)
#
# Run: 573, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 18.37, max: 65)
#
# Run: 574, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.17, max: 65)
#
# Run: 575, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.96, max: 65)
#
# Run: 576, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.93, max: 65)
#
# Run: 577, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.94, max: 65)
#
# Run: 578, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 18.43, max: 68)
#
# Run: 579, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 18.56, max: 68)
#
# Run: 580, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 18.54, max: 68)
#
# Run: 581, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 18.57, max: 68)
#
# Run: 582, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 18.45, max: 68)
#
# Run: 583, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 18.24, max: 68)
#
# Run: 584, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 18.51, max: 68)
#
# Run: 585, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 18.43, max: 68)
#
# Run: 586, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 18.6, max: 68)
#
# Run: 587, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 18.9, max: 68)
#
# Run: 588, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 18.36, max: 68)
#
# Run: 589, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 18.39, max: 68)
#
# Run: 590, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 18.33, max: 68)
#
# ...
#
# Run: 1106, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.04, max: 55)
#
# Run: 1107, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 12.07, max: 55)
#
# Run: 1108, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 12.03, max: 55)
#
# Run: 1109, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.97, max: 55)
#
# Run: 1110, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.98, max: 55)
#
# Run: 1111, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.59, max: 55)
#
# Run: 1112, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.56, max: 55)
#
# Run: 1113, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.51, max: 55)
#
# Run: 1114, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.5, max: 55)
#
# Run: 1115, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.52, max: 55)
#
# Run: 1116, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.52, max: 55)
#
# Run: 1117, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.5, max: 55)
#
# Run: 1118, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.45, max: 55)
#
# Run: 1119, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.45, max: 55)
#
# Run: 1120, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.38, max: 55)
#
# Run: 1121, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.92, max: 38)
#
# Run: 1122, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.93, max: 38)
#
# Run: 1123, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.94, max: 38)
#
# Run: 1124, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.95, max: 38)
#
# Run: 1125, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.96, max: 38)
#
# Run: 1126, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.87, max: 38)
#
# Run: 1127, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.77, max: 38)
#
# Run: 1128, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.58, max: 38)
#
# Run: 1129, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.29, max: 32)
#
# Run: 1130, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 10.25, max: 32)
#
# Run: 1131, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.25, max: 32)
#
# Run: 1132, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.25, max: 32)
#
# Run: 1133, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.15, max: 32)
#
# Run: 1134, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.1, max: 32)
#
# Run: 1135, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.86, max: 19)
# Run: 1136, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.76, max: 17)
#
# Run: 1137, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.76, max: 17)
#
# Run: 1138, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.7, max: 17)
#
# Run: 1139, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.69, max: 17)
#
# Run: 1140, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.65, max: 17)
#
# Run: 1141, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.57, max: 13)
#
# Run: 1142, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.58, max: 13)
#
# Run: 1143, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.58, max: 13)
#
# Run: 1144, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.58, max: 13)
#
# Run: 1145, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.57, max: 13)
#
# Run: 1146, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.57, max: 13)
#
# Run: 1147, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.58, max: 13)
#
# Run: 1148, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.57, max: 13)
#
# Run: 1149, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.58, max: 13)
#
# Run: 1150, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.58, max: 13)
#
# Run: 1151, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.59, max: 13)
#
# Run: 1152, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.58, max: 13)
#
# Run: 1153, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.59, max: 13)
#
# Run: 1154, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.59, max: 13)
#
# Run: 1155, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.59, max: 13)
#
# Run: 1156, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.58, max: 13)
#
# Run: 1157, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.59, max: 13)
#
# Run: 1158, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.6, max: 13)
#
# Run: 1159, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.59, max: 13)
#
# Run: 1160, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.59, max: 13)
#
# Run: 1161, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 9.74, max: 25)
#
# Run: 1162, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 9.91, max: 26)
#
# Run: 1163, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 10.02, max: 26)
#
# Run: 1164, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 10.22, max: 30)
#
# Run: 1165, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 10.3, max: 30)
#
# Run: 1166, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 10.44, max: 30)
#
# Run: 1167, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 10.49, max: 30)
#
# Run: 1168, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 10.67, max: 30)
#
# Run: 1169, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 10.77, max: 30)
#
# Run: 1170, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 10.91, max: 30)
#
# Run: 1171, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 11, max: 30)
#
# Run: 1172, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 11.18, max: 30)
#
# Run: 1173, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 11.4, max: 31)
#
# Run: 1174, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 11.63, max: 31)
#
# Run: 1175, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 11.79, max: 31)
#
# Run: 1176, exploration: 0.01, score: 96
# Scores: (min: 8, avg: 12.66, max: 96)
#
# Run: 1177, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 13.19, max: 96)
#
# Run: 1178, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 13.64, max: 96)
#
# Run: 1179, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 13.78, max: 96)
#
# Run: 1180, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 14.4, max: 96)
#
# Run: 1181, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 14.57, max: 96)
#
# Run: 1182, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 14.75, max: 96)
#
# Run: 1183, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 14.95, max: 96)
#
# Run: 1184, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 15.37, max: 96)
#
# Run: 1185, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 15.68, max: 96)
#
# Run: 1186, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 15.9, max: 96)
#
# Run: 1187, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 16.32, max: 96)
#
# Run: 1188, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 16.6, max: 96)
#
# Run: 1189, exploration: 0.01, score: 129
# Scores: (min: 8, avg: 17.79, max: 129)
#
# Run: 1190, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 18.63, max: 129)
#
# Run: 1191, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 18.8, max: 129)
#
# Run: 1192, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 19, max: 129)
#
# Run: 1193, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 19.23, max: 129)
#
# Run: 1194, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 19.8, max: 129)
#
# Run: 1195, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 20.39, max: 129)
#
# Run: 1196, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 20.64, max: 129)
#
# Run: 1197, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 21.48, max: 129)
#
# Run: 1198, exploration: 0.01, score: 86
# Scores: (min: 8, avg: 22.25, max: 129)
#
# Run: 1199, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 22.26, max: 129)
#
# Run: 1200, exploration: 0.01, score: 87
# Scores: (min: 8, avg: 23.03, max: 129)
#
# Run: 1201, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 23.51, max: 129)
#
# Run: 1202, exploration: 0.01, score: 116
# Scores: (min: 8, avg: 24.57, max: 129)
#
# Run: 1203, exploration: 0.01, score: 134
# Scores: (min: 8, avg: 25.82, max: 134)
#
# Run: 1204, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 27.28, max: 156)
#
# Run: 1205, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 27.86, max: 156)
#
# Run: 1206, exploration: 0.01, score: 102
# Scores: (min: 8, avg: 28.78, max: 156)
#
# Run: 1207, exploration: 0.01, score: 81
# Scores: (min: 8, avg: 29.47, max: 156)
#
# Run: 1208, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 30.41, max: 156)
#
# Run: 1209, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 32.14, max: 181)
#
# Run: 1210, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 33.56, max: 181)
#
# Run: 1211, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 35.03, max: 181)
#
# Run: 1212, exploration: 0.01, score: 196
# Scores: (min: 8, avg: 36.9, max: 196)
#
# Run: 1213, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 38.26, max: 196)
#
# Run: 1214, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 38.48, max: 196)
#
# Run: 1215, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 38.79, max: 196)
#
# Run: 1216, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 39.13, max: 196)
#
# Run: 1217, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 39.41, max: 196)
#
# Run: 1218, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 39.73, max: 196)
#
# Run: 1219, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 40.08, max: 196)
#
# Run: 1220, exploration: 0.01, score: 86
# Scores: (min: 8, avg: 40.84, max: 196)
#
# Run: 1221, exploration: 0.01, score: 256
# Scores: (min: 8, avg: 43.31, max: 256)
#
# Run: 1222, exploration: 0.01, score: 154
# Scores: (min: 8, avg: 44.75, max: 256)
#
# Run: 1223, exploration: 0.01, score: 298
# Scores: (min: 8, avg: 47.63, max: 298)
#
# Run: 1224, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 48.8, max: 298)
#
# Run: 1225, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 49.8, max: 298)
#
# Run: 1226, exploration: 0.01, score: 118
# Scores: (min: 8, avg: 50.9, max: 298)
#
# Run: 1227, exploration: 0.01, score: 142
# Scores: (min: 8, avg: 52.23, max: 298)
#
# Run: 1228, exploration: 0.01, score: 170
# Scores: (min: 8, avg: 53.83, max: 298)
#
# Run: 1229, exploration: 0.01, score: 400
# Scores: (min: 8, avg: 57.74, max: 400)
#
# Run: 1230, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 58.89, max: 400)
#
# Run: 1231, exploration: 0.01, score: 137
# Scores: (min: 8, avg: 60.16, max: 400)
#
# Run: 1232, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 62.15, max: 400)
#
# Run: 1233, exploration: 0.01, score: 289
# Scores: (min: 8, avg: 64.94, max: 400)
#
# Run: 1234, exploration: 0.01, score: 237
# Scores: (min: 8, avg: 67.21, max: 400)
#
# Run: 1235, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 69.11, max: 400)
#
# Run: 1236, exploration: 0.01, score: 192
# Scores: (min: 8, avg: 70.94, max: 400)
#
# Run: 1237, exploration: 0.01, score: 465
# Scores: (min: 8, avg: 75.49, max: 465)
#
# Run: 1238, exploration: 0.01, score: 275
# Scores: (min: 8, avg: 78.16, max: 465)
#
# Run: 1239, exploration: 0.01, score: 411
# Scores: (min: 8, avg: 82.17, max: 465)
# Run: 1240, exploration: 0.01, score: 193
# Scores: (min: 9, avg: 84.02, max: 465)
#
# Run: 1241, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 85.42, max: 465)
#
# Run: 1242, exploration: 0.01, score: 358
# Scores: (min: 9, avg: 88.9, max: 465)
#
# Run: 1243, exploration: 0.01, score: 199
# Scores: (min: 9, avg: 90.79, max: 465)
#
# Run: 1244, exploration: 0.01, score: 168
# Scores: (min: 9, avg: 92.38, max: 465)
#
# Run: 1245, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 94.09, max: 465)
#
# Run: 1246, exploration: 0.01, score: 273
# Scores: (min: 9, avg: 96.72, max: 465)
#
# Run: 1247, exploration: 0.01, score: 195
# Scores: (min: 9, avg: 98.57, max: 465)
#
# Run: 1248, exploration: 0.01, score: 236
# Scores: (min: 9, avg: 100.84, max: 465)
#
# Run: 1249, exploration: 0.01, score: 211
# Scores: (min: 9, avg: 102.85, max: 465)
#
# Run: 1250, exploration: 0.01, score: 241
# Scores: (min: 9, avg: 105.17, max: 465)
#
# Run: 1251, exploration: 0.01, score: 244
# Scores: (min: 9, avg: 107.52, max: 465)
#
# Run: 1252, exploration: 0.01, score: 202
# Scores: (min: 9, avg: 109.45, max: 465)
#
# Run: 1253, exploration: 0.01, score: 287
# Scores: (min: 9, avg: 112.22, max: 465)
#
# Run: 1254, exploration: 0.01, score: 225
# Scores: (min: 9, avg: 114.37, max: 465)
#
# Run: 1255, exploration: 0.01, score: 209
# Scores: (min: 9, avg: 116.37, max: 465)
#
# Run: 1256, exploration: 0.01, score: 241
# Scores: (min: 9, avg: 118.69, max: 465)
#
# Run: 1257, exploration: 0.01, score: 230
# Scores: (min: 9, avg: 120.89, max: 465)
#
# Run: 1258, exploration: 0.01, score: 271
# Scores: (min: 9, avg: 123.51, max: 465)
#
# Run: 1259, exploration: 0.01, score: 200
# Scores: (min: 9, avg: 125.41, max: 465)
#
# Run: 1260, exploration: 0.01, score: 279
# Scores: (min: 11, avg: 128.11, max: 465)
#
# Run: 1261, exploration: 0.01, score: 228
# Scores: (min: 11, avg: 130.14, max: 465)
#
# Run: 1262, exploration: 0.01, score: 229
# Scores: (min: 11, avg: 132.17, max: 465)
#
# Run: 1263, exploration: 0.01, score: 290
# Scores: (min: 11, avg: 134.86, max: 465)
#
# Run: 1264, exploration: 0.01, score: 271
# Scores: (min: 11, avg: 137.27, max: 465)
#
# Run: 1265, exploration: 0.01, score: 204
# Scores: (min: 11, avg: 139.14, max: 465)
#
# Run: 1266, exploration: 0.01, score: 273
# Scores: (min: 11, avg: 141.62, max: 465)
#
# Run: 1267, exploration: 0.01, score: 215
# Scores: (min: 11, avg: 143.62, max: 465)
#
# Run: 1268, exploration: 0.01, score: 273
# Scores: (min: 11, avg: 146.07, max: 465)
#
# Run: 1269, exploration: 0.01, score: 335
# Scores: (min: 11, avg: 149.24, max: 465)
#
# Run: 1270, exploration: 0.01, score: 245
# Scores: (min: 11, avg: 151.42, max: 465)
#
# Run: 1271, exploration: 0.01, score: 154
# Scores: (min: 11, avg: 152.78, max: 465)
#
# Run: 1272, exploration: 0.01, score: 303
# Scores: (min: 11, avg: 155.54, max: 465)
#
# Run: 1273, exploration: 0.01, score: 194
# Scores: (min: 11, avg: 157.17, max: 465)
#
# Run: 1274, exploration: 0.01, score: 311
# Scores: (min: 11, avg: 159.97, max: 465)
#
# Run: 1275, exploration: 0.01, score: 500
# Scores: (min: 11, avg: 164.72, max: 500)
#
# Run: 1276, exploration: 0.01, score: 195
# Scores: (min: 11, avg: 165.71, max: 500)
#
# Run: 1277, exploration: 0.01, score: 194
# Scores: (min: 11, avg: 167.03, max: 500)
#
# Run: 1278, exploration: 0.01, score: 222
# Scores: (min: 11, avg: 168.7, max: 500)
#
# Run: 1279, exploration: 0.01, score: 232
# Scores: (min: 11, avg: 170.78, max: 500)
#
# Run: 1280, exploration: 0.01, score: 321
# Scores: (min: 11, avg: 173.27, max: 500)
#
# Run: 1281, exploration: 0.01, score: 198
# Scores: (min: 11, avg: 174.96, max: 500)
#
# Run: 1282, exploration: 0.01, score: 441
# Scores: (min: 11, avg: 179.1, max: 500)
#
# Run: 1283, exploration: 0.01, score: 229
# Scores: (min: 11, avg: 181.1, max: 500)
#
# Run: 1284, exploration: 0.01, score: 351
# Scores: (min: 11, avg: 184.1, max: 500)
#
# Run: 1285, exploration: 0.01, score: 146
# Scores: (min: 11, avg: 185.15, max: 500)
#
# Run: 1286, exploration: 0.01, score: 239
# Scores: (min: 11, avg: 187.22, max: 500)
#
# Run: 1287, exploration: 0.01, score: 183
# Scores: (min: 11, avg: 188.53, max: 500)
#
# Run: 1288, exploration: 0.01, score: 232
# Scores: (min: 11, avg: 190.48, max: 500)
#
# Run: 1289, exploration: 0.01, score: 165
# Scores: (min: 11, avg: 190.84, max: 500)
#
# Run: 1290, exploration: 0.01, score: 169
# Scores: (min: 11, avg: 191.59, max: 500)
#
# Run: 1291, exploration: 0.01, score: 269
# Scores: (min: 11, avg: 194.01, max: 500)
#
# Run: 1292, exploration: 0.01, score: 145
# Scores: (min: 11, avg: 195.16, max: 500)
#
# Solved in 1192 runs, 1292 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-238ba1e1e267> in <module>
#       2 LEARNING_RATE = 0.01
#       3
# ----> 4 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# ### Reinforcement learning
# The cartpole problem is one in wich a pole is balanced on a cart via a pivot. The goal is to keep the pole upright by moving the cart back and forth. The goal of the agent in this case it to keep the pole upright. The state values are the carts position and velocity, as well as the poles andle and angular velocity.(Gymnasium) The only actions possible are to move left or right, and the model is trained to chose between these using a Deep Q-Network.
#
# ### Experence Replay
# In this algorithm past batches of experence are remembered and used for future training. This helps the model with stability making sure it's not overtrained on the last action, or overfit the trainig data. We use a discout factor to calculate future rewards. We need to strike a ballance between training for the current situation and the future states and the discount facter allowes us to reduce the reward for future states.
#
# ### Neural Networks
# This network has two hidden layers and output layer with the move left and right options. Q-Learning works well for instances with a set number of states but can struggle with continuous problems like cartpole. This is where neural networds come in to provide a more generalivable prediction table that isn't dependent on the number of states from the begining. (Taweh, 2019) The learning rate informs how fast the neural network changes it's weights. A learing rate that is too high the model will skip all over the place and posibly not converge. With a learing rate too low it will take forever for the model to improve and may get caught in a local maximum.

# %% [markdown]
# ## References
#
# Gymnasium Documentation. (n.d.). Gymnasium.farama.org. https://gymnasium.farama.org/
#
# Lamba, A. (2018, September 3). An introduction to Q-Learning: reinforcement learning. We’ve Moved to FreeCodeCamp.org/News. https://medium.com/free-code-camp/an-introduction-to-q-learning-reinforcement-learning-14ac0b4493cc
#
# Patel, R. (2025, June 29). Master CartPole RL: Unlock Fun Learning with Setup, Q-Learning & More! Aigreeks.com. https://aigreeks.com/cartpole-magic-master-reinforcement-learning/
#
# Taweh Beysolow Ii, & Springerlink (Online Service. (2019). Applied Reinforcement Learning with Python : With OpenAI Gym, Tensorflow, and Keras. Apress.
